# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Homo_sapiens_AR109.20190905_annotation_report.xml')
root = tree.getroot()
print(root.tag, root.attrib)
for child in root:
    print(child.tag, child.attrib)
# Out:
# AnnotationReports {}
# AssembliesReport {'target_set_accession': 'GCF_002925485.2'}
# BuildInfo {}
# FeatureCounts {}
# FeatureStats {}

# %%
# children
count = 0 
for child in root:
    count += 1
print(count)
# Out:
# 4

# %%
# grandchildren
count = 0
for child in root:
    print('Child:')
    print(child.tag, child.attrib)
    print('Grandchildren:')
    for grandchild in child:
        count += 1
        if count < 10:
            print(grandchild.tag, grandchild.attrib)
    print(count)
    print('\n\n')
# Out:
# Child:
# AssembliesReport {'target_set_accession': 'GCF_002925485.2'}
# Grandchildren:
# FullAssembly {}
# 1
#
#
#
# Child:
# BuildInfo {}
# Grandchildren:
# Taxid {}
# ScientificName {}
# AnnotationReleaseId {}
# FreezeDate {}
# FreezeDateId {}
# IdLoadDate {}
# SoftwareMajorVersion {}
# SoftwareMinorVersion {}
# 11
#
#
#
# Child:
# FeatureCounts {}
# Grandchildren:
# 51
#
#
#
# Child:
# FeatureStats {}
# Grandchildren:
# 91

# %%
# great grandchildren
count = 0
for child in root:
    print('Child:')
    print(child.tag, child.attrib)
    print('Grandchildren:')
    for grandchild in child:
        count += 1
        if count < 10:
            print(grandchild.tag, grandchild.attrib)
        for greatgrandchild in grandchild:
            count += 1
            if count < 10:
                print('Great Grandchildren: ', greatgrandchild.tag, greatgrandchild.attrib)
            for greatgreatgrandchild in greatgrandchild:
                count += 1
                if count < 10:
                    print('Great Great Grandchildren: ', greatgreatgrandchild.tag, greatgreatgrandchild.attrib)
                for ggggchild in greatgreatgrandchild:
                    count += 1
                    if count < 10:
                        print('Great Great Great Grandchildren: ', ggggchild.tag, ggggchild.attrib, '\n')
    print(count)
    print('\n\n')
# Out:
# Child:
# AssembliesReport {'target_set_accession': 'GCF_002925485.2'}
# Grandchildren:
# FullAssembly {}
# Great Grandchildren:  Name {}
# Great Grandchildren:  Accession {}
# Great Grandchildren:  IsReference {}
# Great Grandchildren:  SubmitterOrganization {}
# Great Grandchildren:  SubmitterDate {}
# Great Grandchildren:  AssemblyContents {}
# Great Great Grandchildren:  Chromosomes {}
# Great Great Grandchildren:  AlternateLoci {}
# 203
#
#
#
# Child:
# BuildInfo {}
# Grandchildren:
# 213
#
#
#
# Child:
# FeatureCounts {}
# Grandchildren:
# 2621
#
#
#
# Child:
# FeatureStats {}
# Grandchildren:
# 6391

# %%
tags = []
for element in root.iter():
    tags.append(element.tag)
print(len(tags))
tags
# Out:
# 6396
# ['AnnotationReports',
#  'AssembliesReport',
#  'FullAssembly',
#  'Name',
#  'Accession',
#  'IsReference',
#  'SubmitterOrganization',
#  'SubmitterDate',
#  'AssemblyContents',
#  'Chromosomes',
#  'AlternateLoci',
#  'AssemblyPatches',
#  'UnlocalizedScaffolds',
#  'UnplacedScaffolds',
#  'Units',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'AssemblyUnit',
#  'Name',
#  'Accession',
#  'IsPrimary',
#  'Type',
#  'BuildInfo',
#  'Taxid',
#  'ScientificName',
#  'AnnotationReleaseId',
#  'FreezeDate',
#  'FreezeDateId',
#  'IdLoadDate',
#  'SoftwareMajorVersion',
#  'SoftwareMinorVersion',
#  'MaskingSoftware',
#  'FtpSite',
#  'FeatureCounts',
#  'OverallCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'AssemblyCounts',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Counts',
#  'Total',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  'Subcount',
#  ...]

# %%
full_assembly_collection = []
for i in root[0][0]:
    tags = []
    text = []
    attributes = []
    for element in i.iter():
        tags.append(element.tag)
        text.append(element.text)
        attributes.append(element.attrib)
    thing = list(zip(tags,attributes,text))
    full_assembly_collection.append(thing)
full_assembly_collection
# Out:
# [[('Name', {}, 'GRCh38.p13')],
#  [('Accession', {}, 'GCF_000001405.39')],
#  [('IsReference', {}, 'Yes')],
#  [('SubmitterOrganization', {}, 'Genome Reference Consortium')],
#  [('SubmitterDate', {}, '02-28-2019')],
#  [('AssemblyContents', {}, '\n      '),
#   ('Chromosomes', {}, '25'),
#   ('AlternateLoci', {}, None),
#   ('AssemblyPatches', {}, None),
#   ('UnlocalizedScaffolds', {}, None),
#   ('UnplacedScaffolds', {}, None)],
#  [('Units', {}, '\n      '),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'Primary Assembly'),
#   ('Accession', {}, 'GCF_000001305.15'),
#   ('IsPrimary', {}, 'Yes'),
#   ('Type', {}, 'HaploidUnit'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'PATCHES'),
#   ('Accession', {}, 'GCF_000005045.25'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AssemblyPatches'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_1'),
#   ('Accession', {}, 'GCF_000001315.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_2'),
#   ('Accession', {}, 'GCF_000001325.3'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_3'),
#   ('Accession', {}, 'GCF_000001335.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_4'),
#   ('Accession', {}, 'GCF_000001345.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_5'),
#   ('Accession', {}, 'GCF_000001355.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_6'),
#   ('Accession', {}, 'GCF_000001365.3'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_7'),
#   ('Accession', {}, 'GCF_000001375.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_8'),
#   ('Accession', {}, 'GCF_000510225.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_9'),
#   ('Accession', {}, 'GCF_000510235.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_10'),
#   ('Accession', {}, 'GCF_000509915.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_11'),
#   ('Accession', {}, 'GCF_000509925.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_12'),
#   ('Accession', {}, 'GCF_000509935.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_13'),
#   ('Accession', {}, 'GCF_000509945.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_14'),
#   ('Accession', {}, 'GCF_000509955.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_15'),
#   ('Accession', {}, 'GCF_000509965.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_16'),
#   ('Accession', {}, 'GCF_000509975.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_17'),
#   ('Accession', {}, 'GCF_000509985.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_18'),
#   ('Accession', {}, 'GCF_000509995.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_19'),
#   ('Accession', {}, 'GCF_000510005.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_20'),
#   ('Accession', {}, 'GCF_000510015.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_21'),
#   ('Accession', {}, 'GCF_000510025.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_22'),
#   ('Accession', {}, 'GCF_000510035.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_23'),
#   ('Accession', {}, 'GCF_000510045.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_24'),
#   ('Accession', {}, 'GCF_000510055.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_25'),
#   ('Accession', {}, 'GCF_000510065.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_26'),
#   ('Accession', {}, 'GCF_000510075.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_27'),
#   ('Accession', {}, 'GCF_000510085.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_28'),
#   ('Accession', {}, 'GCF_000510095.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_29'),
#   ('Accession', {}, 'GCF_000510105.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_30'),
#   ('Accession', {}, 'GCF_000510125.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_31'),
#   ('Accession', {}, 'GCF_000510135.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_32'),
#   ('Accession', {}, 'GCF_000510145.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_33'),
#   ('Accession', {}, 'GCF_000510155.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_34'),
#   ('Accession', {}, 'GCF_000510165.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_35'),
#   ('Accession', {}, 'GCF_000510175.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci'),
#   ('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'non-nuclear'),
#   ('Accession', {}, 'GCF_000006015.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'HaploidUnit')]]

# %%
assembly_contents_collection = []
for i in root[0][0][5]:
    tags = []
    text = []
    attributes = []
    for element in i.iter():
        tags.append(element.tag)
        text.append(element.text)
        attributes.append(element.attrib)
    thing = list(zip(tags,attributes,text))
    assembly_contents_collection.append(thing)
assembly_contents_collection
# Out:
# [[('Chromosomes', {}, '25')],
#  [('AlternateLoci', {}, None)],
#  [('AssemblyPatches', {}, None)],
#  [('UnlocalizedScaffolds', {}, None)],
#  [('UnplacedScaffolds', {}, None)]]

# %%
assembly_unit_collection = []
for i in root[0][0][6]:
    tags = []
    text = []
    attributes = []
    for element in i.iter():
        tags.append(element.tag)
        text.append(element.text)
        attributes.append(element.attrib)
    thing = list(zip(tags, attributes, text))
    assembly_unit_collection.append(thing)
print(len(assembly_unit_collection))
assembly_unit_collection
# Out:
# 38
# [[('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'Primary Assembly'),
#   ('Accession', {}, 'GCF_000001305.15'),
#   ('IsPrimary', {}, 'Yes'),
#   ('Type', {}, 'HaploidUnit')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'PATCHES'),
#   ('Accession', {}, 'GCF_000005045.25'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AssemblyPatches')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_1'),
#   ('Accession', {}, 'GCF_000001315.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_2'),
#   ('Accession', {}, 'GCF_000001325.3'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_3'),
#   ('Accession', {}, 'GCF_000001335.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_4'),
#   ('Accession', {}, 'GCF_000001345.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_5'),
#   ('Accession', {}, 'GCF_000001355.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_6'),
#   ('Accession', {}, 'GCF_000001365.3'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_7'),
#   ('Accession', {}, 'GCF_000001375.2'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_8'),
#   ('Accession', {}, 'GCF_000510225.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_9'),
#   ('Accession', {}, 'GCF_000510235.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_10'),
#   ('Accession', {}, 'GCF_000509915.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_11'),
#   ('Accession', {}, 'GCF_000509925.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_12'),
#   ('Accession', {}, 'GCF_000509935.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_13'),
#   ('Accession', {}, 'GCF_000509945.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_14'),
#   ('Accession', {}, 'GCF_000509955.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_15'),
#   ('Accession', {}, 'GCF_000509965.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_16'),
#   ('Accession', {}, 'GCF_000509975.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_17'),
#   ('Accession', {}, 'GCF_000509985.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_18'),
#   ('Accession', {}, 'GCF_000509995.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_19'),
#   ('Accession', {}, 'GCF_000510005.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_20'),
#   ('Accession', {}, 'GCF_000510015.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_21'),
#   ('Accession', {}, 'GCF_000510025.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_22'),
#   ('Accession', {}, 'GCF_000510035.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_23'),
#   ('Accession', {}, 'GCF_000510045.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_24'),
#   ('Accession', {}, 'GCF_000510055.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_25'),
#   ('Accession', {}, 'GCF_000510065.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_26'),
#   ('Accession', {}, 'GCF_000510075.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_27'),
#   ('Accession', {}, 'GCF_000510085.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_28'),
#   ('Accession', {}, 'GCF_000510095.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_29'),
#   ('Accession', {}, 'GCF_000510105.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_30'),
#   ('Accession', {}, 'GCF_000510125.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_31'),
#   ('Accession', {}, 'GCF_000510135.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_32'),
#   ('Accession', {}, 'GCF_000510145.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_33'),
#   ('Accession', {}, 'GCF_000510155.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_34'),
#   ('Accession', {}, 'GCF_000510165.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'ALT_REF_LOCI_35'),
#   ('Accession', {}, 'GCF_000510175.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'AlternateLoci')],
#  [('AssemblyUnit', {}, '\n        '),
#   ('Name', {}, 'non-nuclear'),
#   ('Accession', {}, 'GCF_000006015.1'),
#   ('IsPrimary', {}, 'No'),
#   ('Type', {}, 'HaploidUnit')]]

# %%
build_info_collection = []
for i in root[1]:
    tags = []
    text = []
    attributes = []
    for element in i.iter():
        tags.append(element.tag)
        text.append(element.text)
        attributes.append(element.attrib)
    thing = list(zip(tags,attributes,text))
    build_info_collection.append(thing)
print(len(build_info_collection))
build_info_collection
# Out:
# 10
# [[('Taxid', {}, '9606')],
#  [('ScientificName', {}, 'Homo sapiens')],
#  [('AnnotationReleaseId', {}, '109')],
#  [('FreezeDate', {}, 'Sep 5 2019')],
#  [('FreezeDateId', {}, '20190905')],
#  [('IdLoadDate', {}, 'Sep 9 2019')],
#  [('SoftwareMajorVersion', {}, '8')],
#  [('SoftwareMinorVersion', {}, '2')],
#  [('MaskingSoftware', {}, 'repeatmasker')],
#  [('FtpSite',
#    {},
#    'ftp://ftp.ncbi.nlm.nih.gov/genomes/all/annotation_releases/9606/109.20190905')]]

# %%
feature_counts_collection = []
for i in root[2]:
    tags = []
    text = []
    attributes = []
    for element in i.iter():
        tags.append(element.tag)
        text.append(element.text)
        attributes.append(element.attrib)
    thing = list(zip(tags, attributes ,text))
    feature_counts_collection.append(thing)
print(len(feature_counts_collection))
feature_counts_collection
# Out:
# 40
# [[('OverallCounts', {}, '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '54639'),
#   ('Subcount', {'subtype': 'other'}, '47'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '15204'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1135'),
#   ('Subcount', {'subtype': 'has variants'}, '19965'),
#   ('Subcount', {'subtype': 'partial'}, '364'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '397'),
#   ('Subcount', {'subtype': 'non coding'}, '18012'),
#   ('Subcount', {'subtype': 'protein coding'}, '19844'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '112430'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '172'),
#   ('Subcount', {'subtype': 'partial'}, '26'),
#   ('Subcount', {'subtype': 'correction'}, '1542'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '58361'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '54069'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '1541'),
#   ('Subcount', {'subtype': 'fully supported'}, '112283'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '88'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '1'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '47041'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '15'),
#   ('Subcount', {'subtype': 'partial'}, '7'),
#   ('Subcount', {'subtype': 'correction'}, '196'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '29863'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '15319'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '196'),
#   ('Subcount', {'subtype': 'fully supported'}, '45168'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1442'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '-2'),
#   ('Subcount', {'subtype': 'correction'}, '74'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '108'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1334'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '74'),
#   ('Subcount', {'subtype': 'fully supported'}, '1431'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '113017'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '2600'),
#   ('Subcount', {'subtype': 'partial'}, '514'),
#   ('Subcount', {'subtype': 'correction'}, '1109'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '58374'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '54069'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '534'),
#   ('Subcount', {'subtype': 'fully supported'}, '112283'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '118'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '1'),
#   ('Subcount', {'subtype': 'major correction'}, '69'),
#   ('Subcount', {'subtype': 'minor correction'}, '503'),
#   ('Subcount', {'subtype': 'premature stop'}, '57'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '35')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001405.39', 'Type': 'full assembly'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '54639'),
#   ('Subcount', {'subtype': 'other'}, '47'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '15204'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1135'),
#   ('Subcount', {'subtype': 'has variants'}, '19965'),
#   ('Subcount', {'subtype': 'partial'}, '364'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '397'),
#   ('Subcount', {'subtype': 'non coding'}, '18012'),
#   ('Subcount', {'subtype': 'protein coding'}, '19844'),
#   ('Subcount', {'subtype': 'multiply placed'}, '3433'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '112430'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '172'),
#   ('Subcount', {'subtype': 'partial'}, '26'),
#   ('Subcount', {'subtype': 'correction'}, '1542'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '58361'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '54069'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '1541'),
#   ('Subcount', {'subtype': 'fully supported'}, '112283'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '88'),
#   ('Subcount', {'subtype': 'multiply placed'}, '2901'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '1'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '47041'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '15'),
#   ('Subcount', {'subtype': 'partial'}, '7'),
#   ('Subcount', {'subtype': 'correction'}, '196'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '29863'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '15319'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '196'),
#   ('Subcount', {'subtype': 'fully supported'}, '45168'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'multiply placed'}, '695'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1442'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '-2'),
#   ('Subcount', {'subtype': 'correction'}, '74'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '108'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1334'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '74'),
#   ('Subcount', {'subtype': 'fully supported'}, '1431'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'multiply placed'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '113017'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '2600'),
#   ('Subcount', {'subtype': 'partial'}, '514'),
#   ('Subcount', {'subtype': 'correction'}, '1109'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '58374'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '54069'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '534'),
#   ('Subcount', {'subtype': 'fully supported'}, '112283'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '118'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '1'),
#   ('Subcount', {'subtype': 'major correction'}, '69'),
#   ('Subcount', {'subtype': 'minor correction'}, '503'),
#   ('Subcount', {'subtype': 'premature stop'}, '57'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '35')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001305.15', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '54312'),
#   ('Subcount', {'subtype': 'other'}, '45'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '15137'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1127'),
#   ('Subcount', {'subtype': 'has variants'}, '19886'),
#   ('Subcount', {'subtype': 'partial'}, '366'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '388'),
#   ('Subcount', {'subtype': 'non coding'}, '17860'),
#   ('Subcount', {'subtype': 'protein coding'}, '19755'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '112169'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '172'),
#   ('Subcount', {'subtype': 'partial'}, '31'),
#   ('Subcount', {'subtype': 'correction'}, '1565'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '58188'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '53981'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '1564'),
#   ('Subcount', {'subtype': 'fully supported'}, '112038'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '78'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '1'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '45167'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '14'),
#   ('Subcount', {'subtype': 'partial'}, '4'),
#   ('Subcount', {'subtype': 'correction'}, '195'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '28479'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '15310'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '195'),
#   ('Subcount', {'subtype': 'fully supported'}, '43775'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1426'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '1'),
#   ('Subcount', {'subtype': 'correction'}, '78'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '97'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1329'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '78'),
#   ('Subcount', {'subtype': 'fully supported'}, '1417'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '112558'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '2602'),
#   ('Subcount', {'subtype': 'partial'}, '348'),
#   ('Subcount', {'subtype': 'correction'}, '938'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '58188'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '53981'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '548'),
#   ('Subcount', {'subtype': 'fully supported'}, '112038'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '104'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '1'),
#   ('Subcount', {'subtype': 'major correction'}, '66'),
#   ('Subcount', {'subtype': 'minor correction'}, '493'),
#   ('Subcount', {'subtype': 'premature stop'}, '61'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '45')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001405.39', 'Type': 'grouped alt loci'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '2398'),
#   ('Subcount', {'subtype': 'other'}, '8'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '631'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '90'),
#   ('Subcount', {'subtype': 'has variants'}, '606'),
#   ('Subcount', {'subtype': 'partial'}, '297'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '161'),
#   ('Subcount', {'subtype': 'non coding'}, '676'),
#   ('Subcount', {'subtype': 'protein coding'}, '832'),
#   ('Subcount', {'subtype': 'multiply placed'}, '658'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '1917'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '267'),
#   ('Subcount', {'subtype': 'correction'}, '818'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '136'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1781'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '818'),
#   ('Subcount', {'subtype': 'fully supported'}, '1906'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '7'),
#   ('Subcount', {'subtype': 'multiply placed'}, '638'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '1820'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '1'),
#   ('Subcount', {'subtype': 'partial'}, '56'),
#   ('Subcount', {'subtype': 'correction'}, '166'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '1013'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '506'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '170'),
#   ('Subcount', {'subtype': 'fully supported'}, '1519'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'multiply placed'}, '183'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '109'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '9'),
#   ('Subcount', {'subtype': 'correction'}, '65'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '8'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '101'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '65'),
#   ('Subcount', {'subtype': 'fully supported'}, '107'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'multiply placed'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '2077'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '28'),
#   ('Subcount', {'subtype': 'partial'}, '364'),
#   ('Subcount', {'subtype': 'correction'}, '654'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '136'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1778'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '491'),
#   ('Subcount', {'subtype': 'fully supported'}, '1906'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '10'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '61'),
#   ('Subcount', {'subtype': 'minor correction'}, '544'),
#   ('Subcount', {'subtype': 'premature stop'}, '26'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '28')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001315.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '1942'),
#   ('Subcount', {'subtype': 'other'}, '8'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '515'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '71'),
#   ('Subcount', {'subtype': 'has variants'}, '486'),
#   ('Subcount', {'subtype': 'partial'}, '305'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '161'),
#   ('Subcount', {'subtype': 'non coding'}, '529'),
#   ('Subcount', {'subtype': 'protein coding'}, '658'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '1505'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '281'),
#   ('Subcount', {'subtype': 'correction'}, '743'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '82'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1423'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '743'),
#   ('Subcount', {'subtype': 'fully supported'}, '1498'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '4'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '1038'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '1'),
#   ('Subcount', {'subtype': 'partial'}, '71'),
#   ('Subcount', {'subtype': 'correction'}, '162'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '582'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '417'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '166'),
#   ('Subcount', {'subtype': 'fully supported'}, '999'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '85'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '6'),
#   ('Subcount', {'subtype': 'correction'}, '53'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '6'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '79'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '53'),
#   ('Subcount', {'subtype': 'fully supported'}, '84'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '1665'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '25'),
#   ('Subcount', {'subtype': 'partial'}, '384'),
#   ('Subcount', {'subtype': 'correction'}, '651'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '82'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1420'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '488'),
#   ('Subcount', {'subtype': 'fully supported'}, '1498'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '6'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '45'),
#   ('Subcount', {'subtype': 'minor correction'}, '443'),
#   ('Subcount', {'subtype': 'premature stop'}, '27'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '39')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001325.3', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '784'),
#   ('Subcount', {'subtype': 'other'}, '2'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '182'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '31'),
#   ('Subcount', {'subtype': 'has variants'}, '210'),
#   ('Subcount', {'subtype': 'partial'}, '24'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '241'),
#   ('Subcount', {'subtype': 'protein coding'}, '328'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '700'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '44'),
#   ('Subcount', {'subtype': 'correction'}, '428'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '19'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '681'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '428'),
#   ('Subcount', {'subtype': 'fully supported'}, '697'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '2'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '470'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '8'),
#   ('Subcount', {'subtype': 'correction'}, '103'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '215'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '208'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '104'),
#   ('Subcount', {'subtype': 'fully supported'}, '423'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '38'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '3'),
#   ('Subcount', {'subtype': 'correction'}, '27'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '2'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '36'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '27'),
#   ('Subcount', {'subtype': 'fully supported'}, '37'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '700'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '9'),
#   ('Subcount', {'subtype': 'partial'}, '38'),
#   ('Subcount', {'subtype': 'correction'}, '207'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '19'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '681'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '207'),
#   ('Subcount', {'subtype': 'fully supported'}, '697'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '3'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '24'),
#   ('Subcount', {'subtype': 'minor correction'}, '183'),
#   ('Subcount', {'subtype': 'premature stop'}, '17'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '17')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001335.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '398'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '86'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '12'),
#   ('Subcount', {'subtype': 'has variants'}, '127'),
#   ('Subcount', {'subtype': 'partial'}, '15'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '112'),
#   ('Subcount', {'subtype': 'protein coding'}, '188'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '410'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '22'),
#   ('Subcount', {'subtype': 'correction'}, '227'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '5'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '405'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '227'),
#   ('Subcount', {'subtype': 'fully supported'}, '409'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '1'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '209'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '6'),
#   ('Subcount', {'subtype': 'correction'}, '70'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '48'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '138'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '71'),
#   ('Subcount', {'subtype': 'fully supported'}, '186'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '17'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '1'),
#   ('Subcount', {'subtype': 'correction'}, '14'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '17'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '14'),
#   ('Subcount', {'subtype': 'fully supported'}, '17'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '410'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '2'),
#   ('Subcount', {'subtype': 'partial'}, '21'),
#   ('Subcount', {'subtype': 'correction'}, '135'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '5'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '405'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '135'),
#   ('Subcount', {'subtype': 'fully supported'}, '409'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '1'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '8'),
#   ('Subcount', {'subtype': 'minor correction'}, '127'),
#   ('Subcount', {'subtype': 'premature stop'}, '5'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '4')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001345.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '340'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '83'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '10'),
#   ('Subcount', {'subtype': 'has variants'}, '111'),
#   ('Subcount', {'subtype': 'partial'}, '13'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '92'),
#   ('Subcount', {'subtype': 'protein coding'}, '155'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '366'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '29'),
#   ('Subcount', {'subtype': 'correction'}, '213'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '7'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '359'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '213'),
#   ('Subcount', {'subtype': 'fully supported'}, '366'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '176'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '1'),
#   ('Subcount', {'subtype': 'correction'}, '58'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '35'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '113'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '60'),
#   ('Subcount', {'subtype': 'fully supported'}, '148'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '15'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '11'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '15'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '11'),
#   ('Subcount', {'subtype': 'fully supported'}, '15'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '366'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '3'),
#   ('Subcount', {'subtype': 'partial'}, '24'),
#   ('Subcount', {'subtype': 'correction'}, '128'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '7'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '359'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '128'),
#   ('Subcount', {'subtype': 'fully supported'}, '366'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '13'),
#   ('Subcount', {'subtype': 'minor correction'}, '115'),
#   ('Subcount', {'subtype': 'premature stop'}, '6'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '8')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001355.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '346'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '69'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '10'),
#   ('Subcount', {'subtype': 'has variants'}, '113'),
#   ('Subcount', {'subtype': 'partial'}, '18'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '92'),
#   ('Subcount', {'subtype': 'protein coding'}, '175'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '402'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '32'),
#   ('Subcount', {'subtype': 'correction'}, '234'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '8'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '394'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '234'),
#   ('Subcount', {'subtype': 'fully supported'}, '402'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '164'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '7'),
#   ('Subcount', {'subtype': 'correction'}, '62'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '29'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '105'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '63'),
#   ('Subcount', {'subtype': 'fully supported'}, '134'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '15'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '1'),
#   ('Subcount', {'subtype': 'correction'}, '11'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '15'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '11'),
#   ('Subcount', {'subtype': 'fully supported'}, '15'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '402'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '3'),
#   ('Subcount', {'subtype': 'partial'}, '30'),
#   ('Subcount', {'subtype': 'correction'}, '148'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '8'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '394'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '148'),
#   ('Subcount', {'subtype': 'fully supported'}, '402'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '16'),
#   ('Subcount', {'subtype': 'minor correction'}, '132'),
#   ('Subcount', {'subtype': 'premature stop'}, '14'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '14')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001365.3', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '367'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '75'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '9'),
#   ('Subcount', {'subtype': 'has variants'}, '123'),
#   ('Subcount', {'subtype': 'partial'}, '7'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '104'),
#   ('Subcount', {'subtype': 'protein coding'}, '179'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '408'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '12'),
#   ('Subcount', {'subtype': 'correction'}, '276'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '6'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '402'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '276'),
#   ('Subcount', {'subtype': 'fully supported'}, '408'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '198'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '71'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '36'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '130'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '72'),
#   ('Subcount', {'subtype': 'fully supported'}, '166'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '13'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '10'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '13'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '10'),
#   ('Subcount', {'subtype': 'fully supported'}, '13'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '408'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '3'),
#   ('Subcount', {'subtype': 'partial'}, '12'),
#   ('Subcount', {'subtype': 'correction'}, '134'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '6'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '402'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '134'),
#   ('Subcount', {'subtype': 'fully supported'}, '408'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '8'),
#   ('Subcount', {'subtype': 'minor correction'}, '126'),
#   ('Subcount', {'subtype': 'premature stop'}, '4'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '6')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000001375.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '385'),
#   ('Subcount', {'subtype': 'other'}, '1'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '82'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '13'),
#   ('Subcount', {'subtype': 'has variants'}, '124'),
#   ('Subcount', {'subtype': 'partial'}, '16'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '112'),
#   ('Subcount', {'subtype': 'protein coding'}, '177'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '420'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '37'),
#   ('Subcount', {'subtype': 'correction'}, '265'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '5'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '415'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '265'),
#   ('Subcount', {'subtype': 'fully supported'}, '420'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '206'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '5'),
#   ('Subcount', {'subtype': 'correction'}, '73'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '46'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '125'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '74'),
#   ('Subcount', {'subtype': 'fully supported'}, '171'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '17'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '13'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '17'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '13'),
#   ('Subcount', {'subtype': 'fully supported'}, '17'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '419'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '2'),
#   ('Subcount', {'subtype': 'partial'}, '28'),
#   ('Subcount', {'subtype': 'correction'}, '171'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '5'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '414'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '171'),
#   ('Subcount', {'subtype': 'fully supported'}, '420'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '13'),
#   ('Subcount', {'subtype': 'minor correction'}, '160'),
#   ('Subcount', {'subtype': 'premature stop'}, '7'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '7')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000510225.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '45'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '5'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '24'),
#   ('Subcount', {'subtype': 'partial'}, '3'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '8'),
#   ('Subcount', {'subtype': 'protein coding'}, '31'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '92'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '3'),
#   ('Subcount', {'subtype': 'correction'}, '52'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '92'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '52'),
#   ('Subcount', {'subtype': 'fully supported'}, '92'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '21'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '6'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '7'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '14'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '7'),
#   ('Subcount', {'subtype': 'fully supported'}, '21'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '1'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '1'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '92'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '4'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '40'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '92'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '40'),
#   ('Subcount', {'subtype': 'fully supported'}, '92'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '1'),
#   ('Subcount', {'subtype': 'minor correction'}, '39'),
#   ('Subcount', {'subtype': 'premature stop'}, '1'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '1')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000510235.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '65'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '9'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '2'),
#   ('Subcount', {'subtype': 'has variants'}, '34'),
#   ('Subcount', {'subtype': 'partial'}, '1'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '11'),
#   ('Subcount', {'subtype': 'protein coding'}, '43'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '126'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '73'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '4'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '122'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '73'),
#   ('Subcount', {'subtype': 'fully supported'}, '126'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '32'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '5'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '14'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '18'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '5'),
#   ('Subcount', {'subtype': 'fully supported'}, '32'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '6'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '5'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '6'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '5'),
#   ('Subcount', {'subtype': 'fully supported'}, '6'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '126'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '4'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '49'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '4'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '122'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '49'),
#   ('Subcount', {'subtype': 'fully supported'}, '126'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '1'),
#   ('Subcount', {'subtype': 'minor correction'}, '48'),
#   ('Subcount', {'subtype': 'premature stop'}, '1'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '1')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000509915.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '15'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '2'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '5'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '1'),
#   ('Subcount', {'subtype': 'protein coding'}, '11'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '19'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '10'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '19'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '10'),
#   ('Subcount', {'subtype': 'fully supported'}, '19'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '2'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '2'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '2'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '2'),
#   ('Subcount', {'subtype': 'fully supported'}, '2'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '19'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '9'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '19'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '9'),
#   ('Subcount', {'subtype': 'fully supported'}, '19'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '9'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000509925.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '11'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '2'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '4'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '1'),
#   ('Subcount', {'subtype': 'protein coding'}, '7'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '10'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '9'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '10'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '9'),
#   ('Subcount', {'subtype': 'fully supported'}, '10'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '2'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '2'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '2'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '10'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '6'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '10'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '6'),
#   ('Subcount', {'subtype': 'fully supported'}, '10'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '6'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000509935.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '8'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '0'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '4'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '0'),
#   ('Subcount', {'subtype': 'protein coding'}, '7'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '14'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '9'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '14'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '9'),
#   ('Subcount', {'subtype': 'fully supported'}, '14'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
# ...
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '10'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '12'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '10'),
#   ('Subcount', {'subtype': 'fully supported'}, '12'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '10'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000510145.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '12'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '3'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '3'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '1'),
#   ('Subcount', {'subtype': 'protein coding'}, '7'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '9'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '8'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '9'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '8'),
#   ('Subcount', {'subtype': 'fully supported'}, '9'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '2'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '2'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '2'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '9'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '5'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '9'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '5'),
#   ('Subcount', {'subtype': 'fully supported'}, '9'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '5'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000510155.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '15'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '3'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '5'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '1'),
#   ('Subcount', {'subtype': 'protein coding'}, '10'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '17'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '12'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '17'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '12'),
#   ('Subcount', {'subtype': 'fully supported'}, '17'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '2'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '2'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '2'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '2'),
#   ('Subcount', {'subtype': 'fully supported'}, '2'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '17'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '12'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '17'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '12'),
#   ('Subcount', {'subtype': 'fully supported'}, '17'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '12'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000510165.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '11'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '2'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '4'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '1'),
#   ('Subcount', {'subtype': 'protein coding'}, '7'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '10'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '10'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '10'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '10'),
#   ('Subcount', {'subtype': 'fully supported'}, '10'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '2'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '2'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '2'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '2'),
#   ('Subcount', {'subtype': 'fully supported'}, '2'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '10'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '8'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '10'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '8'),
#   ('Subcount', {'subtype': 'fully supported'}, '10'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '8'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000510175.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '10'),
#   ('Subcount', {'subtype': 'other'}, '0'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '0'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '1'),
#   ('Subcount', {'subtype': 'has variants'}, '4'),
#   ('Subcount', {'subtype': 'partial'}, '1'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '0'),
#   ('Subcount', {'subtype': 'non coding'}, '0'),
#   ('Subcount', {'subtype': 'protein coding'}, '9'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '17'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '10'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '17'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '10'),
#   ('Subcount', {'subtype': 'fully supported'}, '17'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '0'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '0'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '1'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '0'),
#   ('Subcount', {'subtype': 'correction'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'fully supported'}, '1'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '17'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '2'),
#   ('Subcount', {'subtype': 'correction'}, '6'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '0'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '17'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '6'),
#   ('Subcount', {'subtype': 'fully supported'}, '17'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '0'),
#   ('Subcount', {'subtype': 'minor correction'}, '6'),
#   ('Subcount', {'subtype': 'premature stop'}, '0'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '0')],
#  [('AssemblyCounts',
#    {'Accession': 'GCF_000005045.25', 'Type': 'assembly unit'},
#    '\n    '),
#   ('Counts', {'feature_type': 'genes'}, '\n      '),
#   ('Total', {}, '1529'),
#   ('Subcount', {'subtype': 'other'}, '12'),
#   ('Subcount', {'subtype': 'non-transcribed pseudo'}, '431'),
#   ('Subcount', {'subtype': 'transcribed pseudo'}, '80'),
#   ('Subcount', {'subtype': 'has variants'}, '380'),
#   ('Subcount', {'subtype': 'partial'}, '101'),
#   ('Subcount', {'subtype': 'Ig TCR segment'}, '22'),
#   ('Subcount', {'subtype': 'non coding'}, '386'),
#   ('Subcount', {'subtype': 'protein coding'}, '598'),
#   ('Counts', {'feature_type': 'mRNAs'}, '\n      '),
#   ('Total', {}, '1382'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '176'),
#   ('Subcount', {'subtype': 'correction'}, '492'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '37'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1345'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '492'),
#   ('Subcount', {'subtype': 'fully supported'}, '1377'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '3'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Counts', {'feature_type': 'non-coding RNAs'}, '\n      '),
#   ('Total', {}, '758'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '39'),
#   ('Subcount', {'subtype': 'correction'}, '104'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '371'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '359'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '105'),
#   ('Subcount', {'subtype': 'fully supported'}, '730'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'pseudo transcripts'}, '\n      '),
#   ('Total', {}, '90'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '0'),
#   ('Subcount', {'subtype': 'partial'}, '6'),
#   ('Subcount', {'subtype': 'correction'}, '48'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '3'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '87'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '48'),
#   ('Subcount', {'subtype': 'fully supported'}, '90'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '0'),
#   ('Subcount', {'subtype': 'has gaps'}, '0'),
#   ('Counts', {'feature_type': 'CDSs'}, '\n      '),
#   ('Total', {}, '1390'),
#   ('Subcount', {'subtype': 'exon <= 3nt'}, '23'),
#   ('Subcount', {'subtype': 'partial'}, '161'),
#   ('Subcount', {'subtype': 'correction'}, '274'),
#   ('Subcount', {'subtype': 'model RefSeq'}, '37'),
#   ('Subcount', {'subtype': 'known RefSeq'}, '1331'),
#   ('Subcount', {'subtype': 'known RefSeq with correction'}, '252'),
#   ('Subcount', {'subtype': 'fully supported'}, '1377'),
#   ('Subcount', {'subtype': 'ab initio > 5%'}, '4'),
#   ('Subcount', {'subtype': 'model RefSeq with correction'}, '0'),
#   ('Subcount', {'subtype': 'major correction'}, '57'),
#   ('Subcount', {'subtype': 'minor correction'}, '200'),
#   ('Subcount', {'subtype': 'premature stop'}, '36'),
#   ('Subcount', {'subtype': 'has frameshifts'}, '40')]]

# %%
feature_stats_collection = []
for i in root[3]:
    tags = []
    text = []
    attributes = []
    for element in i.iter():
        tags.append(element.tag)
        text.append(element.text)
        attributes.append(element.attrib)
    thing = list(zip(tags,attributes,text))
    feature_stats_collection.append(thing)
print(len(feature_stats_collection))
feature_stats_collection
# Out:
# 40
# [[('OverallStats', {}, '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '113'),
#   ('Mean', {}, '4.181'),
#   ('Median', {}, '2'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '363'),
#   ('Mean', {}, '11.6507'),
#   ('Median', {}, '9'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '159471'),
#   ('Min', {}, '16'),
#   ('Max', {}, '109224'),
#   ('Mean', {}, '3565.83'),
#   ('Median', {}, '2847'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '112443'),
#   ('Min', {}, '75'),
#   ('Max', {}, '107976'),
#   ('Mean', {}, '1986.65'),
#   ('Median', {}, '1461'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '37904'),
#   ('Min', {}, '33'),
#   ('Max', {}, '2473592'),
#   ('Mean', {}, '45183.9'),
#   ('Median', {}, '14182'),
#   ('LengthStats', {'category': 'RNase_MRP_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '277'),
#   ('Max', {}, '277'),
#   ('Mean', {}, '277'),
#   ('Median', {}, '277'),
#   ('LengthStats', {'category': 'RNase_P_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '341'),
#   ('Max', {}, '341'),
#   ('Mean', {}, '341'),
#   ('Median', {}, '341'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '1800'),
#   ('Min', {}, '180'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2035.75'),
#   ('Median', {}, '1432'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '1403'),
#   ('Min', {}, '180'),
#   ('Max', {}, '12344'),
#   ('Mean', {}, '1839.05'),
#   ('Median', {}, '1198'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '397'),
#   ('Min', {}, '200'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2730.89'),
#   ('Median', {}, '2064'),
#   ('LengthStats', {'category': 'Y_RNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '84'),
#   ('Max', {}, '113'),
#   ('Mean', {}, '98.75'),
#   ('Median', {}, '102'),
#   ('LengthStats', {'category': 'antisense_RNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '255'),
#   ('Max', {}, '37027'),
#   ('Mean', {}, '4169.59'),
#   ('Median', {}, '1662'),
#   ('LengthStats', {'category': 'guide_RNA'}, '\n      '),
#   ('Count', {}, '29'),
#   ('Min', {}, '125'),
#   ('Max', {}, '421'),
#   ('Mean', {}, '206.793'),
#   ('Median', {}, '148'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '27344'),
#   ('Min', {}, '99'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2029.63'),
#   ('Median', {}, '1376'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '112430'),
#   ('Min', {}, '153'),
#   ('Max', {}, '109224'),
#   ('Mean', {}, '4072.68'),
#   ('Median', {}, '3313'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '3173'),
#   ('Min', {}, '16'),
#   ('Max', {}, '28'),
#   ('Mean', {}, '21.6306'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '15218'),
#   ('Min', {}, '158'),
#   ('Max', {}, '25390'),
#   ('Mean', {}, '3605.73'),
#   ('Median', {}, '2981'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '1913'),
#   ('Min', {}, '41'),
#   ('Max', {}, '180'),
#   ('Mean', {}, '81.9226'),
#   ('Median', {}, '80'),
#   ('LengthStats', {'category': 'rRNA'}, '\n      '),
#   ('Count', {}, '39'),
#   ('Min', {}, '121'),
#   ('Max', {}, '13373'),
#   ('Mean', {}, '2736.56'),
#   ('Median', {}, '157'),
#   ('LengthStats', {'category': 'scRNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '58'),
#   ('Max', {}, '299'),
#   ('Mean', {}, '238.75'),
#   ('Median', {}, '299'),
#   ('LengthStats', {'category': 'snRNA'}, '\n      '),
#   ('Count', {}, '63'),
#   ('Min', {}, '63'),
#   ('Max', {}, '332'),
#   ('Mean', {}, '134.921'),
#   ('Median', {}, '121'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '541'),
#   ('Min', {}, '33'),
#   ('Max', {}, '250'),
#   ('Mean', {}, '105.649'),
#   ('Median', {}, '94'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '597'),
#   ('Min', {}, '59'),
#   ('Max', {}, '84'),
#   ('Mean', {}, '73.7672'),
#   ('Median', {}, '73'),
#   ('LengthStats', {'category': 'telomerase_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '451'),
#   ('Max', {}, '451'),
#   ('Mean', {}, '451'),
#   ('Median', {}, '451'),
#   ('LengthStats', {'category': 'vault_RNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '88'),
#   ('Max', {}, '108'),
#   ('Mean', {}, '95.5'),
#   ('Median', {}, '98')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001405.39', 'Type': 'full assembly'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '113'),
#   ('Mean', {}, '4.181'),
#   ('Median', {}, '2'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '363'),
#   ('Mean', {}, '11.6507'),
#   ('Median', {}, '9'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '411273'),
#   ('Min', {}, '1'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '441.791'),
#   ('Median', {}, '149'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '352207'),
#   ('Min', {}, '26'),
#   ('Max', {}, '1160411'),
#   ('Mean', {}, '8185.69'),
#   ('Median', {}, '1873'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '159471'),
#   ('Min', {}, '16'),
#   ('Max', {}, '109224'),
#   ('Mean', {}, '3565.83'),
#   ('Median', {}, '2847'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '112443'),
#   ('Min', {}, '75'),
#   ('Max', {}, '107976'),
#   ('Mean', {}, '1986.65'),
#   ('Median', {}, '1461'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '327126'),
#   ('Min', {}, '1'),
#   ('Max', {}, '33290'),
#   ('Mean', {}, '413.104'),
#   ('Median', {}, '143'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '156519'),
#   ('Min', {}, '2'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '417.327'),
#   ('Median', {}, '147'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '37904'),
#   ('Min', {}, '33'),
#   ('Max', {}, '2473592'),
#   ('Mean', {}, '45183.9'),
#   ('Median', {}, '14182'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '288015'),
#   ('Min', {}, '26'),
#   ('Max', {}, '1160411'),
#   ('Mean', {}, '7752.87'),
#   ('Median', {}, '1759'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '132792'),
#   ('Min', {}, '28'),
#   ('Max', {}, '773192'),
#   ('Mean', {}, '7841.45'),
#   ('Median', {}, '1965'),
#   ('LengthStats', {'category': 'RNase_MRP_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '277'),
#   ('Max', {}, '277'),
#   ('Mean', {}, '277'),
#   ('Median', {}, '277'),
#   ('LengthStats', {'category': 'RNase_P_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '341'),
#   ('Max', {}, '341'),
#   ('Mean', {}, '341'),
#   ('Median', {}, '341'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '1800'),
#   ('Min', {}, '180'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2035.75'),
#   ('Median', {}, '1432'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '1403'),
#   ('Min', {}, '180'),
#   ('Max', {}, '12344'),
#   ('Mean', {}, '1839.05'),
#   ('Median', {}, '1198'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '397'),
#   ('Min', {}, '200'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2730.89'),
#   ('Median', {}, '2064'),
#   ('LengthStats', {'category': 'Y_RNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '84'),
#   ('Max', {}, '113'),
#   ('Mean', {}, '98.75'),
#   ('Median', {}, '102'),
#   ('LengthStats', {'category': 'antisense_RNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '255'),
#   ('Max', {}, '37027'),
#   ('Mean', {}, '4169.59'),
#   ('Median', {}, '1662'),
#   ('LengthStats', {'category': 'guide_RNA'}, '\n      '),
#   ('Count', {}, '29'),
#   ('Min', {}, '125'),
#   ('Max', {}, '421'),
#   ('Mean', {}, '206.793'),
#   ('Median', {}, '148'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '27344'),
#   ('Min', {}, '99'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2029.63'),
#   ('Median', {}, '1376'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '112430'),
#   ('Min', {}, '153'),
#   ('Max', {}, '109224'),
#   ('Mean', {}, '4072.68'),
#   ('Median', {}, '3313'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '3173'),
#   ('Min', {}, '16'),
#   ('Max', {}, '28'),
#   ('Mean', {}, '21.6306'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '15218'),
#   ('Min', {}, '158'),
#   ('Max', {}, '25390'),
#   ('Mean', {}, '3605.73'),
#   ('Median', {}, '2981'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '1913'),
#   ('Min', {}, '41'),
#   ('Max', {}, '180'),
#   ('Mean', {}, '81.9226'),
#   ('Median', {}, '80'),
#   ('LengthStats', {'category': 'rRNA'}, '\n      '),
#   ('Count', {}, '39'),
#   ('Min', {}, '121'),
#   ('Max', {}, '13373'),
#   ('Mean', {}, '2736.56'),
#   ('Median', {}, '157'),
#   ('LengthStats', {'category': 'scRNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '58'),
#   ('Max', {}, '299'),
#   ('Mean', {}, '238.75'),
#   ('Median', {}, '299'),
#   ('LengthStats', {'category': 'snRNA'}, '\n      '),
#   ('Count', {}, '63'),
#   ('Min', {}, '63'),
#   ('Max', {}, '332'),
#   ('Mean', {}, '134.921'),
#   ('Median', {}, '121'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '541'),
#   ('Min', {}, '33'),
#   ('Max', {}, '250'),
#   ('Mean', {}, '105.649'),
#   ('Median', {}, '94'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '597'),
#   ('Min', {}, '59'),
#   ('Max', {}, '84'),
#   ('Mean', {}, '73.7672'),
#   ('Median', {}, '73'),
#   ('LengthStats', {'category': 'telomerase_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '451'),
#   ('Max', {}, '451'),
#   ('Mean', {}, '451'),
#   ('Median', {}, '451'),
#   ('LengthStats', {'category': 'vault_RNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '88'),
#   ('Max', {}, '108'),
#   ('Mean', {}, '95.5'),
#   ('Median', {}, '98')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001305.15', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '113'),
#   ('Mean', {}, '4.18929'),
#   ('Median', {}, '2'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '363'),
#   ('Mean', {}, '11.7428'),
#   ('Median', {}, '9'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '378131'),
#   ('Min', {}, '1'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '451.678'),
#   ('Median', {}, '149'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '323298'),
#   ('Min', {}, '26'),
#   ('Max', {}, '1160411'),
#   ('Mean', {}, '8626.91'),
#   ('Median', {}, '2004'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '157336'),
#   ('Min', {}, '16'),
#   ('Max', {}, '109224'),
#   ('Mean', {}, '3594.62'),
#   ('Median', {}, '2873'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '112169'),
#   ('Min', {}, '75'),
#   ('Max', {}, '107976'),
#   ('Mean', {}, '1988.61'),
#   ('Median', {}, '1461'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '299699'),
#   ('Min', {}, '1'),
#   ('Max', {}, '33290'),
#   ('Mean', {}, '424.016'),
#   ('Median', {}, '144'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '147954'),
#   ('Min', {}, '2'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '418.11'),
#   ('Median', {}, '146'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '37660'),
#   ('Min', {}, '33'),
#   ('Max', {}, '2473592'),
#   ('Mean', {}, '45795.7'),
#   ('Median', {}, '14350'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '263421'),
#   ('Min', {}, '26'),
#   ('Max', {}, '1160411'),
#   ('Mean', {}, '8220.54'),
#   ('Median', {}, '1904'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '125972'),
#   ('Min', {}, '28'),
#   ('Max', {}, '773192'),
#   ('Mean', {}, '8006.62'),
#   ('Median', {}, '2015'),
#   ('LengthStats', {'category': 'RNase_MRP_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '277'),
#   ('Max', {}, '277'),
#   ('Mean', {}, '277'),
#   ('Median', {}, '277'),
#   ('LengthStats', {'category': 'RNase_P_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '341'),
#   ('Max', {}, '341'),
#   ('Mean', {}, '341'),
#   ('Median', {}, '341'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '1769'),
#   ('Min', {}, '180'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2041.42'),
#   ('Median', {}, '1434'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '1376'),
#   ('Min', {}, '180'),
#   ('Max', {}, '12344'),
#   ('Mean', {}, '1844.77'),
#   ('Median', {}, '1201'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '393'),
#   ('Min', {}, '200'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2729.97'),
#   ('Median', {}, '2064'),
#   ('LengthStats', {'category': 'Y_RNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '84'),
#   ('Max', {}, '113'),
#   ('Mean', {}, '98.75'),
#   ('Median', {}, '102'),
#   ('LengthStats', {'category': 'antisense_RNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '255'),
#   ('Max', {}, '37027'),
#   ('Mean', {}, '4169.59'),
#   ('Median', {}, '1662'),
#   ('LengthStats', {'category': 'guide_RNA'}, '\n      '),
#   ('Count', {}, '29'),
#   ('Min', {}, '125'),
#   ('Max', {}, '421'),
#   ('Mean', {}, '206.793'),
#   ('Median', {}, '148'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '26085'),
#   ('Min', {}, '99'),
#   ('Max', {}, '91671'),
#   ('Mean', {}, '2044.77'),
#   ('Median', {}, '1388'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '112169'),
#   ('Min', {}, '153'),
#   ('Max', {}, '109224'),
#   ('Mean', {}, '4077.3'),
#   ('Median', {}, '3319'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '2875'),
#   ('Min', {}, '16'),
#   ('Max', {}, '28'),
#   ('Mean', {}, '21.6303'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '15084'),
#   ('Min', {}, '158'),
#   ('Max', {}, '25390'),
#   ('Mean', {}, '3614.11'),
#   ('Median', {}, '2987'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '1913'),
#   ('Min', {}, '41'),
#   ('Max', {}, '180'),
#   ('Mean', {}, '81.9226'),
#   ('Median', {}, '80'),
#   ('LengthStats', {'category': 'rRNA'}, '\n      '),
#   ('Count', {}, '37'),
#   ('Min', {}, '121'),
#   ('Max', {}, '13373'),
#   ('Mean', {}, '2816.57'),
#   ('Median', {}, '157'),
#   ('LengthStats', {'category': 'scRNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '58'),
#   ('Max', {}, '299'),
#   ('Mean', {}, '238.75'),
#   ('Median', {}, '299'),
#   ('LengthStats', {'category': 'snRNA'}, '\n      '),
#   ('Count', {}, '63'),
#   ('Min', {}, '63'),
#   ('Max', {}, '332'),
#   ('Mean', {}, '134.921'),
#   ('Median', {}, '121'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '541'),
#   ('Min', {}, '33'),
#   ('Max', {}, '250'),
#   ('Mean', {}, '105.649'),
#   ('Median', {}, '94'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '416'),
#   ('Min', {}, '71'),
#   ('Max', {}, '84'),
#   ('Mean', {}, '73.9423'),
#   ('Median', {}, '73'),
#   ('LengthStats', {'category': 'telomerase_RNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '451'),
#   ('Max', {}, '451'),
#   ('Mean', {}, '451'),
#   ('Median', {}, '451'),
#   ('LengthStats', {'category': 'vault_RNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '88'),
#   ('Max', {}, '108'),
#   ('Mean', {}, '95.5'),
#   ('Median', {}, '98')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001405.39', 'Type': 'grouped alt loci'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '36'),
#   ('Mean', {}, '2.14198'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '66'),
#   ('Mean', {}, '7.05033'),
#   ('Median', {}, '5'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '24956'),
#   ('Min', {}, '2'),
#   ('Max', {}, '18726'),
#   ('Mean', {}, '316.512'),
#   ('Median', {}, '143'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '21748'),
#   ('Min', {}, '30'),
#   ('Max', {}, '232263'),
#   ('Mean', {}, '2901.07'),
#   ('Median', {}, '742'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '3737'),
#   ('Min', {}, '17'),
#   ('Max', {}, '22824'),
#   ('Mean', {}, '2135.54'),
#   ('Median', {}, '1649'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '1917'),
#   ('Min', {}, '75'),
#   ('Max', {}, '22257'),
#   ('Mean', {}, '1561.41'),
#   ('Median', {}, '1182'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '20697'),
#   ('Min', {}, '6'),
#   ('Max', {}, '18726'),
#   ('Mean', {}, '278.942'),
#   ('Median', {}, '135'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '6523'),
#   ('Min', {}, '2'),
#   ('Max', {}, '9896'),
#   ('Mean', {}, '396.419'),
#   ('Median', {}, '162'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '1517'),
#   ('Min', {}, '43'),
#   ('Max', {}, '1296601'),
#   ('Mean', {}, '22661.2'),
#   ('Median', {}, '7270'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '18560'),
#   ('Min', {}, '33'),
#   ('Max', {}, '197352'),
#   ('Mean', {}, '2376.67'),
#   ('Median', {}, '647'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '5178'),
#   ('Min', {}, '30'),
#   ('Max', {}, '232263'),
#   ('Mean', {}, '4504.26'),
#   ('Median', {}, '983'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '159'),
#   ('Min', {}, '252'),
#   ('Max', {}, '8155'),
#   ('Mean', {}, '1895.09'),
#   ('Median', {}, '1100'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '127'),
#   ('Min', {}, '445'),
#   ('Max', {}, '7528'),
#   ('Mean', {}, '1752.8'),
#   ('Median', {}, '1041'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '32'),
#   ('Min', {}, '252'),
#   ('Max', {}, '8155'),
#   ('Mean', {}, '2459.81'),
#   ('Median', {}, '2175'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '1204'),
#   ('Min', {}, '99'),
#   ('Max', {}, '11661'),
#   ('Mean', {}, '1654.36'),
#   ('Median', {}, '1162'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '1917'),
#   ('Min', {}, '264'),
#   ('Max', {}, '22824'),
#   ('Mean', {}, '2828.26'),
#   ('Median', {}, '2252'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '215'),
#   ('Min', {}, '17'),
#   ('Max', {}, '25'),
#   ('Mean', {}, '21.6326'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '232'),
#   ('Min', {}, '207'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '2368.12'),
#   ('Median', {}, '2216'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '71'),
#   ('Min', {}, '43'),
#   ('Max', {}, '153'),
#   ('Mean', {}, '80.7324'),
#   ('Median', {}, '77'),
#   ('LengthStats', {'category': 'snRNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '165'),
#   ('Max', {}, '165'),
#   ('Mean', {}, '165'),
#   ('Median', {}, '165'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '11'),
#   ('Min', {}, '63'),
#   ('Max', {}, '175'),
#   ('Mean', {}, '96.9091'),
#   ('Median', {}, '78'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '157'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '73.9299'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001315.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '21'),
#   ('Mean', {}, '2.13567'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '60'),
#   ('Mean', {}, '7.20447'),
#   ('Median', {}, '5'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '8112'),
#   ('Min', {}, '2'),
#   ('Max', {}, '18726'),
#   ('Mean', {}, '360.229'),
#   ('Median', {}, '146'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '6903'),
#   ('Min', {}, '36'),
#   ('Max', {}, '232263'),
#   ('Mean', {}, '4463.71'),
#   ('Median', {}, '1276'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '2543'),
#   ('Min', {}, '17'),
#   ('Max', {}, '22824'),
#   ('Mean', {}, '2349.12'),
#   ('Median', {}, '1890'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '1505'),
#   ('Min', {}, '75'),
#   ('Max', {}, '22257'),
#   ('Mean', {}, '1550.77'),
#   ('Median', {}, '1233'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '6114'),
#   ('Min', {}, '6'),
#   ('Max', {}, '18726'),
#   ('Mean', {}, '308.109'),
#   ('Median', {}, '137'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '2695'),
#   ('Min', {}, '2'),
#   ('Max', {}, '9896'),
#   ('Mean', {}, '441.574'),
#   ('Median', {}, '171'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '1195'),
#   ('Min', {}, '43'),
#   ('Max', {}, '1296601'),
#   ('Mean', {}, '23813.6'),
#   ('Median', {}, '7853'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '5448'),
#   ('Min', {}, '36'),
#   ('Max', {}, '176607'),
#   ('Mean', {}, '4070.42'),
#   ('Median', {}, '1211'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '2067'),
#   ('Min', {}, '54'),
#   ('Max', {}, '232263'),
#   ('Mean', {}, '5248.83'),
#   ('Median', {}, '1413'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '143'),
#   ('Min', {}, '252'),
#   ('Max', {}, '8155'),
#   ('Mean', {}, '1922.1'),
#   ('Median', {}, '1096'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '113'),
#   ('Min', {}, '445'),
#   ('Max', {}, '7528'),
#   ('Mean', {}, '1757.2'),
#   ('Median', {}, '1039'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '30'),
#   ('Min', {}, '252'),
#   ('Max', {}, '8155'),
#   ('Mean', {}, '2543.2'),
#   ('Median', {}, '2435'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '763'),
#   ('Min', {}, '128'),
#   ('Max', {}, '11661'),
#   ('Mean', {}, '1726.92'),
#   ('Median', {}, '1230'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '1505'),
#   ('Min', {}, '264'),
#   ('Max', {}, '22824'),
#   ('Mean', {}, '2853.48'),
#   ('Median', {}, '2304'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '80'),
#   ('Min', {}, '17'),
#   ('Max', {}, '25'),
#   ('Mean', {}, '21.7375'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '167'),
#   ('Min', {}, '207'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '2141.28'),
#   ('Median', {}, '2006'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '59'),
#   ('Min', {}, '43'),
#   ('Max', {}, '153'),
#   ('Mean', {}, '79.4407'),
#   ('Median', {}, '77'),
#   ('LengthStats', {'category': 'snRNA'}, '\n      '),
#   ('Count', {}, '1'),
#   ('Min', {}, '165'),
#   ('Max', {}, '165'),
#   ('Mean', {}, '165'),
#   ('Median', {}, '165'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '9'),
#   ('Min', {}, '63'),
#   ('Max', {}, '175'),
#   ('Mean', {}, '95.1111'),
#   ('Median', {}, '77'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '18'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '73.7222'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001325.3', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '36'),
#   ('Mean', {}, '2.10694'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '66'),
#   ('Mean', {}, '7.41941'),
#   ('Median', {}, '5'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '3876'),
#   ('Min', {}, '6'),
#   ('Max', {}, '14433'),
#   ('Mean', {}, '355.506'),
#   ('Median', {}, '142'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '3336'),
#   ('Min', {}, '33'),
#   ('Max', {}, '197352'),
#   ('Mean', {}, '3610.37'),
#   ('Median', {}, '656'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '1170'),
#   ('Min', {}, '18'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2275.08'),
#   ('Median', {}, '1870'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '700'),
#   ('Min', {}, '180'),
#   ('Max', {}, '16239'),
#   ('Mean', {}, '1541.12'),
#   ('Median', {}, '1044'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '3119'),
#   ('Min', {}, '6'),
#   ('Max', {}, '14433'),
#   ('Mean', {}, '305.422'),
#   ('Median', {}, '134'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '1087'),
#   ('Min', {}, '12'),
#   ('Max', {}, '7568'),
#   ('Mean', {}, '456.215'),
#   ('Median', {}, '165'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '571'),
#   ('Min', {}, '61'),
#   ('Max', {}, '460024'),
#   ('Mean', {}, '19216.8'),
#   ('Median', {}, '5361'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '2766'),
#   ('Min', {}, '33'),
#   ('Max', {}, '197352'),
#   ('Mean', {}, '2895.93'),
#   ('Median', {}, '565'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '862'),
#   ('Min', {}, '71'),
#   ('Max', {}, '124245'),
#   ('Mean', {}, '5756.43'),
#   ('Median', {}, '1182'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '65'),
#   ('Min', {}, '445'),
#   ('Max', {}, '4834'),
#   ('Mean', {}, '1556.38'),
#   ('Median', {}, '1075'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '56'),
#   ('Min', {}, '445'),
#   ('Max', {}, '4834'),
#   ('Mean', {}, '1451.48'),
#   ('Median', {}, '1048'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '9'),
#   ('Min', {}, '770'),
#   ('Max', {}, '4805'),
#   ('Mean', {}, '2209.11'),
#   ('Median', {}, '2083'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '312'),
#   ('Min', {}, '99'),
#   ('Max', {}, '9818'),
#   ('Mean', {}, '1756.58'),
#   ('Median', {}, '1219'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '700'),
#   ('Min', {}, '331'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2663.46'),
#   ('Median', {}, '2131'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '30'),
#   ('Min', {}, '18'),
#   ('Max', {}, '23'),
#   ('Mean', {}, '21.4667'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '86'),
#   ('Min', {}, '310'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '2855.48'),
#   ('Median', {}, '2746'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '19'),
#   ('Min', {}, '61'),
#   ('Max', {}, '110'),
#   ('Mean', {}, '83.7895'),
#   ('Median', {}, '86'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '6'),
#   ('Min', {}, '63'),
#   ('Max', {}, '132'),
#   ('Mean', {}, '81.6667'),
#   ('Median', {}, '77'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '36'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '73.9444'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001335.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '13'),
#   ('Mean', {}, '2.08392'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '66'),
#   ('Mean', {}, '8.05705'),
#   ('Median', {}, '5'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '2281'),
#   ('Min', {}, '6'),
#   ('Max', {}, '8265'),
#   ('Mean', {}, '301.163'),
#   ('Median', {}, '143'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '2003'),
#   ('Min', {}, '48'),
#   ('Max', {}, '110063'),
#   ('Mean', {}, '1855.19'),
#   ('Median', {}, '433'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '619'),
#   ('Min', {}, '20'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2027.55'),
#   ('Median', {}, '1675'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '410'),
#   ('Min', {}, '180'),
#   ('Max', {}, '16239'),
#   ('Mean', {}, '1595.51'),
#   ('Median', {}, '1071'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '1961'),
#   ('Min', {}, '6'),
#   ('Max', {}, '8265'),
#   ('Mean', {}, '273.348'),
#   ('Median', {}, '138'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '519'),
#   ('Min', {}, '11'),
#   ('Max', {}, '7568'),
#   ('Mean', {}, '366.651'),
#   ('Median', {}, '154'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '300'),
#   ('Min', {}, '63'),
#   ('Max', {}, '152246'),
#   ('Mean', {}, '11334.9'),
#   ('Median', {}, '5586'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '1751'),
#   ('Min', {}, '48'),
#   ('Max', {}, '35672'),
#   ('Mean', {}, '1161.36'),
#   ('Median', {}, '366'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '424'),
#   ('Min', {}, '71'),
#   ('Max', {}, '110063'),
#   ('Mean', {}, '4483.21'),
#   ('Median', {}, '964'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '24'),
#   ('Min', {}, '963'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1634.71'),
#   ('Median', {}, '1348'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '18'),
#   ('Min', {}, '963'),
#   ('Max', {}, '2517'),
#   ('Mean', {}, '1531.33'),
#   ('Median', {}, '1260'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '6'),
#   ('Min', {}, '1180'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1944.83'),
#   ('Median', {}, '2083'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '139'),
#   ('Min', {}, '149'),
#   ('Max', {}, '8477'),
#   ('Mean', {}, '1434.51'),
#   ('Median', {}, '893'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '410'),
#   ('Min', {}, '402'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2428.95'),
#   ('Median', {}, '2059'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '20'),
#   ('Min', {}, '20'),
#   ('Max', {}, '23'),
#   ('Mean', {}, '21.65'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '30'),
#   ('Min', {}, '505'),
#   ('Max', {}, '4543'),
#   ('Mean', {}, '1928.1'),
#   ('Median', {}, '1801'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '11'),
#   ('Min', {}, '63'),
#   ('Max', {}, '110'),
#   ('Mean', {}, '81.8182'),
#   ('Median', {}, '81'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '6'),
#   ('Min', {}, '63'),
#   ('Max', {}, '132'),
#   ('Mean', {}, '81.6667'),
#   ('Median', {}, '77'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '14'),
#   ('Min', {}, '72'),
#   ('Max', {}, '82'),
#   ('Mean', {}, '73.0714'),
#   ('Median', {}, '72')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001345.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '13'),
#   ('Mean', {}, '2.26432'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '66'),
#   ('Mean', {}, '7.55642'),
#   ('Median', {}, '5'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '1708'),
#   ('Min', {}, '6'),
#   ('Max', {}, '12739'),
#   ('Mean', {}, '306.721'),
#   ('Median', {}, '149'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '1492'),
#   ('Min', {}, '68'),
#   ('Max', {}, '110356'),
#   ('Mean', {}, '1996.42'),
#   ('Median', {}, '535'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '542'),
#   ('Min', {}, '19'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '1938.63'),
#   ('Median', {}, '1603'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '366'),
#   ('Min', {}, '180'),
#   ('Max', {}, '16239'),
#   ('Mean', {}, '1458.86'),
#   ('Median', {}, '1002'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '1463'),
#   ('Min', {}, '6'),
#   ('Max', {}, '12739'),
#   ('Mean', {}, '279.636'),
#   ('Median', {}, '142'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '432'),
#   ('Min', {}, '23'),
#   ('Max', {}, '7568'),
#   ('Mean', {}, '343.002'),
#   ('Median', {}, '153'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '247'),
#   ('Min', {}, '61'),
#   ('Max', {}, '152594'),
#   ('Mean', {}, '10004.8'),
#   ('Median', {}, '5355'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '1293'),
#   ('Min', {}, '68'),
#   ('Max', {}, '53017'),
#   ('Mean', {}, '1237.51'),
#   ('Median', {}, '453'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '361'),
#   ('Min', {}, '71'),
#   ('Max', {}, '110356'),
#   ('Mean', {}, '4303.32'),
#   ('Median', {}, '861'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '20'),
#   ('Min', {}, '770'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1417.75'),
#   ('Median', {}, '1136'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '15'),
#   ('Min', {}, '963'),
#   ('Max', {}, '2481'),
#   ('Mean', {}, '1310.47'),
#   ('Median', {}, '1075'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '5'),
#   ('Min', {}, '770'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1739.6'),
#   ('Median', {}, '1889'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '108'),
#   ('Min', {}, '99'),
#   ('Max', {}, '8477'),
#   ('Mean', {}, '1469.68'),
#   ('Median', {}, '955'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '366'),
#   ('Min', {}, '402'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2290.78'),
#   ('Median', {}, '1970'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '18'),
#   ('Min', {}, '19'),
#   ('Max', {}, '23'),
#   ('Mean', {}, '21.5'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '26'),
#   ('Min', {}, '505'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '1975.19'),
#   ('Median', {}, '1571'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '10'),
#   ('Min', {}, '61'),
#   ('Max', {}, '110'),
#   ('Mean', {}, '82.7'),
#   ('Median', {}, '87'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '76'),
#   ('Max', {}, '132'),
#   ('Mean', {}, '90.75'),
#   ('Median', {}, '78'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '20'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '73.95'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001355.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '13'),
#   ('Mean', {}, '2.17004'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '66'),
#   ('Mean', {}, '8.30224'),
#   ('Median', {}, '6'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '2015'),
#   ('Min', {}, '11'),
#   ('Max', {}, '7195'),
#   ('Mean', {}, '277.085'),
#   ('Median', {}, '141'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '1759'),
#   ('Min', {}, '30'),
#   ('Max', {}, '39615'),
#   ('Mean', {}, '1315.9'),
#   ('Median', {}, '398'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '566'),
#   ('Min', {}, '20'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '1938.92'),
#   ('Median', {}, '1632'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '402'),
#   ('Min', {}, '180'),
#   ('Max', {}, '16239'),
#   ('Mean', {}, '1513.62'),
#   ('Median', {}, '1044'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '1800'),
#   ('Min', {}, '12'),
#   ('Max', {}, '7195'),
#   ('Mean', {}, '261.909'),
#   ('Median', {}, '138'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '432'),
#   ('Min', {}, '11'),
#   ('Max', {}, '3210'),
#   ('Mean', {}, '295.051'),
#   ('Median', {}, '143'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '267'),
#   ('Min', {}, '61'),
#   ('Max', {}, '152244'),
#   ('Mean', {}, '9200.34'),
#   ('Median', {}, '5056'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '1605'),
#   ('Min', {}, '48'),
#   ('Max', {}, '36388'),
#   ('Mean', {}, '1140.18'),
#   ('Median', {}, '352'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '347'),
#   ('Min', {}, '30'),
#   ('Max', {}, '39615'),
#   ('Mean', {}, '2001.61'),
#   ('Median', {}, '594'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '24'),
#   ('Min', {}, '407'),
#   ('Max', {}, '2547'),
#   ('Mean', {}, '1351'),
#   ('Median', {}, '1136'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '16'),
#   ('Min', {}, '963'),
#   ('Max', {}, '2481'),
#   ('Mean', {}, '1335'),
#   ('Median', {}, '1106'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '8'),
#   ('Min', {}, '407'),
#   ('Max', {}, '2547'),
#   ('Mean', {}, '1383'),
#   ('Median', {}, '1332'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '89'),
#   ('Min', {}, '333'),
#   ('Max', {}, '4070'),
#   ('Mean', {}, '1238.73'),
#   ('Median', {}, '940'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '402'),
#   ('Min', {}, '402'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2303.87'),
#   ('Median', {}, '2005'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '20'),
#   ('Max', {}, '23'),
#   ('Mean', {}, '21.6818'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '29'),
#   ('Min', {}, '505'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '2024.31'),
#   ('Median', {}, '1603'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '12'),
#   ('Min', {}, '61'),
#   ('Max', {}, '110'),
#   ('Mean', {}, '81.6667'),
#   ('Median', {}, '86'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '76'),
#   ('Max', {}, '132'),
#   ('Mean', {}, '90.75'),
#   ('Median', {}, '78'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '20'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '74.1'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001365.3', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '13'),
#   ('Mean', {}, '2.19923'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '66'),
#   ('Mean', {}, '8.15505'),
#   ('Median', {}, '6'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '2083'),
#   ('Min', {}, '6'),
#   ('Max', {}, '12739'),
#   ('Mean', {}, '293.904'),
#   ('Median', {}, '144'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '1832'),
#   ('Min', {}, '45'),
#   ('Max', {}, '110042'),
#   ('Mean', {}, '1644.74'),
#   ('Median', {}, '437'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '606'),
#   ('Min', {}, '20'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '1950.13'),
#   ('Median', {}, '1621'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '408'),
#   ('Min', {}, '180'),
#   ('Max', {}, '16239'),
#   ('Mean', {}, '1524.63'),
#   ('Median', {}, '1071'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '1817'),
#   ('Min', {}, '6'),
#   ('Max', {}, '12739'),
#   ('Mean', {}, '266.216'),
#   ('Median', {}, '138'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '476'),
#   ('Min', {}, '23'),
#   ('Max', {}, '7568'),
#   ('Mean', {}, '347.704'),
#   ('Median', {}, '154'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '283'),
#   ('Min', {}, '61'),
#   ('Max', {}, '152236'),
#   ('Mean', {}, '9397.71'),
#   ('Median', {}, '5464'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '1624'),
#   ('Min', {}, '68'),
#   ('Max', {}, '35669'),
#   ('Mean', {}, '1151.79'),
#   ('Median', {}, '382'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '394'),
#   ('Min', {}, '45'),
#   ('Max', {}, '110042'),
#   ('Mean', {}, '3451.84'),
#   ('Median', {}, '791'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '20'),
#   ('Min', {}, '770'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1561.95'),
#   ('Median', {}, '1332'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '14'),
#   ('Min', {}, '963'),
#   ('Max', {}, '2517'),
#   ('Mean', {}, '1525.79'),
#   ('Median', {}, '1260'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '6'),
#   ('Min', {}, '770'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1646.33'),
#   ('Median', {}, '1889'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '118'),
#   ('Min', {}, '149'),
#   ('Max', {}, '8477'),
#   ('Mean', {}, '1466.86'),
#   ('Median', {}, '940'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '408'),
#   ('Min', {}, '402'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2322.43'),
#   ('Median', {}, '2028'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '20'),
#   ('Max', {}, '23'),
#   ('Mean', {}, '21.6818'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '30'),
#   ('Min', {}, '505'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '1951.17'),
#   ('Median', {}, '1603'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '12'),
#   ('Min', {}, '61'),
#   ('Max', {}, '110'),
#   ('Mean', {}, '81.6667'),
#   ('Median', {}, '86'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '6'),
#   ('Min', {}, '63'),
#   ('Max', {}, '132'),
#   ('Mean', {}, '81.6667'),
#   ('Median', {}, '77'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '74.3182'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000001375.2', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '13'),
#   ('Mean', {}, '2.24715'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '65'),
#   ('Mean', {}, '8.01861'),
#   ('Median', {}, '6'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '2142'),
#   ('Min', {}, '6'),
#   ('Max', {}, '12739'),
#   ('Mean', {}, '286.005'),
#   ('Median', {}, '145'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '1890'),
#   ('Min', {}, '30'),
#   ('Max', {}, '110010'),
#   ('Mean', {}, '1795.23'),
#   ('Median', {}, '425'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '626'),
#   ('Min', {}, '19'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '1974.92'),
#   ('Median', {}, '1678'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '420'),
#   ('Min', {}, '180'),
#   ('Max', {}, '16239'),
#   ('Mean', {}, '1455.1'),
#   ('Median', {}, '1038'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '1852'),
#   ('Min', {}, '6'),
#   ('Max', {}, '12739'),
#   ('Mean', {}, '257.789'),
#   ('Median', {}, '138'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '564'),
#   ('Min', {}, '13'),
#   ('Max', {}, '7568'),
#   ('Mean', {}, '328.339'),
#   ('Median', {}, '154'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '290'),
#   ('Min', {}, '61'),
#   ('Max', {}, '152236'),
#   ('Mean', {}, '10236'),
#   ('Median', {}, '5628'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '1668'),
#   ('Min', {}, '68'),
#   ('Max', {}, '52905'),
#   ('Mean', {}, '1189.78'),
#   ('Median', {}, '365'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '466'),
#   ('Min', {}, '30'),
#   ('Max', {}, '110010'),
#   ('Mean', {}, '3478.97'),
#   ('Median', {}, '568'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '23'),
#   ('Min', {}, '590'),
#   ('Max', {}, '4525'),
#   ('Mean', {}, '1549.43'),
#   ('Median', {}, '1180'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '17'),
#   ('Min', {}, '590'),
#   ('Max', {}, '4525'),
#   ('Mean', {}, '1515.24'),
#   ('Median', {}, '1106'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '6'),
#   ('Min', {}, '770'),
#   ('Max', {}, '2624'),
#   ('Mean', {}, '1646.33'),
#   ('Median', {}, '1889'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '121'),
#   ('Min', {}, '99'),
#   ('Max', {}, '8477'),
#   ('Mean', {}, '1400.26'),
#   ('Median', {}, '940'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '420'),
#   ('Min', {}, '402'),
#   ('Max', {}, '16756'),
#   ('Mean', {}, '2337.2'),
#   ('Median', {}, '2042'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '19'),
#   ('Min', {}, '19'),
#   ('Max', {}, '23'),
#   ('Mean', {}, '21.4737'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '36'),
#   ('Min', {}, '505'),
#   ('Max', {}, '6314'),
#   ('Mean', {}, '2293.11'),
#   ('Median', {}, '1960'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '11'),
#   ('Min', {}, '61'),
#   ('Max', {}, '107'),
#   ('Mean', {}, '82.8182'),
#   ('Median', {}, '86'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '3'),
#   ('Min', {}, '76'),
#   ('Max', {}, '132'),
#   ('Mean', {}, '95.3333'),
#   ('Median', {}, '78'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '27'),
#   ('Min', {}, '72'),
#   ('Max', {}, '83'),
#   ('Mean', {}, '74.037'),
#   ('Median', {}, '73')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000510225.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '8'),
#   ('Mean', {}, '2.89744'),
#   ('Median', {}, '2'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '18'),
#   ('Mean', {}, '7.90265'),
#   ('Median', {}, '7'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '358'),
#   ('Min', {}, '12'),
#   ('Max', {}, '4033'),
#   ('Mean', {}, '248.601'),
#   ('Median', {}, '154'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '324'),
#   ('Min', {}, '69'),
#   ('Max', {}, '36335'),
#   ('Mean', {}, '1632.85'),
#   ('Median', {}, '673'),
# ...
#   ('Count', {}, '3'),
#   ('Min', {}, '84'),
#   ('Max', {}, '849'),
#   ('Mean', {}, '570.333'),
#   ('Median', {}, '778'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '710'),
#   ('Max', {}, '781'),
#   ('Mean', {}, '745.5'),
#   ('Median', {}, '781'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '22'),
#   ('Min', {}, '821'),
#   ('Max', {}, '2476'),
#   ('Mean', {}, '1770.32'),
#   ('Median', {}, '1826')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000510135.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '2'),
#   ('Mean', {}, '1.4'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '3'),
#   ('Max', {}, '9'),
#   ('Mean', {}, '7.28571'),
#   ('Median', {}, '8'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '78'),
#   ('Min', {}, '34'),
#   ('Max', {}, '774'),
#   ('Mean', {}, '206.141'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '71'),
#   ('Min', {}, '84'),
#   ('Max', {}, '9889'),
#   ('Mean', {}, '1863.48'),
#   ('Median', {}, '1113'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '14'),
#   ('Min', {}, '710'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1536.86'),
#   ('Median', {}, '1602'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '12'),
#   ('Min', {}, '669'),
#   ('Max', {}, '1368'),
#   ('Mean', {}, '1050.75'),
#   ('Median', {}, '1047'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '74'),
#   ('Min', {}, '34'),
#   ('Max', {}, '774'),
#   ('Mean', {}, '204.068'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '43'),
#   ('Max', {}, '470'),
#   ('Mean', {}, '244.5'),
#   ('Median', {}, '268'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '10'),
#   ('Min', {}, '1643'),
#   ('Max', {}, '16769'),
#   ('Mean', {}, '12516.1'),
#   ('Median', {}, '14535'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '68'),
#   ('Min', {}, '98'),
#   ('Max', {}, '9889'),
#   ('Mean', {}, '1920.53'),
#   ('Median', {}, '1464'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '3'),
#   ('Min', {}, '84'),
#   ('Max', {}, '849'),
#   ('Mean', {}, '570.333'),
#   ('Median', {}, '778'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '710'),
#   ('Max', {}, '781'),
#   ('Mean', {}, '745.5'),
#   ('Median', {}, '781'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '12'),
#   ('Min', {}, '1477'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1668.75'),
#   ('Median', {}, '1614')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000510145.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '2'),
#   ('Mean', {}, '1.375'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '3'),
#   ('Max', {}, '9'),
#   ('Mean', {}, '7.18182'),
#   ('Median', {}, '8'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '62'),
#   ('Min', {}, '36'),
#   ('Max', {}, '686'),
#   ('Mean', {}, '207.613'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '56'),
#   ('Min', {}, '84'),
#   ('Max', {}, '9892'),
#   ('Mean', {}, '1833.68'),
#   ('Median', {}, '1113'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '11'),
#   ('Min', {}, '710'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1524.82'),
#   ('Median', {}, '1605'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '9'),
#   ('Min', {}, '915'),
#   ('Max', {}, '1368'),
#   ('Mean', {}, '1156'),
#   ('Median', {}, '1134'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '58'),
#   ('Min', {}, '36'),
#   ('Max', {}, '686'),
#   ('Mean', {}, '205.069'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '43'),
#   ('Max', {}, '470'),
#   ('Mean', {}, '244.5'),
#   ('Median', {}, '268'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '8'),
#   ('Min', {}, '1643'),
#   ('Max', {}, '16768'),
#   ('Mean', {}, '12476.5'),
#   ('Median', {}, '14514'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '53'),
#   ('Min', {}, '98'),
#   ('Max', {}, '9892'),
#   ('Mean', {}, '1905.19'),
#   ('Median', {}, '1273'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '3'),
#   ('Min', {}, '84'),
#   ('Max', {}, '849'),
#   ('Mean', {}, '570.333'),
#   ('Median', {}, '778'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '710'),
#   ('Max', {}, '781'),
#   ('Mean', {}, '745.5'),
#   ('Median', {}, '781'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '9'),
#   ('Min', {}, '1477'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1698'),
#   ('Median', {}, '1614')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000510155.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '5'),
#   ('Mean', {}, '1.72727'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '3'),
#   ('Max', {}, '9'),
#   ('Mean', {}, '7.26316'),
#   ('Median', {}, '8'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '87'),
#   ('Min', {}, '34'),
#   ('Max', {}, '774'),
#   ('Mean', {}, '209.793'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '82'),
#   ('Min', {}, '84'),
#   ('Max', {}, '9888'),
#   ('Mean', {}, '2009.87'),
#   ('Median', {}, '1464'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '19'),
#   ('Min', {}, '710'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1492.89'),
#   ('Median', {}, '1581'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '17'),
#   ('Min', {}, '321'),
#   ('Max', {}, '1368'),
#   ('Mean', {}, '962.471'),
#   ('Median', {}, '1017'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '83'),
#   ('Min', {}, '34'),
#   ('Max', {}, '774'),
#   ('Mean', {}, '208.12'),
#   ('Median', {}, '104'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '43'),
#   ('Max', {}, '470'),
#   ('Mean', {}, '244.5'),
#   ('Median', {}, '268'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '11'),
#   ('Min', {}, '1643'),
#   ('Max', {}, '16787'),
#   ('Mean', {}, '12692.8'),
#   ('Median', {}, '14342'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '79'),
#   ('Min', {}, '98'),
#   ('Max', {}, '9888'),
#   ('Mean', {}, '2064.53'),
#   ('Median', {}, '1476'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '3'),
#   ('Min', {}, '84'),
#   ('Max', {}, '849'),
#   ('Mean', {}, '570.333'),
#   ('Median', {}, '778'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '710'),
#   ('Max', {}, '781'),
#   ('Mean', {}, '745.5'),
#   ('Median', {}, '781'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '17'),
#   ('Min', {}, '979'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1580.82'),
#   ('Median', {}, '1583')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000510165.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '2'),
#   ('Mean', {}, '1.5'),
#   ('Median', {}, '2'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '3'),
#   ('Max', {}, '9'),
#   ('Mean', {}, '7.16667'),
#   ('Median', {}, '8'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '62'),
#   ('Min', {}, '36'),
#   ('Max', {}, '686'),
#   ('Mean', {}, '207.242'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '57'),
#   ('Min', {}, '84'),
#   ('Max', {}, '9889'),
#   ('Mean', {}, '1945.98'),
#   ('Median', {}, '1113'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '12'),
#   ('Min', {}, '710'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1523.5'),
#   ('Median', {}, '1592'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '10'),
#   ('Min', {}, '669'),
#   ('Max', {}, '1368'),
#   ('Mean', {}, '1056.6'),
#   ('Median', {}, '1047'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '58'),
#   ('Min', {}, '36'),
#   ('Max', {}, '686'),
#   ('Mean', {}, '204.672'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '4'),
#   ('Min', {}, '43'),
#   ('Max', {}, '470'),
#   ('Mean', {}, '244.5'),
#   ('Median', {}, '268'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '8'),
#   ('Min', {}, '1643'),
#   ('Max', {}, '16765'),
#   ('Mean', {}, '12568'),
#   ('Median', {}, '14527'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '54'),
#   ('Min', {}, '98'),
#   ('Max', {}, '9889'),
#   ('Mean', {}, '2022.41'),
#   ('Median', {}, '1464'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '3'),
#   ('Min', {}, '84'),
#   ('Max', {}, '849'),
#   ('Mean', {}, '570.333'),
#   ('Median', {}, '778'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '710'),
#   ('Max', {}, '781'),
#   ('Mean', {}, '745.5'),
#   ('Median', {}, '781'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '10'),
#   ('Min', {}, '1477'),
#   ('Max', {}, '1986'),
#   ('Mean', {}, '1679.1'),
#   ('Median', {}, '1614')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000510175.1', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '5'),
#   ('Mean', {}, '1.88889'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '5'),
#   ('Max', {}, '9'),
#   ('Mean', {}, '7.41176'),
#   ('Median', {}, '8'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '73'),
#   ('Min', {}, '36'),
#   ('Max', {}, '694'),
#   ('Mean', {}, '198.123'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '69'),
#   ('Min', {}, '98'),
#   ('Max', {}, '7716'),
#   ('Mean', {}, '1891.99'),
#   ('Median', {}, '1476'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '17'),
#   ('Min', {}, '979'),
#   ('Max', {}, '1877'),
#   ('Mean', {}, '1524.71'),
#   ('Median', {}, '1573'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '17'),
#   ('Min', {}, '321'),
#   ('Max', {}, '1368'),
#   ('Mean', {}, '979.941'),
#   ('Median', {}, '1017'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '73'),
#   ('Min', {}, '36'),
#   ('Max', {}, '694'),
#   ('Mean', {}, '198.123'),
#   ('Median', {}, '105'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '9'),
#   ('Min', {}, '8713'),
#   ('Max', {}, '15021'),
#   ('Mean', {}, '12624.4'),
#   ('Median', {}, '14015'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '69'),
#   ('Min', {}, '98'),
#   ('Max', {}, '7716'),
#   ('Mean', {}, '1891.99'),
#   ('Median', {}, '1476'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '17'),
#   ('Min', {}, '979'),
#   ('Max', {}, '1877'),
#   ('Mean', {}, '1524.71'),
#   ('Median', {}, '1573')],
#  [('AssemblyStats',
#    {'Accession': 'GCF_000005045.25', 'Type': 'assembly unit'},
#    '\n    '),
#   ('TranscriptsPerGene', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '33'),
#   ('Mean', {}, '2.14199'),
#   ('Median', {}, '1'),
#   ('ExonsPerTranscript', {}, '\n      '),
#   ('Min', {}, '1'),
#   ('Max', {}, '93'),
#   ('Mean', {}, '7.87595'),
#   ('Median', {}, '5'),
#   ('LengthStats', {'category': 'All exons'}, '\n      '),
#   ('Count', {}, '8186'),
#   ('Min', {}, '7'),
#   ('Max', {}, '14433'),
#   ('Mean', {}, '366.997'),
#   ('Median', {}, '138'),
#   ('LengthStats', {'category': 'All introns'}, '\n      '),
#   ('Count', {}, '7161'),
#   ('Min', {}, '30'),
#   ('Max', {}, '334517'),
#   ('Mean', {}, '4315.23'),
#   ('Median', {}, '1113'),
#   ('LengthStats', {'category': 'All transcripts'}, '\n      '),
#   ('Count', {}, '2140'),
#   ('Min', {}, '17'),
#   ('Max', {}, '21046'),
#   ('Mean', {}, '2885.79'),
#   ('Median', {}, '2234'),
#   ('LengthStats', {'category': 'CDSs'}, '\n      '),
#   ('Count', {}, '1382'),
#   ('Min', {}, '132'),
#   ('Max', {}, '16965'),
#   ('Mean', {}, '1728.69'),
#   ('Median', {}, '1284'),
#   ('LengthStats', {'category': 'Exons in coding models'}, '\n      '),
#   ('Count', {}, '6730'),
#   ('Min', {}, '7'),
#   ('Max', {}, '14433'),
#   ('Mean', {}, '339.759'),
#   ('Median', {}, '133'),
#   ('LengthStats', {'category': 'Exons in non-coding models'}, '\n      '),
#   ('Count', {}, '2042'),
#   ('Min', {}, '9'),
#   ('Max', {}, '10558'),
#   ('Mean', {}, '427.424'),
#   ('Median', {}, '153'),
#   ('LengthStats', {'category': 'Genes'}, '\n      '),
#   ('Count', {}, '996'),
#   ('Min', {}, '51'),
#   ('Max', {}, '650936'),
#   ('Mean', {}, '25456.7'),
#   ('Median', {}, '8349'),
#   ('LengthStats', {'category': 'Introns in coding models'}, '\n      '),
#   ('Count', {}, '6034'),
#   ('Min', {}, '30'),
#   ('Max', {}, '334517'),
#   ('Mean', {}, '3872.72'),
#   ('Median', {}, '1015'),
#   ('LengthStats', {'category': 'Introns in non-coding models'}, '\n      '),
#   ('Count', {}, '1642'),
#   ('Min', {}, '38'),
#   ('Max', {}, '112483'),
#   ('Mean', {}, '5694.09'),
#   ('Median', {}, '1571'),
#   ('LengthStats', {'category': 'Single-exon transcripts'}, '\n      '),
#   ('Count', {}, '118'),
#   ('Min', {}, '452'),
#   ('Max', {}, '18485'),
#   ('Mean', {}, '3601.76'),
#   ('Median', {}, '2485'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in coding models'},
#    '\n      '),
#   ('Count', {}, '104'),
#   ('Min', {}, '452'),
#   ('Max', {}, '18485'),
#   ('Mean', {}, '3517.5'),
#   ('Median', {}, '2462'),
#   ('LengthStats',
#    {'category': 'Single-exon transcripts in non-coding models'},
#    '\n      '),
#   ('Count', {}, '14'),
#   ('Min', {}, '829'),
#   ('Max', {}, '12682'),
#   ('Mean', {}, '4227.71'),
#   ('Median', {}, '2879'),
#   ('LengthStats', {'category': 'guide_RNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '266'),
#   ('Max', {}, '278'),
#   ('Mean', {}, '272'),
#   ('Median', {}, '278'),
#   ('LengthStats', {'category': 'lncRNA'}, '\n      '),
#   ('Count', {}, '475'),
#   ('Min', {}, '137'),
#   ('Max', {}, '13054'),
#   ('Mean', {}, '1834.45'),
#   ('Median', {}, '1308'),
#   ('LengthStats', {'category': 'mRNA'}, '\n      '),
#   ('Count', {}, '1382'),
#   ('Min', {}, '234'),
#   ('Max', {}, '21046'),
#   ('Mean', {}, '3470.96'),
#   ('Median', {}, '2585'),
#   ('LengthStats', {'category': 'miRNA'}, '\n      '),
#   ('Count', {}, '83'),
#   ('Min', {}, '17'),
#   ('Max', {}, '26'),
#   ('Mean', {}, '21.6386'),
#   ('Median', {}, '22'),
#   ('LengthStats', {'category': 'misc_RNA'}, '\n      '),
#   ('Count', {}, '161'),
#   ('Min', {}, '173'),
#   ('Max', {}, '12682'),
#   ('Mean', {}, '2863.29'),
#   ('Median', {}, '2760'),
#   ('LengthStats', {'category': 'premsg'}, '\n      '),
#   ('Count', {}, '57'),
#   ('Min', {}, '51'),
#   ('Max', {}, '138'),
#   ('Mean', {}, '83.7368'),
#   ('Median', {}, '80'),
#   ('LengthStats', {'category': 'rRNA'}, '\n      '),
#   ('Count', {}, '25'),
#   ('Min', {}, '121'),
#   ('Max', {}, '13351'),
#   ('Mean', {}, '1715.6'),
#   ('Median', {}, '121'),
#   ('LengthStats', {'category': 'snoRNA'}, '\n      '),
#   ('Count', {}, '10'),
#   ('Min', {}, '59'),
#   ('Max', {}, '197'),
#   ('Mean', {}, '98.2'),
#   ('Median', {}, '75'),
#   ('LengthStats', {'category': 'tRNA'}, '\n      '),
#   ('Count', {}, '2'),
#   ('Min', {}, '82'),
#   ('Max', {}, '82'),
#   ('Mean', {}, '82'),
#   ('Median', {}, '82')]]

# %%
human_accession = full_assembly_collection[1][0][2]
human_accession
# Out:
# 'GCF_000001405.39'

# %% [markdown]
# From this 'human_accession', at the ncbi online database located at https://www.ncbi.nlm.nih.gov/assembly/GCF_000001405.39/, the full sequence report can be pulled down into a text file seen below. This information contains information about genetic information located on chromosomes, in other words, it's a type of dna data.

# %%
import csv
txt_file_dna = r"GCF_000001405.39_GRCh38.p13_assembly_report.txt"
csv_file_dna = r"GCF_000001405.39_GRCh38.p13_assembly_report.csv"
in_txt_dna = csv.reader(open(txt_file_dna, "r", encoding='utf-8'), delimiter = '\t')
out_csv_dna = csv.writer(open(csv_file_dna, 'w'))
out_csv_dna.writerows(in_txt_dna)

# %%
import pandas as pd
to_skip_info = []
for i in range(34,1406):
    to_skip_info.append(i)
information_about_dna_data = pd.read_csv('GCF_000001405.39_GRCh38.p13_assembly_report_fixed.csv', skiprows=(to_skip_info), header=0)
pd.DataFrame(information_about_dna_data['Assembly name:  GRCh38.p13'].dropna(axis=0))
# Out:
#                            Assembly name:  GRCh38.p13
# 1   Description:    Genome Reference Consortium Hu...
# 3                Organism name:  Homo sapiens (human)
# 5                                Taxid:          9606
# 7                          BioProject:     PRJNA31257
# 9         Submitter:      Genome Reference Consortium
# 11                         Date:           2019-02-28
# 13              Assembly type:  haploid-with-alt-loci
# 15                              Release type:   patch
# 17                         Assembly level: Chromosome
# 19                        Genome representation: full
# 21                  RefSeq category: Reference Genome
# 23       GenBank assembly accession: GCA_000001405.28
# 25        RefSeq assembly accession: GCF_000001405.39
# 27  RefSeq assembly and GenBank assemblies identic...
# 31                                    Assembly-Units:

# %%
dna_data = pd.read_csv('GCF_000001405.39_GRCh38.p13_assembly_report_fixed.csv', header=124)
dna_data = dna_data.dropna(axis=0)

# %%
dna_data.sample(10)
# Out:
#          # Sequence-Name      Sequence-Role Assigned-Molecule  \
# 881        HSCHR7_1_CTG6       alt-scaffold                 7
# 559         HG1708_PATCH          fix-patch                11
# 317   HSCHRUN_RANDOM_143  unplaced-scaffold                na
# 339   HSCHRUN_RANDOM_161  unplaced-scaffold                na
# 263   HSCHRUN_RANDOM_120  unplaced-scaffold                na
# 945     HG151_NOVEL_TEST       alt-scaffold                11
# 473       HSCHR4_8_CTG12        novel-patch                 4
# 607         HG2291_PATCH          fix-patch                13
# 1007      HSCHR15_1_CTG3       alt-scaffold                15
# 641       HSCHR15_6_CTG8        novel-patch                15
#
#      Assigned-Molecule-Location/Type GenBank-Accn Relationship  \
# 881                       Chromosome   GL383534.2            =
# 559                       Chromosome   KV766195.1            =
# 317                               na   KI270529.1            =
# 339                               na   KI270584.1            =
# 263                               na   KI270422.1            =
# 945                       Chromosome   JH159137.1            =
# 473                       Chromosome   KQ090014.1            =
# 607                       Chromosome   KN538372.1            =
# 1007                      Chromosome   KI270848.1            =
# 641                       Chromosome   KQ031389.1            =
#
#          RefSeq-Accn     Assembly-Unit  Sequence-Length       UCSC-style-name
# 881   NW_003315922.2    ALT_REF_LOCI_1         119183.0   chr7_GL383534v2_alt
# 559   NW_017363816.1           PATCHES         140877.0                    na
# 317      NT_187439.1  Primary Assembly           1899.0      chrUn_KI270529v1
# 339      NT_187453.1  Primary Assembly           4513.0      chrUn_KI270584v1
# 263      NT_187416.1  Primary Assembly           1445.0      chrUn_KI270422v1
# 945   NW_003871074.1    ALT_REF_LOCI_1         191409.0  chr11_JH159137v1_alt
# 473   NW_013171800.1           PATCHES         163749.0                    na
# 607   NW_011332699.1           PATCHES         356766.0                    na
# 1007     NT_187603.1    ALT_REF_LOCI_1         327382.0  chr15_KI270848v1_alt
# 641   NW_012132920.1           PATCHES        2365364.0                    na

# %%
dna_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 1 to 1279
# Data columns (total 10 columns):
# # Sequence-Name                    640 non-null object
# Sequence-Role                      640 non-null object
# Assigned-Molecule                  640 non-null object
# Assigned-Molecule-Location/Type    640 non-null object
# GenBank-Accn                       640 non-null object
# Relationship                       640 non-null object
# RefSeq-Accn                        640 non-null object
# Assembly-Unit                      640 non-null object
# Sequence-Length                    640 non-null float64
# UCSC-style-name                    640 non-null object
# dtypes: float64(1), object(9)
# memory usage: 55.0+ KB

# %%
len(dna_data)
# Out:
# 640

# %% [markdown]
# From the same https://www.ncbi.nlm.nih.gov/assembly/GCF_000001405.39/ page, under genome information, https://www.ncbi.nlm.nih.gov/genome/?term=txid9606[orgn], and in the Genome Assembly and Annotation report, https://www.ncbi.nlm.nih.gov/genome/genomes/51?, in the protein section at https://www.ncbi.nlm.nih.gov/genome/proteins/51?genome_assembly_id=582967, a comprehensive report of human proteins can be found.

# %%
txt_file_protein = r"ProteinTable51_582967.txt"
csv_file_protein = r"ProteinTable51_582967.csv"
in_txt_protein = csv.reader(open(txt_file_protein, "r"), delimiter = '\t')
out_csv_protein = csv.writer(open(csv_file_protein, 'w'))
out_csv_protein.writerows(in_txt_protein)

# %%
protein_data = pd.read_csv('ProteinTable51_582967.csv')
protein_data.sample(10)
# Out:
#        #Replicon Name Replicon Accession      Start       Stop Strand  GeneID  \
# 15509               1       NC_000001.11  196289844  196608309      -  343450
# 14107               1       NC_000001.11  157796112  157820037      -  115350
# 58847               9       NC_000009.12   41127130   41128383      -  653404
# 100154             18       NC_000018.10    2539067    2567216      -   64863
# 73097              11       NC_000011.10  108287651  108365508      +     472
# 38450               5       NC_000005.10   37107602   37247698      -   65250
# 34748               4       NC_000004.12   53061810   53365941      -  152579
# 72346              11       NC_000011.10   77323274   77379385      -    5058
# 44764               6       NC_000006.12   42228345   42269590      -   55809
# 51667               7       NC_000007.14  103312569  103344622      -   27000
#
#           Locus Protein product  Length  \
# 15509     KCNT2  XP_016856668.1     923
# 14107     FCRL1  XP_011507427.1     424
# 58847   FOXD4L6  NP_001078945.1     417
# 100154   METTL4  XP_011524032.1     325
# 73097       ATM  XP_006718908.1    1708
# 38450   CPLANE1  XP_005248407.1    3208
# 34748     SCFD2  XP_011532677.1     533
# 72346      PAK1  NP_001363233.1     447
# 44764    TRERF1     NP_277037.1    1200
# 51667    DNAJC2     NP_055192.1     621
#
#                                              Protein name
# 15509   potassium channel subfamily T member 2 isoform X3
# 14107               Fc receptor-like protein 1 isoform X1
# 58847                      forkhead box protein D4-like 6
# 100154  N(6)-adenine-specific DNA methyltransferase ME...
# 73097                serine-protein kinase ATM isoform X8
# 38450   ciliogenesis and planar polarity effector 1 is...
# 34748   sec1 family domain-containing protein 2 isofor...
# 72346    serine/threonine-protein kinase PAK 1 isoform 13
# 44764       transcriptional-regulating factor 1 isoform 2
# 51667         dnaJ homolog subfamily C member 2 isoform 1

# %%
protein_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119489 entries, 0 to 119488
# Data columns (total 10 columns):
# #Replicon Name        119489 non-null object
# Replicon Accession    119489 non-null object
# Start                 119489 non-null int64
# Stop                  119489 non-null int64
# Strand                119489 non-null object
# GeneID                119489 non-null int64
# Locus                 119489 non-null object
# Protein product       119489 non-null object
# Length                119489 non-null int64
# Protein name          119489 non-null object
# dtypes: int64(4), object(6)
# memory usage: 9.1+ MB

# %%
len(protein_data)
# Out:
# 119489

# %% [markdown]
# The protein and dna information is related through the RefSeq-Accn column on the dna_data table and the Replicon Accession column on the protein_data table. The two cells below show that many types of protein information is stored in chromosomes.

# %%
dna_data[dna_data['RefSeq-Accn'] == 'NC_000012.12']
# Out:
#    # Sequence-Name       Sequence-Role Assigned-Molecule  \
# 23              12  assembled-molecule                12
#
#    Assigned-Molecule-Location/Type GenBank-Accn Relationship   RefSeq-Accn  \
# 23                      Chromosome   CM000674.2            =  NC_000012.12
#
#        Assembly-Unit  Sequence-Length UCSC-style-name
# 23  Primary Assembly      133275309.0           chr12

# %%
protein_data[protein_data['Replicon Accession']== 'NC_000012.12']
# Out:
#       #Replicon Name Replicon Accession      Start       Stop Strand  GeneID  \
# 74388             12       NC_000012.12      66883     175033      +  440073
# 74389             12       NC_000012.12      66883     171308      +  440073
# 74390             12       NC_000012.12      66883     171321      +  440073
# 74391             12       NC_000012.12      66883     171308      +  440073
# 74392             12       NC_000012.12      66883     174693      +  440073
# ...              ...                ...        ...        ...    ...     ...
# 80340             12       NC_000012.12  133218885  133234356      -  647589
# 80341             12       NC_000012.12  133218885  133234356      -  647589
# 80342             12       NC_000012.12  133221223  133234356      -  647589
# 80343             12       NC_000012.12  133221223  133234356      -  647589
# 80344             12       NC_000012.12  133221223  133234356      -  647589
#
#         Locus Protein product  Length  \
# 74388  IQSEC3  NP_001164209.1    1182
# 74389  IQSEC3  XP_016874800.1    1041
# 74390  IQSEC3  XP_011519262.1    1062
# 74391  IQSEC3  XP_016874799.1    1041
# 74392  IQSEC3  XP_011519260.1    1063
# ...       ...             ...     ...
# 80340    ANHX  XP_006719806.1     492
# 80341    ANHX  XP_011533124.1     336
# 80342    ANHX  XP_011533127.1     322
# 80343    ANHX  XP_011533126.1     331
# 80344    ANHX  XP_011533125.1     331
#
#                                             Protein name
# 74388  IQ motif and SEC7 domain-containing protein 3 ...
# 74389  IQ motif and SEC7 domain-containing protein 3 ...
# 74390  IQ motif and SEC7 domain-containing protein 3 ...
# 74391  IQ motif and SEC7 domain-containing protein 3 ...
# 74392  IQ motif and SEC7 domain-containing protein 3 ...
# ...                                                  ...
# 80340              anomalous homeobox protein isoform X1
# 80341              anomalous homeobox protein isoform X3
# 80342              anomalous homeobox protein isoform X5
# 80343              anomalous homeobox protein isoform X4
# 80344              anomalous homeobox protein isoform X4
#
# [5957 rows x 10 columns]

# %%
import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)
keys = get_keys("/Users/eannefawcett/.secret/ncbi_api.json")
api_key = keys['api_key']

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
handle = Entrez.einfo()
result = handle.read()
handle.close()

# %%
print(result)
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE eInfoResult PUBLIC "-//NLM//DTD einfo 20190110//EN" "https://eutils.ncbi.nlm.nih.gov/eutils/dtd/20190110/einfo.dtd">
# <eInfoResult>
# <DbList>
#
# 	<DbName>pubmed</DbName>
# 	<DbName>protein</DbName>
# 	<DbName>nuccore</DbName>
# 	<DbName>ipg</DbName>
# 	<DbName>nucleotide</DbName>
# 	<DbName>structure</DbName>
# 	<DbName>sparcle</DbName>
# 	<DbName>genome</DbName>
# 	<DbName>annotinfo</DbName>
# 	<DbName>assembly</DbName>
# 	<DbName>bioproject</DbName>
# 	<DbName>biosample</DbName>
# 	<DbName>blastdbinfo</DbName>
# 	<DbName>books</DbName>
# 	<DbName>cdd</DbName>
# 	<DbName>clinvar</DbName>
# 	<DbName>gap</DbName>
# 	<DbName>gapplus</DbName>
# 	<DbName>grasp</DbName>
# 	<DbName>dbvar</DbName>
# 	<DbName>gene</DbName>
# 	<DbName>gds</DbName>
# 	<DbName>geoprofiles</DbName>
# 	<DbName>homologene</DbName>
# 	<DbName>medgen</DbName>
# 	<DbName>mesh</DbName>
# 	<DbName>ncbisearch</DbName>
# 	<DbName>nlmcatalog</DbName>
# 	<DbName>omim</DbName>
# 	<DbName>orgtrack</DbName>
# 	<DbName>pmc</DbName>
# 	<DbName>popset</DbName>
# 	<DbName>probe</DbName>
# 	<DbName>proteinclusters</DbName>
# 	<DbName>pcassay</DbName>
# 	<DbName>biosystems</DbName>
# 	<DbName>pccompound</DbName>
# 	<DbName>pcsubstance</DbName>
# 	<DbName>seqannot</DbName>
# 	<DbName>snp</DbName>
# 	<DbName>sra</DbName>
# 	<DbName>taxonomy</DbName>
# 	<DbName>biocollections</DbName>
# 	<DbName>gtr</DbName>
# </DbList>
#
# </eInfoResult>

# %%
handle = Entrez.einfo()
record = Entrez.read(handle)

# %%
record.keys()
# Out:
# dict_keys(['DbList'])

# %%
record['DbList']
# Out:
# ['pubmed', 'protein', 'nuccore', 'ipg', 'nucleotide', 'structure', 'sparcle', 'genome', 'annotinfo', 'assembly', 'bioproject', 'biosample', 'blastdbinfo', 'books', 'cdd', 'clinvar', 'gap', 'gapplus', 'grasp', 'dbvar', 'gene', 'gds', 'geoprofiles', 'homologene', 'medgen', 'mesh', 'ncbisearch', 'nlmcatalog', 'omim', 'orgtrack', 'pmc', 'popset', 'probe', 'proteinclusters', 'pcassay', 'biosystems', 'pccompound', 'pcsubstance', 'seqannot', 'snp', 'sra', 'taxonomy', 'biocollections', 'gtr']

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
handle = Entrez.einfo(db="protein")
record = Entrez.read(handle)
record["DbInfo"]["Description"]
# Out:
# 'Protein sequence record'

# %%
record["DbInfo"]["Count"]
# Out:
# '831488909'

# %%
record["DbInfo"]["LastUpdate"]
# Out:
# '2020/03/16 21:46'

# %%
record["DbInfo"].keys()
# Out:
# dict_keys(['DbName', 'MenuName', 'Description', 'DbBuild', 'Count', 'LastUpdate', 'FieldList', 'LinkList'])

# %%
for field in record["DbInfo"]["FieldList"]:
    print("%(Name)s, %(FullName)s, %(Description)s" % field)
# Out:
# ALL, All Fields, All terms from all searchable fields
# UID, UID, Unique number assigned to each sequence
# FILT, Filter, Limits the records
# WORD, Text Word, Free text associated with record
# TITL, Title, Words in definition line
# KYWD, Keyword, Nonstandardized terms provided by submitter
# AUTH, Author, Author(s) of publication
# JOUR, Journal, Journal abbreviation of publication
# VOL, Volume, Volume number of publication
# ISS, Issue, Issue number of publication
# PAGE, Page Number, Page number(s) of publication
# ORGN, Organism, Scientific and common names of organism, and all higher levels of taxonomy
# ACCN, Accession, Accession number of sequence
# PACC, Primary Accession, Does not include retired secondary accessions
# GENE, Gene Name, Name of gene associated with sequence
# PROT, Protein Name, Name of protein associated with sequence
# ECNO, EC/RN Number, EC number for enzyme or CAS registry number
# PDAT, Publication Date, Date sequence added to GenBank
# MDAT, Modification Date, Date of last update
# SUBS, Substance Name, CAS chemical name or MEDLINE Substance Name
# PROP, Properties, Classification by source qualifiers and molecule type
# SQID, SeqID String, String identifier for sequence
# GPRJ, BioProject, BioProject
# SLEN, Sequence Length, Length of sequence
# MLWT, Molecular Weight, Molecular Weight
# FKEY, Feature key, Feature annotated on sequence
# PORG, Primary Organism, Scientific and common names of primary organism, and all higher levels of taxonomy
# ASSM, Assembly, Assembly
# DIV, Division, Division
# STRN, Strain, Strain
# ISOL, Isolate, Isolate
# CULT, Cultivar, Cultivar
# BRD, Breed, Breed

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
handle = Entrez.einfo(db="protein", ACCN='NP_001164209.1')
record = Entrez.read(handle)

# %%
record
# Out:
# {'DbInfo': {'DbName': 'protein', 'MenuName': 'Protein', 'Description': 'Protein sequence record', 'DbBuild': 'Build200315-0206m.1', 'Count': '831488909', 'LastUpdate': '2020/03/16 21:46', 'FieldList': [{'Name': 'ALL', 'FullName': 'All Fields', 'Description': 'All terms from all searchable fields', 'TermCount': '4427725646', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'N', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'UID', 'FullName': 'UID', 'Description': 'Unique number assigned to each sequence', 'TermCount': '0', 'IsDate': 'N', 'IsNumerical': 'Y', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'Y'}, {'Name': 'FILT', 'FullName': 'Filter', 'Description': 'Limits the records', 'TermCount': '260', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'WORD', 'FullName': 'Text Word', 'Description': 'Free text associated with record', 'TermCount': '1159081284', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'N', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'TITL', 'FullName': 'Title', 'Description': 'Words in definition line', 'TermCount': '134102182', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'N', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'KYWD', 'FullName': 'Keyword', 'Description': 'Nonstandardized terms provided by submitter', 'TermCount': '32361', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'AUTH', 'FullName': 'Author', 'Description': 'Author(s) of publication', 'TermCount': '2816926', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'JOUR', 'FullName': 'Journal', 'Description': 'Journal abbreviation of publication', 'TermCount': '85573', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'VOL', 'FullName': 'Volume', 'Description': 'Volume number of publication', 'TermCount': '4633', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'ISS', 'FullName': 'Issue', 'Description': 'Issue number of publication', 'TermCount': '4639', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'PAGE', 'FullName': 'Page Number', 'Description': 'Page number(s) of publication', 'TermCount': '204739', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'ORGN', 'FullName': 'Organism', 'Description': 'Scientific and common names of organism, and all higher levels of taxonomy', 'TermCount': '3676060', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'Y', 'IsHidden': 'N'}, {'Name': 'ACCN', 'FullName': 'Accession', 'Description': 'Accession number of sequence', 'TermCount': '1664479509', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'PACC', 'FullName': 'Primary Accession', 'Description': 'Does not include retired secondary accessions', 'TermCount': '1662924655', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'GENE', 'FullName': 'Gene Name', 'Description': 'Name of gene associated with sequence', 'TermCount': '1273647323', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'PROT', 'FullName': 'Protein Name', 'Description': 'Name of protein associated with sequence', 'TermCount': '6847131', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'ECNO', 'FullName': 'EC/RN Number', 'Description': 'EC number for enzyme or CAS registry number', 'TermCount': '6214', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'PDAT', 'FullName': 'Publication Date', 'Description': 'Date sequence added to GenBank', 'TermCount': '11535', 'IsDate': 'Y', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}, {'Name': 'MDAT' ...

# %%
record.keys()
# Out:
# dict_keys(['DbInfo'])

# %%
record['DbInfo'].keys()
# Out:
# dict_keys(['DbName', 'MenuName', 'Description', 'DbBuild', 'Count', 'LastUpdate', 'FieldList', 'LinkList'])

# %%
record['DbInfo']['DbName']
# Out:
# 'protein'

# %%
record['DbInfo']['MenuName']
# Out:
# 'Protein'

# %%
record['DbInfo']['Description']
# Out:
# 'Protein sequence record'

# %%
record['DbInfo']['DbBuild']
# Out:
# 'Build200315-0206m.1'

# %%
record['DbInfo']['Count']
# Out:
# '831488909'

# %%
record['DbInfo']['LastUpdate']
# Out:
# '2020/03/16 21:46'

# %%
len(record['DbInfo']['FieldList'])
# Out:
# 33

# %%
for field in record["DbInfo"]["FieldList"]:
    print("%(Name)s, %(FullName)s, %(Description)s" % field)
# Out:
# ALL, All Fields, All terms from all searchable fields
# UID, UID, Unique number assigned to each sequence
# FILT, Filter, Limits the records
# WORD, Text Word, Free text associated with record
# TITL, Title, Words in definition line
# KYWD, Keyword, Nonstandardized terms provided by submitter
# AUTH, Author, Author(s) of publication
# JOUR, Journal, Journal abbreviation of publication
# VOL, Volume, Volume number of publication
# ISS, Issue, Issue number of publication
# PAGE, Page Number, Page number(s) of publication
# ORGN, Organism, Scientific and common names of organism, and all higher levels of taxonomy
# ACCN, Accession, Accession number of sequence
# PACC, Primary Accession, Does not include retired secondary accessions
# GENE, Gene Name, Name of gene associated with sequence
# PROT, Protein Name, Name of protein associated with sequence
# ECNO, EC/RN Number, EC number for enzyme or CAS registry number
# PDAT, Publication Date, Date sequence added to GenBank
# MDAT, Modification Date, Date of last update
# SUBS, Substance Name, CAS chemical name or MEDLINE Substance Name
# PROP, Properties, Classification by source qualifiers and molecule type
# SQID, SeqID String, String identifier for sequence
# GPRJ, BioProject, BioProject
# SLEN, Sequence Length, Length of sequence
# MLWT, Molecular Weight, Molecular Weight
# FKEY, Feature key, Feature annotated on sequence
# PORG, Primary Organism, Scientific and common names of primary organism, and all higher levels of taxonomy
# ASSM, Assembly, Assembly
# DIV, Division, Division
# STRN, Strain, Strain
# ISOL, Isolate, Isolate
# CULT, Cultivar, Cultivar
# BRD, Breed, Breed

# %%
for field in record['DbInfo']['FieldList']:
    print(field)
    print('\n')
# Out:
# {'Name': 'ALL', 'FullName': 'All Fields', 'Description': 'All terms from all searchable fields', 'TermCount': '4427725646', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'N', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'UID', 'FullName': 'UID', 'Description': 'Unique number assigned to each sequence', 'TermCount': '0', 'IsDate': 'N', 'IsNumerical': 'Y', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'Y'}
#
#
# {'Name': 'FILT', 'FullName': 'Filter', 'Description': 'Limits the records', 'TermCount': '260', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'WORD', 'FullName': 'Text Word', 'Description': 'Free text associated with record', 'TermCount': '1159081284', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'N', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'TITL', 'FullName': 'Title', 'Description': 'Words in definition line', 'TermCount': '134102182', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'N', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'KYWD', 'FullName': 'Keyword', 'Description': 'Nonstandardized terms provided by submitter', 'TermCount': '32361', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'AUTH', 'FullName': 'Author', 'Description': 'Author(s) of publication', 'TermCount': '2816926', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'JOUR', 'FullName': 'Journal', 'Description': 'Journal abbreviation of publication', 'TermCount': '85573', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'VOL', 'FullName': 'Volume', 'Description': 'Volume number of publication', 'TermCount': '4633', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'ISS', 'FullName': 'Issue', 'Description': 'Issue number of publication', 'TermCount': '4639', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'PAGE', 'FullName': 'Page Number', 'Description': 'Page number(s) of publication', 'TermCount': '204739', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'ORGN', 'FullName': 'Organism', 'Description': 'Scientific and common names of organism, and all higher levels of taxonomy', 'TermCount': '3676060', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'Y', 'IsHidden': 'N'}
#
#
# {'Name': 'ACCN', 'FullName': 'Accession', 'Description': 'Accession number of sequence', 'TermCount': '1664479509', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'PACC', 'FullName': 'Primary Accession', 'Description': 'Does not include retired secondary accessions', 'TermCount': '1662924655', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'GENE', 'FullName': 'Gene Name', 'Description': 'Name of gene associated with sequence', 'TermCount': '1273647323', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'PROT', 'FullName': 'Protein Name', 'Description': 'Name of protein associated with sequence', 'TermCount': '6847131', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'ECNO', 'FullName': 'EC/RN Number', 'Description': 'EC number for enzyme or CAS registry number', 'TermCount': '6214', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'PDAT', 'FullName': 'Publication Date', 'Description': 'Date sequence added to GenBank', 'TermCount': '11535', 'IsDate': 'Y', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'MDAT', 'FullName': 'Modification Date', 'Description': 'Date of last update', 'TermCount': '6916', 'IsDate': 'Y', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'SUBS', 'FullName': 'Substance Name', 'Description': 'CAS chemical name or MEDLINE Substance Name', 'TermCount': '913681', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'PROP', 'FullName': 'Properties', 'Description': 'Classification by source qualifiers and molecule type', 'TermCount': '161343', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'SQID', 'FullName': 'SeqID String', 'Description': 'String identifier for sequence', 'TermCount': '623643845', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'GPRJ', 'FullName': 'BioProject', 'Description': 'BioProject', 'TermCount': '140917', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'Y', 'IsHidden': 'N'}
#
#
# {'Name': 'SLEN', 'FullName': 'Sequence Length', 'Description': 'Length of sequence', 'TermCount': '15029', 'IsDate': 'N', 'IsNumerical': 'Y', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'MLWT', 'FullName': 'Molecular Weight', 'Description': 'Molecular Weight', 'TermCount': '566834', 'IsDate': 'N', 'IsNumerical': 'Y', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'FKEY', 'FullName': 'Feature key', 'Description': 'Feature annotated on sequence', 'TermCount': '32', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'PORG', 'FullName': 'Primary Organism', 'Description': 'Scientific and common names of primary organism, and all higher levels of taxonomy', 'TermCount': '3668032', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'Y', 'IsHidden': 'N'}
#
#
# {'Name': 'ASSM', 'FullName': 'Assembly', 'Description': 'Assembly', 'TermCount': '77', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'DIV', 'FullName': 'Division', 'Description': 'Division', 'TermCount': '13', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'STRN', 'FullName': 'Strain', 'Description': 'Strain', 'TermCount': '937942', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'ISOL', 'FullName': 'Isolate', 'Description': 'Isolate', 'TermCount': '2734730', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'CULT', 'FullName': 'Cultivar', 'Description': 'Cultivar', 'TermCount': '24108', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}
#
#
# {'Name': 'BRD', 'FullName': 'Breed', 'Description': 'Breed', 'TermCount': '3224', 'IsDate': 'N', 'IsNumerical': 'N', 'SingleToken': 'Y', 'Hierarchy': 'N', 'IsHidden': 'N'}

# %%
for field in record["DbInfo"]["LinkList"]:
    print("%(Name)s, %(Menu)s, %(Description)s" % field)
# Out:
# nuccore_protein_wp, Links to autonomous proteins, Autonomous protein records
# protein_biocollections, BioCollections, BioCollections
# protein_bioproject, BioProject Links, Proteins related to BioProjects
# protein_biosystems, BioSystem Links, BioSystems
# protein_ccds, ccds, Link to Consensus CDS
# protein_cdd, Conserved Domain Links, Link to conserved domains within a protein
# protein_cdd_concise_2, Concise Conserved Domain Links, Link to a concise list of conserved domains in a protein
# protein_cdd_summary, , Display conserved domains within a protein
# protein_gene, Gene Links, Link to related Genes
# protein_genome, Genome Links, Genome record encoding protein sequence
# protein_homologene, HomoloGene Links, Related HomoloGene
# protein_nuccore, Nucleotide Links, Nucleotide sequence from coding region
# protein_nuccore_mat_peptide, Mature Peptides, Link between nucleotide record and mature peptides contained within nucleotide record
# protein_nuccore_mgc, Nucleotide NIH cDNA clone links, Nucleotide NIH cDNA clone
# protein_nuccore_mrna, Encoding mRNA, Link from protein to encoding mRNA
# protein_nuccore_small_genome, Link to all nucleotide sequences from this genome, All nucleotide sequences from this genome
# protein_nuccore_tsa, TSA master records, Links to TSA master records
# protein_nuccore_wgs, , Links to WGS master sequences
# protein_nuccore_wp, Link to genomic records, Genomic records
# protein_nucgss, GSS Links, GSS sequence from coding region
# protein_nucleotide_mgc_url, , Order cDNA clone
# protein_omim, OMIM Links, OMIM records associated with protein sequence
# protein_pcassay_target, BioAssay by Target (List), PubChem BioAssays done on the protein target
# protein_pcassay_target_pig, BioAssay by Target (Identical Proteins, List), PubChem BioAssays done on the protein target PIG
# protein_pcassay_target_pig_summary, pcassay, BioAssay by Target (Identical Proteins, Summary)
# protein_pcassay_target_summary, pcassay, BioAssay by Target (Summary)
# protein_pccompound, PubChem Compound Links, Related PubChem Compound
# protein_pcsubstance, PubChem Substance Links, Related PubChem Substance
# protein_pmc, PMC Links, Free full text articles in PMC
# protein_popset, PopSet Links, Population set containing protein sequence
# protein_protein_cdart_summary, , Display proteins with similar conserved domain architecture
# protein_protein_ref2wp, Links from references to autonomous proteins, Autonomous protein records
# protein_protein_refseq2uniprot, Protein (UniProtKB), Protein gi (refseq) to protein gi (UniProtKB)
# protein_protein_small_genome, Link to all proteins from this genome, All proteins from this genome
# protein_protein_uniprot2refseq, Protein (RefSeq), Protein gi (UniProtKB) to protein gi (refseq)
# protein_protein_wp2ref, Link to referencing proteins, Referencing proteins
# protein_proteinclusters, Protein Cluster Links, Related Protein Clusters
# protein_pubmed, PubMed Links, PubMed articles cited by protein sequence record
# protein_pubmed_refseq, PubMed (RefSeq) Links, Link to RefSeq PubMed articles
# protein_pubmed_weighted, PubMed (Weighted) Links, Links to pubmed
# protein_snp, SNP Links, Related SNPs
# protein_snp_geneview, , SNPs linked from GeneView
# protein_structure, Identical Structures, 3D structures for identical protein sequences
# protein_structure_direct, Structures, Experimentally determined 3D Structures
# protein_structure_related, , Related structures
# protein_structure_related_list, Related Structures (List), List of related structures
# protein_taxonomy, Taxonomy Links, Taxonomy sequences associated with protein record
# protein_taxonomy_wp2species, Links from autonomous proteins to species level organisms, Species level organisms

# %%
for field in record['DbInfo']['LinkList']:
    print(field)
    print('\n')
# Out:
# {'Name': 'nuccore_protein_wp', 'Menu': 'Links to autonomous proteins', 'Description': 'Autonomous protein records', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_biocollections', 'Menu': 'BioCollections', 'Description': 'BioCollections', 'DbTo': 'biocollections'}
#
#
# {'Name': 'protein_bioproject', 'Menu': 'BioProject Links', 'Description': 'Proteins related to BioProjects', 'DbTo': 'bioproject'}
#
#
# {'Name': 'protein_biosystems', 'Menu': 'BioSystem Links', 'Description': 'BioSystems', 'DbTo': 'biosystems'}
#
#
# {'Name': 'protein_ccds', 'Menu': 'ccds', 'Description': 'Link to Consensus CDS', 'DbTo': 'ccds'}
#
#
# {'Name': 'protein_cdd', 'Menu': 'Conserved Domain Links', 'Description': 'Link to conserved domains within a protein', 'DbTo': 'cdd'}
#
#
# {'Name': 'protein_cdd_concise_2', 'Menu': 'Concise Conserved Domain Links', 'Description': 'Link to a concise list of conserved domains in a protein', 'DbTo': 'cdd'}
#
#
# {'Name': 'protein_cdd_summary', 'Menu': '', 'Description': 'Display conserved domains within a protein', 'DbTo': 'cdd'}
#
#
# {'Name': 'protein_gene', 'Menu': 'Gene Links', 'Description': 'Link to related Genes', 'DbTo': 'gene'}
#
#
# {'Name': 'protein_genome', 'Menu': 'Genome Links', 'Description': 'Genome record encoding protein sequence', 'DbTo': 'genome'}
#
#
# {'Name': 'protein_homologene', 'Menu': 'HomoloGene Links', 'Description': 'Related HomoloGene', 'DbTo': 'homologene'}
#
#
# {'Name': 'protein_nuccore', 'Menu': 'Nucleotide Links', 'Description': 'Nucleotide sequence from coding region', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_mat_peptide', 'Menu': 'Mature Peptides', 'Description': 'Link between nucleotide record and mature peptides contained within nucleotide record', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_mgc', 'Menu': 'Nucleotide NIH cDNA clone links', 'Description': 'Nucleotide NIH cDNA clone', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_mrna', 'Menu': 'Encoding mRNA', 'Description': 'Link from protein to encoding mRNA', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_small_genome', 'Menu': 'Link to all nucleotide sequences from this genome', 'Description': 'All nucleotide sequences from this genome', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_tsa', 'Menu': 'TSA master records', 'Description': 'Links to TSA master records', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_wgs', 'Menu': '', 'Description': 'Links to WGS master sequences', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nuccore_wp', 'Menu': 'Link to genomic records', 'Description': 'Genomic records', 'DbTo': 'nuccore'}
#
#
# {'Name': 'protein_nucgss', 'Menu': 'GSS Links', 'Description': 'GSS sequence from coding region', 'DbTo': 'nucgss'}
#
#
# {'Name': 'protein_nucleotide_mgc_url', 'Menu': '', 'Description': 'Order cDNA clone', 'DbTo': 'nucleotide'}
#
#
# {'Name': 'protein_omim', 'Menu': 'OMIM Links', 'Description': 'OMIM records associated with protein sequence', 'DbTo': 'omim'}
#
#
# {'Name': 'protein_pcassay_target', 'Menu': 'BioAssay by Target (List)', 'Description': 'PubChem BioAssays done on the protein target', 'DbTo': 'pcassay'}
#
#
# {'Name': 'protein_pcassay_target_pig', 'Menu': 'BioAssay by Target (Identical Proteins, List)', 'Description': 'PubChem BioAssays done on the protein target PIG', 'DbTo': 'pcassay'}
#
#
# {'Name': 'protein_pcassay_target_pig_summary', 'Menu': 'pcassay', 'Description': 'BioAssay by Target (Identical Proteins, Summary)', 'DbTo': 'pcassay'}
#
#
# {'Name': 'protein_pcassay_target_summary', 'Menu': 'pcassay', 'Description': 'BioAssay by Target (Summary)', 'DbTo': 'pcassay'}
#
#
# {'Name': 'protein_pccompound', 'Menu': 'PubChem Compound Links', 'Description': 'Related PubChem Compound', 'DbTo': 'pccompound'}
#
#
# {'Name': 'protein_pcsubstance', 'Menu': 'PubChem Substance Links', 'Description': 'Related PubChem Substance', 'DbTo': 'pcsubstance'}
#
#
# {'Name': 'protein_pmc', 'Menu': 'PMC Links', 'Description': 'Free full text articles in PMC', 'DbTo': 'pmc'}
#
#
# {'Name': 'protein_popset', 'Menu': 'PopSet Links', 'Description': 'Population set containing protein sequence', 'DbTo': 'popset'}
#
#
# {'Name': 'protein_protein_cdart_summary', 'Menu': '', 'Description': 'Display proteins with similar conserved domain architecture', 'DbTo': 'protein'}
#
#
# {'Name': 'protein_protein_ref2wp', 'Menu': 'Links from references to autonomous proteins', 'Description': 'Autonomous protein records', 'DbTo': 'protein'}
#
#
# {'Name': 'protein_protein_refseq2uniprot', 'Menu': 'Protein (UniProtKB)', 'Description': 'Protein gi (refseq) to protein gi (UniProtKB)', 'DbTo': 'protein'}
#
#
# {'Name': 'protein_protein_small_genome', 'Menu': 'Link to all proteins from this genome', 'Description': 'All proteins from this genome', 'DbTo': 'protein'}
#
#
# {'Name': 'protein_protein_uniprot2refseq', 'Menu': 'Protein (RefSeq)', 'Description': 'Protein gi (UniProtKB) to protein gi (refseq)', 'DbTo': 'protein'}
#
#
# {'Name': 'protein_protein_wp2ref', 'Menu': 'Link to referencing proteins', 'Description': 'Referencing proteins', 'DbTo': 'protein'}
#
#
# {'Name': 'protein_proteinclusters', 'Menu': 'Protein Cluster Links', 'Description': 'Related Protein Clusters', 'DbTo': 'proteinclusters'}
#
#
# {'Name': 'protein_pubmed', 'Menu': 'PubMed Links', 'Description': 'PubMed articles cited by protein sequence record', 'DbTo': 'pubmed'}
#
#
# {'Name': 'protein_pubmed_refseq', 'Menu': 'PubMed (RefSeq) Links', 'Description': 'Link to RefSeq PubMed articles', 'DbTo': 'pubmed'}
#
#
# {'Name': 'protein_pubmed_weighted', 'Menu': 'PubMed (Weighted) Links', 'Description': 'Links to pubmed', 'DbTo': 'pubmed'}
#
#
# {'Name': 'protein_snp', 'Menu': 'SNP Links', 'Description': 'Related SNPs', 'DbTo': 'snp'}
#
#
# {'Name': 'protein_snp_geneview', 'Menu': '', 'Description': 'SNPs linked from GeneView', 'DbTo': 'snp'}
#
#
# {'Name': 'protein_structure', 'Menu': 'Identical Structures', 'Description': '3D structures for identical protein sequences', 'DbTo': 'structure'}
#
#
# {'Name': 'protein_structure_direct', 'Menu': 'Structures', 'Description': 'Experimentally determined 3D Structures', 'DbTo': 'structure'}
#
#
# {'Name': 'protein_structure_related', 'Menu': '', 'Description': 'Related structures', 'DbTo': 'structure'}
#
#
# {'Name': 'protein_structure_related_list', 'Menu': 'Related Structures (List)', 'Description': 'List of related structures', 'DbTo': 'structure'}
#
#
# {'Name': 'protein_taxonomy', 'Menu': 'Taxonomy Links', 'Description': 'Taxonomy sequences associated with protein record', 'DbTo': 'taxonomy'}
#
#
# {'Name': 'protein_taxonomy_wp2species', 'Menu': 'Links from autonomous proteins to species level organisms', 'Description': 'Species level organisms', 'DbTo': 'taxonomy'}

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = ['NP_001164209.1', 'XP_016874800.1']
print(Entrez.epost("protein", id=",".join(id_list)).read())
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE ePostResult PUBLIC "-//NLM//DTD epost 20090526//EN" "https://eutils.ncbi.nlm.nih.gov/eutils/dtd/20090526/epost.dtd"><ePostResult>
# 	<QueryKey>1</QueryKey>
# 	<WebEnv>NCID_1_190607792_130.14.18.97_9001_1584415437_1741210555_0MetA0_S_MegaStore</WebEnv>
# </ePostResult>

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = ['NP_001164209.1', 'XP_016874800.1']
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]
print(webenv)
print(query_key)
# Out:
# NCID_1_190536794_130.14.22.76_9001_1584415437_1110160424_0MetA0_S_MegaStore
# 1

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = ['NP_001164209.1']
search_results = Entrez.read(Entrez.efetch(db="protein", id=id_list, retmode='xml'))

# %%
search_results[0].keys()
# Out:
# dict_keys(['GBSeq_locus', 'GBSeq_length', 'GBSeq_moltype', 'GBSeq_topology', 'GBSeq_division', 'GBSeq_update-date', 'GBSeq_create-date', 'GBSeq_definition', 'GBSeq_primary-accession', 'GBSeq_accession-version', 'GBSeq_other-seqids', 'GBSeq_keywords', 'GBSeq_source', 'GBSeq_organism', 'GBSeq_taxonomy', 'GBSeq_references', 'GBSeq_comment', 'GBSeq_source-db', 'GBSeq_feature-table', 'GBSeq_sequence'])

# %%
search_results[0]['GBSeq_locus']
# Out:
# 'NP_001164209'

# %%
search_results[0]['GBSeq_length']
# Out:
# '1182'

# %%
search_results[0]['GBSeq_moltype']
# Out:
# 'AA'

# %%
search_results[0]['GBSeq_topology']
# Out:
# 'linear'

# %%
search_results[0]['GBSeq_division']
# Out:
# 'PRI'

# %%
search_results[0]['GBSeq_update-date']
# Out:
# '25-OCT-2019'

# %%
search_results[0]['GBSeq_create-date']
# Out:
# '31-DEC-2009'

# %%
search_results[0]['GBSeq_definition']
# Out:
# 'IQ motif and SEC7 domain-containing protein 3 isoform 1 [Homo sapiens]'

# %%
search_results[0]['GBSeq_primary-accession']
# Out:
# 'NP_001164209'

# %%
search_results[0]['GBSeq_accession-version']
# Out:
# 'NP_001164209.1'

# %%
search_results[0]['GBSeq_other-seqids'][0]
# Out:
# 'ref|NP_001164209.1|'

# %%
search_results[0]['GBSeq_other-seqids'][1]
# Out:
# 'gi|282721018'

# %%
search_results[0]['GBSeq_keywords']
# Out:
# ['RefSeq', 'MANE Select']

# %%
search_results[0]['GBSeq_source']
# Out:
# 'Homo sapiens (human)'

# %%
search_results[0]['GBSeq_organism']
# Out:
# 'Homo sapiens'

# %%
search_results[0]['GBSeq_taxonomy']
# Out:
# 'Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Euarchontoglires; Primates; Haplorrhini; Catarrhini; Hominidae; Homo'

# %%
search_results[0]['GBSeq_references'][0]
# Out:
# {'GBReference_reference': '1', 'GBReference_position': '1..1182', 'GBReference_authors': ['Um JW', 'Choii G', 'Park D', 'Kim D', 'Jeon S', 'Kang H', 'Mori T', 'Papadopoulos T', 'Yoo T', 'Lee Y', 'Kim E', 'Tabuchi K', 'Ko J'], 'GBReference_title': 'IQ Motif and SEC7 Domain-containing Protein 3 (IQSEC3) Interacts with Gephyrin to Promote Inhibitory Synapse Formation', 'GBReference_journal': 'J. Biol. Chem. 291 (19), 10119-10130 (2016)', 'GBReference_xref': [{'GBXref_dbname': 'doi', 'GBXref_id': '10.1074/jbc.M115.712893'}], 'GBReference_pubmed': '27002143', 'GBReference_remark': 'GeneRIF: these data reveal that IQSEC3 acts together with gephyrin to regulate inhibitory synapse development.'}

# %%
search_results[0]['GBSeq_references'][1]
# Out:
# {'GBReference_reference': '2', 'GBReference_position': '1..1182', 'GBReference_authors': ['Turner ST', 'Bailey KR', 'Schwartz GL', 'Chapman AB', 'Chai HS', 'Boerwinkle E'], 'GBReference_title': 'Genomic association analysis identifies multiple loci influencing antihypertensive response to an angiotensin II receptor blocker', 'GBReference_journal': 'Hypertension 59 (6), 1204-1211 (2012)', 'GBReference_xref': [{'GBXref_dbname': 'doi', 'GBXref_id': '10.1161/HYP.0b013e31825b30f8'}], 'GBReference_pubmed': '22566498'}

# %%
search_results[0]['GBSeq_references'][2]
# Out:
# {'GBReference_reference': '3', 'GBReference_position': '1..1182', 'GBReference_authors': ['Hattori Y', 'Ohta S', 'Hamada K', 'Yamada-Okabe H', 'Kanemura Y', 'Matsuzaki Y', 'Okano H', 'Kawakami Y', 'Toda M'], 'GBReference_title': 'Identification of a neuron-specific human gene, KIAA1110, that is a guanine nucleotide exchange factor for ARF1', 'GBReference_journal': 'Biochem. Biophys. Res. Commun. 364 (4), 737-742 (2007)', 'GBReference_xref': [{'GBXref_dbname': 'doi', 'GBXref_id': '10.1016/j.bbrc.2007.10.041'}], 'GBReference_pubmed': '17981261', 'GBReference_remark': 'GeneRIF: These results suggest that KIAA1110 is expressed specifically in mature neurons and may play an important role in the secretion pathway as a GEF for ARF1.'}

# %%
search_results[0]['GBSeq_comment']
# Out:
# 'VALIDATED REFSEQ: This record has undergone validation or preliminary review. The reference sequence was derived from AC026369.21 and AC007406.1.; ~Transcript Variant: This variant (1) represents the longer transcript and encodes the longer isoform (1).; ~Sequence Note: The RefSeq transcript and protein were derived from genomic sequence to make the sequence consistent with the reference genome assembly. The genomic coordinates used for the transcript record were based on transcript alignments and orthologous data.; ; ##Evidence-Data-START## ; RNAseq introns :: single sample supports all introns SAMEA2145743, SAMEA2154665 [ECO:0000348] ; ##Evidence-Data-END##; ; ##RefSeq-Attributes-START## ; MANE Ensembl match :: ENST00000538872.6/ ENSP00000437554.1 ; RefSeq Select criteria :: based on conservation, expression, longest protein ; ##RefSeq-Attributes-END##'

# %%
search_results[0]['GBSeq_source-db']
# Out:
# 'REFSEQ: accession NM_001170738.2'

# %%
len(search_results[0]['GBSeq_feature-table'])
# Out:
# 9

# %%
for feature in search_results[0]['GBSeq_feature-table']:
    print(feature)
    print('\n')
# Out:
# {'GBFeature_key': 'source', 'GBFeature_location': '1..1182', 'GBFeature_intervals': [{'GBInterval_from': '1', 'GBInterval_to': '1182', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_quals': [{'GBQualifier_name': 'organism', 'GBQualifier_value': 'Homo sapiens'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'taxon:9606'}, {'GBQualifier_name': 'chromosome', 'GBQualifier_value': '12'}, {'GBQualifier_name': 'map', 'GBQualifier_value': '12p13.33'}]}
#
#
# {'GBFeature_key': 'Protein', 'GBFeature_location': '1..1182', 'GBFeature_intervals': [{'GBInterval_from': '1', 'GBInterval_to': '1182', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_quals': [{'GBQualifier_name': 'product', 'GBQualifier_value': 'IQ motif and SEC7 domain-containing protein 3 isoform 1'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'IQ motif and SEC7 domain-containing protein 3; IQ motif and Sec7 domain 3'}, {'GBQualifier_name': 'calculated_mol_wt', 'GBQualifier_value': '127491'}]}
#
#
# {'GBFeature_key': 'Region', 'GBFeature_location': '<32..63', 'GBFeature_intervals': [{'GBInterval_from': '32', 'GBInterval_to': '63', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_partial5': StringElement('', attributes={'value': 'true'}), 'GBFeature_quals': [{'GBQualifier_name': 'region_name', 'GBQualifier_value': 'bZIP'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'Basic leucine zipper (bZIP) domain of bZIP transcription factors: a DNA-binding and dimerization domain; cd14686'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:269834'}]}
#
#
# {'GBFeature_key': 'Site', 'GBFeature_location': 'order(32,35..36,39..40,42..43,46..47,49..50,53..54,56..57,60..61,63)', 'GBFeature_intervals': [{'GBInterval_point': '32', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '35', 'GBInterval_to': '36', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '39', 'GBInterval_to': '40', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '42', 'GBInterval_to': '43', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '46', 'GBInterval_to': '47', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '49', 'GBInterval_to': '50', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '53', 'GBInterval_to': '54', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '56', 'GBInterval_to': '57', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '60', 'GBInterval_to': '61', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_point': '63', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_operator': 'order', 'GBFeature_quals': [{'GBQualifier_name': 'site_type', 'GBQualifier_value': 'other'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'dimer interface [polypeptide binding]'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:269834'}]}
#
#
# {'GBFeature_key': 'Site', 'GBFeature_location': '259', 'GBFeature_intervals': [{'GBInterval_point': '259', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_quals': [{'GBQualifier_name': 'site_type', 'GBQualifier_value': 'phosphorylation'}, {'GBQualifier_name': 'experiment', 'GBQualifier_value': 'experimental evidence, no additional details recorded'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'Phosphoserine. {ECO:0000250|UniProtKB:Q3TES0}; propagated from UniProtKB/Swiss-Prot (Q9UPP2.3)'}]}
#
#
# {'GBFeature_key': 'Region', 'GBFeature_location': '651..839', 'GBFeature_intervals': [{'GBInterval_from': '651', 'GBInterval_to': '839', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_quals': [{'GBQualifier_name': 'region_name', 'GBQualifier_value': 'Sec7'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'Sec7 domain; pfam01369'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:279680'}]}
#
#
# {'GBFeature_key': 'Site', 'GBFeature_location': 'order(742..749,781..794)', 'GBFeature_intervals': [{'GBInterval_from': '742', 'GBInterval_to': '749', 'GBInterval_accession': 'NP_001164209.1'}, {'GBInterval_from': '781', 'GBInterval_to': '794', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_operator': 'order', 'GBFeature_quals': [{'GBQualifier_name': 'site_type', 'GBQualifier_value': 'active'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'active site/putative ARF binding site [active]'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:238100'}]}
#
#
# {'GBFeature_key': 'Region', 'GBFeature_location': '866..996', 'GBFeature_intervals': [{'GBInterval_from': '866', 'GBInterval_to': '996', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_quals': [{'GBQualifier_name': 'region_name', 'GBQualifier_value': 'PH_IQSEC'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'IQ motif and SEC7 domain-containing protein family Pleckstrin homology domain; cd13318'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:270128'}]}
#
#
# {'GBFeature_key': 'CDS', 'GBFeature_location': '1..1182', 'GBFeature_intervals': [{'GBInterval_from': '1', 'GBInterval_to': '1182', 'GBInterval_accession': 'NP_001164209.1'}], 'GBFeature_quals': [{'GBQualifier_name': 'gene', 'GBQualifier_value': 'IQSEC3'}, {'GBQualifier_name': 'coded_by', 'GBQualifier_value': 'NM_001170738.2:117..3665'}, {'GBQualifier_name': 'note', 'GBQualifier_value': 'isoform 1 is encoded by transcript variant 1'}, {'GBQualifier_name': 'transl_table', 'GBQualifier_value': '1'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CCDS:CCDS53728.1'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'GeneID:440073'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'HGNC:HGNC:29193'}, {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'MIM:612118'}]}

# %%
search_results[0]['GBSeq_feature-table'][0].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_intervals'][0])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_intervals'][0]['GBInterval_from'])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# source
# 1..1182
# {'GBInterval_from': '1', 'GBInterval_to': '1182', 'GBInterval_accession': 'NP_001164209.1'}
# 1
# 1182
# {'GBQualifier_name': 'organism', 'GBQualifier_value': 'Homo sapiens'}
# {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'taxon:9606'}
# {'GBQualifier_name': 'chromosome', 'GBQualifier_value': '12'}
# 12

# %%
search_results[0]['GBSeq_feature-table'][1].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_intervals'][0])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_intervals'][0]['GBInterval_from'])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# Protein
# 1..1182
# {'GBInterval_from': '1', 'GBInterval_to': '1182', 'GBInterval_accession': 'NP_001164209.1'}
# 1
# 1182
# {'GBQualifier_name': 'product', 'GBQualifier_value': 'IQ motif and SEC7 domain-containing protein 3 isoform 1'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'IQ motif and SEC7 domain-containing protein 3; IQ motif and Sec7 domain 3'}
# {'GBQualifier_name': 'calculated_mol_wt', 'GBQualifier_value': '127491'}
# 127491

# %%
search_results[0]['GBSeq_feature-table'][2].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_partial5', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_intervals'][0])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_intervals'][0]['GBInterval_from'])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_partial5'])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][2]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# Region
# <32..63
# {'GBInterval_from': '32', 'GBInterval_to': '63', 'GBInterval_accession': 'NP_001164209.1'}
# 32
# 63
#
# {'GBQualifier_name': 'region_name', 'GBQualifier_value': 'bZIP'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'Basic leucine zipper (bZIP) domain of bZIP transcription factors: a DNA-binding and dimerization domain; cd14686'}
# {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:269834'}
# CDD:269834

# %%
search_results[0]['GBSeq_feature-table'][2]['GBFeature_partial5']
# Out:
# StringElement('', attributes={'value': 'true'})

# %%
search_results[0]['GBSeq_feature-table'][3].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_operator', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][3]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][3]['GBFeature_location'])
for i in range(0, len(search_results[0]['GBSeq_feature-table'][3]['GBFeature_intervals'])):
    print(search_results[0]['GBSeq_feature-table'][3]['GBFeature_intervals'][i])
print(search_results[0]['GBSeq_feature-table'][3]['GBFeature_operator'])
for i in search_results[0]['GBSeq_feature-table'][3]['GBFeature_quals']:
    print(i)
# Out:
# Site
# order(32,35..36,39..40,42..43,46..47,49..50,53..54,56..57,60..61,63)
# {'GBInterval_point': '32', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '35', 'GBInterval_to': '36', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '39', 'GBInterval_to': '40', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '42', 'GBInterval_to': '43', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '46', 'GBInterval_to': '47', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '49', 'GBInterval_to': '50', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '53', 'GBInterval_to': '54', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '56', 'GBInterval_to': '57', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '60', 'GBInterval_to': '61', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_point': '63', 'GBInterval_accession': 'NP_001164209.1'}
# order
# {'GBQualifier_name': 'site_type', 'GBQualifier_value': 'other'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'dimer interface [polypeptide binding]'}
# {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:269834'}

# %%
search_results[0]['GBSeq_feature-table'][4].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_intervals'][0])
# print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_intervals'][0]['GBInterval_from'])
# print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][4]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# Site
# 259
# {'GBInterval_point': '259', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBQualifier_name': 'site_type', 'GBQualifier_value': 'phosphorylation'}
# {'GBQualifier_name': 'experiment', 'GBQualifier_value': 'experimental evidence, no additional details recorded'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'Phosphoserine. {ECO:0000250|UniProtKB:Q3TES0}; propagated from UniProtKB/Swiss-Prot (Q9UPP2.3)'}
# Phosphoserine. {ECO:0000250|UniProtKB:Q3TES0}; propagated from UniProtKB/Swiss-Prot (Q9UPP2.3)

# %%
search_results[0]['GBSeq_feature-table'][5].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_intervals'][0])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_intervals'][0]['GBInterval_from'])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][5]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# Region
# 651..839
# {'GBInterval_from': '651', 'GBInterval_to': '839', 'GBInterval_accession': 'NP_001164209.1'}
# 651
# 839
# {'GBQualifier_name': 'region_name', 'GBQualifier_value': 'Sec7'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'Sec7 domain; pfam01369'}
# {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:279680'}
# CDD:279680

# %%
search_results[0]['GBSeq_feature-table'][6].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_operator', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][6]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][6]['GBFeature_location'])
for i in range(0, len(search_results[0]['GBSeq_feature-table'][6]['GBFeature_intervals'])):
    print(search_results[0]['GBSeq_feature-table'][6]['GBFeature_intervals'][i])
print(search_results[0]['GBSeq_feature-table'][6]['GBFeature_operator'])
for i in search_results[0]['GBSeq_feature-table'][6]['GBFeature_quals']:
    print(i)
# Out:
# Site
# order(742..749,781..794)
# {'GBInterval_from': '742', 'GBInterval_to': '749', 'GBInterval_accession': 'NP_001164209.1'}
# {'GBInterval_from': '781', 'GBInterval_to': '794', 'GBInterval_accession': 'NP_001164209.1'}
# order
# {'GBQualifier_name': 'site_type', 'GBQualifier_value': 'active'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'active site/putative ARF binding site [active]'}
# {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:238100'}

# %%
search_results[0]['GBSeq_feature-table'][7].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_intervals'][0])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_intervals'][0]['GBInterval_from'])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][7]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# Region
# 866..996
# {'GBInterval_from': '866', 'GBInterval_to': '996', 'GBInterval_accession': 'NP_001164209.1'}
# 866
# 996
# {'GBQualifier_name': 'region_name', 'GBQualifier_value': 'PH_IQSEC'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'IQ motif and SEC7 domain-containing protein family Pleckstrin homology domain; cd13318'}
# {'GBQualifier_name': 'db_xref', 'GBQualifier_value': 'CDD:270128'}
# CDD:270128

# %%
search_results[0]['GBSeq_feature-table'][8].keys()
# Out:
# dict_keys(['GBFeature_key', 'GBFeature_location', 'GBFeature_intervals', 'GBFeature_quals'])

# %%
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_key'])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_location'])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_intervals'][0])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_intervals'][0]['GBInterval_from'])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_intervals'][0]['GBInterval_to'])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_quals'][0])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_quals'][1])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_quals'][2])
print(search_results[0]['GBSeq_feature-table'][8]['GBFeature_quals'][2]['GBQualifier_value'])
# Out:
# CDS
# 1..1182
# {'GBInterval_from': '1', 'GBInterval_to': '1182', 'GBInterval_accession': 'NP_001164209.1'}
# 1
# 1182
# {'GBQualifier_name': 'gene', 'GBQualifier_value': 'IQSEC3'}
# {'GBQualifier_name': 'coded_by', 'GBQualifier_value': 'NM_001170738.2:117..3665'}
# {'GBQualifier_name': 'note', 'GBQualifier_value': 'isoform 1 is encoded by transcript variant 1'}
# isoform 1 is encoded by transcript variant 1

# %%
search_results[0]['GBSeq_sequence']
# Out:
# '...'

# %%
webenv
# Out:
# 'NCID_1_190536794_130.14.22.76_9001_1584415437_1110160424_0MetA0_S_MegaStore'

# %%
query_key
# Out:
# '1'

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
len(results)
# Out:
# 2

# %% [markdown]
# I need to pull out the following information:
# - GBSeq_sequence
# - GBSeq_references using line comprehension --> not in every entry
# - GBSeq_organism
# - GBSeq_accession-version
# - GBSeq_definition
# - GBSeq_division
# - GBSeq_topology
# - GBSeq_moltype
# - ['GBSeq_feature-table'][0]['GBFeature_key'] == 'source', then ['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'] # for chromosome #
# - ['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein', ['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'] # for molar weight
#  - count 'GBSeq_feature-table[x]['GBFeature_key'] == 'Region'
#  - count 'GBSeq_feature-table[x]['GBFeature_key'] == 'Site'

# %%
protein_additional_data = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data['Chromosome'] = chromosome
protein_additional_data['Accesion Version'] = accession_version
protein_additional_data['Organism'] = organism
protein_additional_data['Definition'] = definition
protein_additional_data['Division'] = division
protein_additional_data['Topology'] = topology
protein_additional_data['Molecule Type'] = moltype
protein_additional_data['Molecular Weight'] = molar_weight
protein_additional_data['Number of Regions'] = regions
protein_additional_data['Number of Binding Sites'] = sites
protein_additional_data['Sequence'] = sequence

# %%
protein_additional_data
# Out:
#   Chromosome Accesion Version      Organism  \
# 0         12   NP_001164209.1  Homo sapiens
# 1         12   XP_016874800.1  Homo sapiens
#
#                                           Definition Division Topology  \
# 0  IQ motif and SEC7 domain-containing protein 3 ...      PRI   linear
# 1  IQ motif and SEC7 domain-containing protein 3 ...      PRI   linear
#
#   Molecule Type Molecular Weight  Number of Regions  Number of Binding Sites  \
# 0            AA           127491                  3                        3
# 1            AA           112808                  0                        0
#
#                                             Sequence
# 0  mesllenpvravlylkeltaivqnqqslihtqreridelerrldel...
# 1  mesllenpvravlylkeltaivqnqqslihtqreridelerrldel...

# %%
reference_accession_numbers_dna = dna_data['RefSeq-Accn'].unique()

# %%
decision_about_chromosome = pd.DataFrame()
accession_numbers = dna_data['RefSeq-Accn'].unique()
number_of_proteins = []
for accession_number in reference_accession_numbers_dna:
    number_of_proteins.append(len(protein_data[protein_data['Replicon Accession']==accession_number]))
decision_about_chromosome['Accession Number'] = accession_numbers
decision_about_chromosome['Number of Proteins'] = number_of_proteins
decision_about_chromosome[decision_about_chromosome['Number of Proteins'] >= 1000].nsmallest(5, 'Number of Proteins')
# Out:
#    Accession Number  Number of Proteins
# 20      NC_000021.9                1286
# 12     NC_000013.11                2019
# 17     NC_000018.10                2038
# 21     NC_000022.11                2508
# 19     NC_000020.11                2805

# %% [markdown]
# Since Accession Number 'NC_000021.9' has more rows than required for the project, but is still a relatively managable amount of proteins to study, I have selected chromosome 21 to study.

# %%
accession_to_study = decision_about_chromosome[decision_about_chromosome['Number of Proteins'] >= 1000].nsmallest(1, 'Number of Proteins').loc[20, 'Accession Number']
accession_to_study
# Out:
# 'NC_000021.9'

# %%
protein_accession_numbers = list(protein_data[protein_data['Replicon Accession']==accession_to_study]['Protein product'])
protein_accession_numbers
# Out:
# ['XP_006723962.1',
#  'XP_011544381.1',
#  'XP_011544380.1',
#  'NP_001350699.1',
#  'NP_001350689.1',
#  'NP_001350690.1',
#  'NP_001350687.1',
#  'NP_001355167.1',
#  'XP_011544384.3',
#  'XP_016883695.1',
#  'XP_011544387.2',
#  'XP_024307804.1',
#  'XP_011544385.1',
#  'NP_001308973.1',
#  'XP_016883696.1',
#  'XP_011544386.1',
#  'XP_006723981.1',
#  'XP_011544388.1',
#  'XP_006723982.1',
#  'XP_016884017.1',
#  'XP_016883697.1',
#  'NP_001307572.1',
#  'XP_016883999.1',
#  'XP_016884000.1',
#  'XP_024307912.1',
#  'NP_001340935.1',
#  'NP_001340936.1',
#  'NP_001308002.1',
#  'XP_016883699.1',
#  'NP_001340944.1',
#  'NP_001340937.1',
#  'NP_001340943.1',
#  'NP_001340941.1',
#  'XP_016883698.1',
#  'NP_001340938.1',
#  'NP_001340939.1',
#  'XP_024307806.1',
#  'XP_024307805.1',
#  'NP_001307575.1',
#  'NP_001307580.1',
#  'XP_016883709.1',
#  'XP_016883708.1',
#  'NP_001307579.1',
#  'XP_024307807.1',
#  'NP_001307577.1',
#  'NP_001300979.1',
#  'NP_001307648.1',
#  'XP_024307809.1',
#  'XP_016883711.1',
#  'XP_024307808.1',
#  'XP_016883710.1',
#  'XP_011544404.1',
#  'XP_016883712.1',
#  'NP_001308976.1',
#  'XP_011544405.1',
#  'XP_016883713.1',
#  'XP_016883714.1',
#  'XP_024307810.1',
#  'XP_011544409.2',
#  'XP_016883715.1',
#  'XP_011544407.1',
#  'XP_011544408.1',
#  'NP_001308965.1',
#  'NP_001309904.1',
#  'XP_006724005.1',
#  'XP_006724007.1',
#  'XP_011544411.1',
#  'XP_024307801.1',
#  'NP_001300621.1',
#  'XP_016883694.1',
#  'XP_016883693.1',
#  'NP_001351640.1',
#  'NP_001356798.1',
#  'NP_001316994.1',
#  'XP_006724009.1',
#  'XP_024307911.1',
#  'XP_011542311.1',
#  'NP_872288.2',
#  'XP_016884009.1',
#  'XP_016884010.1',
#  'NP_954870.2',
#  'NP_954869.1',
#  'NP_954868.1',
#  'NP_001277153.1',
#  'XP_006724060.1',
#  'NP_778146.2',
#  'XP_011527852.1',
#  'NP_001289930.1',
#  'NP_001289929.1',
#  'NP_001289928.1',
#  'NP_945347.2',
#  'NP_001289927.1',
#  'XP_006724028.1',
#  'NP_001307531.1',
#  'XP_005261054.1',
#  'NP_658983.3',
#  'XP_016883873.1',
#  'XP_016883875.1',
#  'XP_016883874.1',
#  'XP_016883876.1',
#  'NP_008879.3',
#  'NP_001273452.1',
#  'NP_071419.3',
#  'XP_011527986.1',
#  'NP_001243299.1',
#  'XP_011527987.1',
#  'XP_016883916.1',
#  'XP_011527988.1',
#  'NP_001243508.2',
#  'XP_016883964.1',
#  'XP_005261122.1',
#  'XP_016883965.1',
#  'XP_011528051.1',
#  'XP_011528053.1',
#  'XP_016883963.1',
#  'XP_011528049.1',
#  'NP_003480.2',
#  'XP_011528050.1',
#  'XP_005261120.1',
#  'XP_016883962.1',
#  'XP_011528054.1',
#  'XP_016883814.1',
#  'NP_001269970.1',
#  'NP_001269971.1',
#  'NP_037528.3',
#  'XP_011527837.1',
#  'XP_011527831.1',
#  'XP_016883812.1',
#  'XP_016883811.1',
#  'NP_001339489.1',
#  'XP_024307831.1',
#  'XP_024307832.1',
#  'XP_016883816.1',
#  'XP_005261006.1',
#  'NP_001339490.1',
#  'XP_011527779.1',
#  'NP_001193993.1',
#  'NP_001329.1',
#  'NP_001193994.1',
#  'XP_011527781.1',
#  'XP_011527778.1',
#  'NP_001193992.1',
#  'NP_001193995.1',
#  'XP_011527780.1',
#  'NP_001124386.1',
#  'XP_016883754.1',
#  'XP_024307819.1',
#  'XP_011527743.1',
#  'NP_006797.3',
#  'XP_016883755.1',
#  'XP_024307820.1',
#  'NP_059143.3',
#  'NP_001093890.1',
#  'NP_001093891.1',
#  'XP_011527755.1',
#  'NP_079220.2',
#  'NP_001191103.1',
#  'XP_016883762.1',
#  'NP_001191106.1',
#  'NP_001191105.1',
#  'NP_001191104.1',
#  'XP_011527759.1',
#  'NP_001191107.1',
#  'XP_011527960.1',
#  'NP_002763.3',
#  'XP_011527958.1',
#  'XP_011527961.1',
#  'XP_011527959.1',
#  'XP_011527956.1',
#  'XP_011527957.1',
#  'NP_001339525.1',
#  'NP_001339522.1',
#  'NP_001339524.1',
#  'NP_004531.2',
#  'XP_024307849.1',
#  'NP_001339520.1',
#  'NP_001339523.1',
#  'XP_011527883.1',
#  'NP_001339521.1',
#  'XP_011527884.1',
#  'XP_011527878.1',
#  'XP_011527882.1',
#  'XP_011527877.1',
#  'NP_001339526.1',
#  'XP_016883845.1',
#  'XP_016883846.1',
#  'XP_011527887.1',
#  'XP_011527953.1',
#  'NP_059142.3',
#  'NP_542984.3',
#  'XP_006724089.1',
#  'NP_067042.1',
#  'NP_001257337.1',
#  'NP_001257336.1',
#  'XP_024307891.1',
#  'XP_024307892.1',
#  'NP_001003701.1',
#  'NP_001003697.1',
#  'NP_001003696.1',
#  'NP_001307196.1',
#  'NP_001676.2',
#  'NP_001307195.1',
#  'NP_001003703.1',
#  'XP_005260995.1',
#  'NP_001184226.1',
#  'XP_024307830.1',
#  'XP_011527822.1',
#  'XP_011527823.1',
#  'NP_002031.2',
#  'XP_016883802.1',
#  'NP_001129488.1',
#  'NP_001191230.1',
#  'NP_958817.1',
#  'NP_001191231.1',
#  'NP_958816.1',
#  'NP_001129603.1',
#  'NP_000475.1',
#  'NP_001129601.1',
#  'NP_001191232.1',
#  'NP_001129602.1',
#  'XP_024307843.1',
#  'NP_443186.3',
#  'NP_001307697.2',
#  'XP_011527752.1',
#  'NP_008919.3',
#  'XP_024307822.1',
#  'XP_024307821.1',
#  'NP_008969.2',
#  'NP_877426.4',
#  'NP_037372.4',
#  'XP_016883806.1',
#  'NP_001307695.2',
#  'XP_016883805.1',
#  'NP_056380.3',
#  'XP_006724050.1',
#  'NP_058636.1',
#  'NP_001307653.1',
#  'XP_016883746.1',
#  'XP_016883748.1',
#  'NP_001001992.1',
#  'XP_016883747.1',
#  'NP_006438.1',
#  'NP_001027582.1',
#  'XP_016883749.1',
#  'XP_016883750.1',
#  'XP_024307813.1',
#  'NP_001269836.1',
#  'NP_001269837.1',
#  'NP_001269838.1',
#  'NP_006576.2',
#  'NP_001273552.1',
#  'NP_001358298.1',
#  'NP_064537.1',
#  'NP_001273563.1',
#  'NP_001273551.1',
#  'NP_001358299.1',
#  'NP_001358300.1',
#  'NP_001273548.1',
#  'NP_001358301.1',
#  'NP_001273547.1',
#  'NP_001358303.1',
#  'NP_001273546.1',
#  'NP_001358302.1',
#  'NP_001273549.1',
#  'NP_001273553.1',
#  'NP_001358305.1',
#  'NP_996749.1',
#  'NP_001177.1',
#  'NP_001307550.1',
#  'NP_001317922.1',
#  'NP_783300.1',
#  'NP_001307545.1',
#  'NP_001317923.1',
#  'NP_001307547.1',
#  'NP_000821.1',
#  'XP_005261001.1',
#  'NP_001307559.1',
#  'NP_036263.1',
#  'NP_955360.1',
#  'NP_001078924.1',
#  'NP_001122070.1',
#  'NP_981950.1',
#  'NP_001071179.1',
#  'NP_853655.1',
#  'NP_853652.1',
#  'NP_853630.2',
#  'NP_853653.1',
#  'NP_853631.1',
#  'NP_853654.1',
#  'NP_853638.1',
#  'NP_853639.1',
#  'NP_853640.1',
#  'NP_853641.1',
#  'NP_853642.1',
#  'NP_853643.1',
#  'NP_853645.1',
#  'NP_001157906.1',
#  'NP_853636.3',
#  'NP_853635.1',
#  'NP_853651.1',
#  'NP_853633.1',
#  'NP_853646.1',
#  'NP_001337906.1',
#  'NP_853647.1',
#  'NP_001121549.1',
#  'NP_001157907.1',
#  'NP_853648.1',
#  'NP_853650.1',
#  'NP_787053.1',
#  'NP_853637.2',
#  'NP_787054.1',
#  'NP_001092689.1',
#  'XP_016883939.1',
#  'NP_001340614.1',
#  'NP_001340619.1',
#  'XP_005261095.1',
#  'NP_001340616.1',
#  'XP_024307895.1',
#  'NP_001340618.1',
#  'NP_001340623.1',
#  'NP_001340615.1',
#  'XP_011528014.1',
#  'XP_016883937.1',
#  'NP_001340620.1',
#  'XP_016883940.1',
#  'NP_001340622.1',
#  'NP_003244.2',
#  'NP_001340621.1',
#  'NP_001340613.1',
#  'XP_011528015.1',
#  'NP_001340617.1',
#  'XP_005261097.1',
#  'NP_001307952.1',
#  'NP_000445.1',
#  'NP_001138917.1',
#  'XP_006724099.1',
#  'XP_005261074.1',
#  'XP_016883905.1',
#  'XP_006724098.1',
#  'NP_001138916.1',
#  'XP_016883904.1',
#  'XP_016883906.1',
#  'NP_065757.1',
#  'XP_011527839.1',
#  'NP_055401.1',
#  'XP_016883889.1',
#  'XP_016883891.1',
#  'XP_016883890.1',
#  'NP_061817.1',
#  'NP_996781.1',
#  'NP_848932.1',
#  'XP_006724091.1',
#  'XP_016883896.1',
#  'NP_001272323.1',
#  'NP_055640.2',
#  'XP_016883911.1',
#  'NP_001273485.1',
#  'XP_016883907.1',
#  'XP_016883908.1',
#  'NP_001307673.1',
#  'XP_006724101.1',
#  'XP_005261076.1',
#  'XP_016883912.1',
#  'NP_478067.2',
#  'NP_001307674.1',
#  'XP_016883910.1',
#  'XP_016883909.1',
#  'XP_011527971.1',
#  'XP_024307894.1',
#  'XP_024307893.1',
#  'NP_653260.1',
#  'NP_001337267.1',
#  'NP_067077.1',
#  'NP_001337263.1',
#  'NP_001337265.1',
#  'NP_001337266.1',
#  'NP_001337264.1',
#  'NP_003886.3',
#  'XP_016883988.1',
#  'XP_016883987.1',
#  'XP_016883984.1',
#  'XP_016883983.1',
#  'NP_001153778.1',
#  'XP_016883986.1',
#  'XP_016883985.1',
#  'XP_016883994.1',
#  'XP_016883991.1',
#  'NP_982271.3',
#  'XP_016883990.1',
#  'XP_016883993.1',
#  'NP_001153774.1',
#  'XP_016883989.1',
#  'XP_016883992.1',
#  'NP_057715.2',
#  'XP_006724129.1',
#  'NP_037461.2',
#  'XP_011528106.1',
#  'NP_001155967.2',
#  'NP_062542.5',
#  'NP_001155968.2',
#  'XP_011527955.1',
#  'NP_005797.1',
#  'XP_005260965.1',
#  'NP_620450.2',
#  'NP_000865.2',
#  'NP_001276055.1',
#  'NP_001276054.1',
#  'NP_001276057.1',
#  'NP_997468.1',
#  'NP_997467.1',
#  'NP_000619.3',
#  'XP_011527854.1',
#  'NP_000620.2',
#  'XP_005261021.1',
#  'NP_001316057.1',
#  'NP_005525.2',
#  'XP_011527855.1',
#  'XP_011527856.1',
#  'XP_011528048.1',
#  'NP_006125.2',
#  'NP_060303.2',
#  'NP_001307675.1',
#  'NP_001035282.1',
#  'XP_005260998.1',
#  'NP_001129478.1',
#  'NP_000810.1',
#  'NP_001129477.1',
#  'XP_006724053.1',
#  'XP_006724052.1',
#  'XP_011527828.1',
#  'NP_780294.1',
#  'NP_001278341.1',
#  'NP_620305.2',
#  'NP_001278340.1',
#  'NP_115571.2',
#  'NP_060083.1',
#  'NP_665857.2',
#  'NP_001317939.1',
#  'XP_016883919.1',
#  'NP_003015.2',
#  'XP_016883929.1',
#  'NP_001317937.1',
#  'XP_016883922.1',
#  'XP_016883925.1',
#  'XP_016883918.1',
#  'XP_016883917.1',
#  'NP_001317941.1',
#  'XP_011527994.1',
#  'NP_001317938.1',
#  'XP_016883921.1',
#  'XP_016883924.1',
#  'XP_016883927.1',
#  'NP_001317940.1',
#  'XP_016883923.1',
#  'XP_016883930.1',
#  'NP_001001132.1',
#  'XP_011527995.1',
#  'XP_016883920.1',
#  'XP_016883926.1',
#  'NP_001688.1',
#  'NP_115865.1',
#  'NP_008864.4',
#  'NP_751951.1',
#  'NP_001363828.1',
#  'NP_478062.1',
#  'NP_001269466.1',
#  'NP_001354277.1',
#  'NP_001257331.1',
#  'NP_001121142.1',
#  'NP_001257334.1',
#  'NP_000210.2',
#  'NP_001121141.1',
#  'NP_001257333.1',
#  'XP_016883831.1',
#  'NP_001121140.1',
#  'NP_001257332.1',
#  'XP_016883772.1',
#  'NP_981963.1',
#  'NP_004405.3',
#  'NP_001272318.1',
#  'NP_001272320.2',
#  'NP_981962.1',
#  'NP_001272321.1',
#  'NP_001272322.1',
#  'XP_016883771.1',
#  'NP_001317945.1',
#  'XP_005260986.1',
#  'NP_444507.1',
#  'XP_016883895.1',
#  'NP_001303938.1',
#  'XP_016883976.1',
#  'NP_001745.2',
#  'XP_011528069.1',
#  'XP_005261125.1',
#  'NP_001001890.1',
#  'XP_011528068.1',
#  'XP_011528070.1',
#  'XP_005261126.1',
#  'NP_001116079.1',
#  'XP_011528072.1',
#  'XP_016883893.1',
#  'NP_001273681.1',
#  'XP_011527945.1',
#  'XP_011527939.1',
#  'XP_011527946.1',
#  'XP_011527942.1',
#  'XP_011527941.1',
#  'XP_011527938.1',
#  'XP_011527944.1',
#  'NP_059134.1',
#  'XP_011527940.1',
#  'NP_001007260.1',
#  'XP_016883894.1',
#  'NP_001007262.1',
#  'XP_024307890.1',
#  'XP_024307889.1',
#  'NP_001273718.1',
#  'NP_001748.1',
#  'XP_011528074.1',
#  'NP_001227.1',
#  'NP_005119.2',
#  'NP_001307643.1',
#  'XP_016883998.1',
#  'NP_056173.1',
#  'NP_001307374.1',
#  'XP_011527820.1',
#  'NP_001307375.1',
#  'XP_016883800.1',
#  'XP_016883801.1',
#  'XP_016883967.1',
#  'XP_016883966.1',
#  'NP_005432.1',
#  'XP_011528057.1',
#  'NP_001139550.1',
#  'NP_001139549.1',
#  'NP_036262.1',
#  'NP_652763.1',
#  'NP_001139551.1',
#  'NP_033664.2',
#  'NP_005060.1',
#  'XP_016883931.1',
#  'XP_011527996.1',
#  'XP_016883819.1',
#  'NP_001229713.1',
#  'NP_000402.3',
#  'NP_001229714.1',
#  'NP_001339447.1',
#  'NP_001339443.1',
#  'NP_001339446.1',
#  'XP_024307834.1',
#  'XP_024307833.1',
#  'XP_011527841.1',
#  'XP_006724058.1',
#  'NP_001339445.1',
#  'NP_001339444.1',
#  'XP_011527840.1',
#  'XP_011527842.1',
#  'NP_061835.1',
#  'NP_001304697.1',
#  'NP_001304706.1',
#  'NP_710148.1',
#  'NP_057514.2',
#  'NP_001307409.1',
#  'XP_016883854.1',
#  'NP_710149.1',
#  'XP_016883947.1',
#  'NP_001307632.1',
#  'XP_016883948.1',
#  'XP_016883949.1',
#  'XP_005261109.1',
#  'NP_001307633.1',
#  'NP_001317612.1',
#  'XP_005261105.1',
#  'XP_005261111.1',
#  'XP_016883951.1',
#  'NP_001001894.1',
#  'XP_005261107.1',
#  'XP_016883950.1',
#  'XP_005261106.1',
#  'NP_003307.3',
#  'XP_011528042.1',
#  'XP_011528041.1',
#  'NP_001340865.1',
#  'XP_005261112.1',
#  'NP_001317611.1',
#  'XP_016883954.1',
#  'NP_001317610.1',
#  'XP_005261113.1',
#  'NP_001340866.1',
#  'NP_001340867.1',
#  'NP_006043.1',
#  'NP_001317951.1',
#  'NP_001317950.1',
#  'NP_001317947.1',
#  'NP_001334651.1',
#  'XP_006724040.1',
#  'XP_016883773.1',
#  'NP_001334650.1',
#  'NP_001387.2',
#  'XP_006724039.1',
#  'XP_011527785.1',
#  'NP_569120.1',
#  'NP_567824.1',
#  'NP_569122.1',
#  'XP_006724041.1',
#  'XP_024307825.1',
#  'XP_016883775.1',
#  'NP_001334652.1',
#  'XP_005260990.1',
#  'XP_016884012.1',
#  'NP_002231.1',
#  'XP_011527863.1',
#  'NP_001263368.1',
#  'XP_016883834.1',
#  'NP_733933.1',
#  'NP_001263364.1',
#  'XP_016883832.1',
#  'XP_005261032.1',
#  'NP_001263367.1',
#  'NP_733932.1',
#  'XP_016883833.1',
#  'NP_001263366.1',
#  'NP_002234.2',
#  'XP_011527862.1',
#  'XP_006724065.1',
#  'NP_001263365.1',
#  'NP_001230361.1',
#  'NP_001230358.1',
#  'NP_001230357.1',
#  'NP_001129627.1',
#  'NP_891548.1',
#  'NP_001129626.1',
#  'NP_001317954.1',
#  'NP_004440.1',
#  'NP_001278320.1',
#  'NP_001243224.1',
#  'XP_005260992.1',
#  'XP_016883779.1',
#  'NP_005230.1',
#  'NP_001248753.1',
#  'NP_001307724.1',
#  'NP_003711.1',
#  'XP_024307903.1',
#  'NP_982257.1',
#  'NP_061836.2',
#  'XP_011527914.1',
#  'XP_016883862.1',
#  'XP_016883863.1',
#  'XP_011527915.1',
#  'XP_011527913.1',
#  'NP_387505.1',
#  'XP_016883864.1',
#  'NP_001007247.1',
#  'XP_016883822.1',
#  'XP_024307836.1',
#  'XP_011527845.1',
#  'XP_016883825.1',
#  'XP_024307839.1',
#  'XP_011527851.1',
#  'XP_024307835.1',
#  'XP_016883824.1',
#  'XP_011527846.1',
#  'XP_024307838.1',
#  'XP_016883823.1',
#  'XP_024307837.1',
#  'NP_004956.5',
#  'NP_001337229.1',
#  'NP_004618.2',
#  'NP_001304673.1',
#  'NP_001337222.1',
#  'NP_001337224.1',
#  'NP_001139690.1',
#  'NP_001337225.1',
#  'NP_001337223.1',
#  'XP_011527769.1',
#  'XP_024307823.1',
#  'XP_011527760.1',
#  'XP_011527772.1',
#  'XP_016883765.1',
#  'XP_011527768.1',
#  'XP_011527763.1',
#  'XP_006724030.1',
#  'XP_011527764.1',
#  'XP_016883764.1',
#  'XP_011527765.1',
#  'XP_011527770.1',
#  'XP_006724036.1',
#  'XP_011527773.1',
#  'XP_016883767.1',
#  'XP_005260983.1',
#  'XP_011527767.1',
#  'XP_011527766.1',
#  'XP_011527761.1',
#  'NP_689718.1',
#  'XP_024307824.1',
#  'XP_006724035.1',
#  'XP_016883766.1',
#  'XP_011527771.1',
#  'XP_016883763.1',
#  'XP_011527762.1',
#  'NP_001304669.1',
#  'NP_031367.1',
#  'NP_001304671.1',
#  'NP_001304670.1',
#  'NP_001001713.1',
#  'NP_149362.2',
#  'NP_001265579.1',
#  'NP_149360.1',
#  'NP_001343268.1',
#  'NP_001343265.1',
#  'NP_006048.1',
#  'NP_001343267.1',
#  'NP_149361.1',
#  'XP_011527774.1',
#  'NP_001073913.1',
#  'NP_006189.2',
#  'NP_001380.2',
#  'XP_016883770.1',
#  'NP_001258463.1',
#  'NP_036237.2',
#  'NP_620477.1',
#  'NP_620476.1',
#  'XP_016883803.1',
#  'XP_011527951.1',
#  'NP_996847.1',
#  'NP_478066.3',
#  'XP_011527950.2',
#  'XP_005261040.1',
#  'XP_011527873.1',
#  'XP_011527875.1',
#  'XP_011527874.1',
#  'XP_024307848.1',
#  'XP_005261041.1',
#  'NP_002454.1',
#  'XP_011527876.1',
#  'NP_001138397.1',
#  'XP_016883839.1',
#  'XP_011527872.1',
#  'XP_016883841.1',
#  'XP_016883838.1',
#  'XP_005261036.1',
#  'XP_005261039.1',
#  'NP_002453.2',
#  'XP_016883840.1',
#  'NP_001269849.1',
#  'XP_005261038.1',
#  'XP_011527870.1',
#  'XP_005261037.1',
#  'NP_001171517.1',
#  'XP_005261035.1',
#  'NP_001128571.1',
#  'NP_005647.3',
#  'NP_065690.2',
#  'XP_016883914.1',
#  'XP_011527978.1',
#  'XP_011527979.1',
#  'XP_011527980.1',
#  'XP_006724103.1',
#  'XP_011527976.1',
#  'NP_001269863.2',
#  'XP_011527977.1',
#  'XP_016883915.1',
#  'XP_006724102.1',
#  'NP_001035514.2',
#  'XP_011527985.1',
#  'XP_011527981.1',
#  'NP_071398.4',
#  'XP_011527983.1',
#  'XP_005261166.1',
#  'NP_950251.1',
#  'NP_056315.1',
#  'XP_011527825.1',
#  'XP_016883804.1',
#  'XP_011527824.1',
#  'XP_011527826.1',
#  'NP_001307660.1',
#  'NP_001091873.1',
#  'NP_065778.3',
#  'NP_001307658.1',
#  'XP_005261178.1',
#  'XP_016883849.1',
#  'NP_001091872.1',
#  'XP_011527892.1',
#  'XP_011527890.1',
#  'XP_016883850.1',
#  'NP_775839.3',
#  'NP_001004416.2',
#  'NP_001186457.3',
#  'XP_016883995.1',
#  'NP_001186456.2',
#  'XP_016883996.1',
#  'XP_011528099.1',
#  'XP_016883997.1',
#  'NP_997510.1',
#  'NP_997512.1',
#  'NP_004906.3',
#  'NP_058198.2',
#  'XP_011528109.1',
#  'NP_997057.1',
#  'XP_011528108.1',
#  'NP_997511.1',
#  'XP_024307909.1',
#  'NP_003217.3',
#  'NP_005414.1',
#  'NP_003216.1',
#  'NP_001243246.1',
#  'NP_115780.1',
#  'NP_076927.1',
#  'NP_115781.1',
#  'NP_061834.1',
#  'XP_011527911.1',
#  'NP_001001895.1',
#  'NP_001230396.1',
#  'XP_011527907.1',
#  'XP_006724076.1',
#  'XP_011527909.1',
#  'XP_011527908.1',
#  'XP_011527912.1',
#  'XP_011528088.1',
#  'NP_001273435.1',
#  'NP_543136.1',
#  'XP_005261265.1',
#  'XP_016883867.1',
#  'XP_016883870.1',
#  'NP_061837.3',
#  'NP_001307466.1',
#  'XP_016883866.1',
#  'XP_016883869.1',
#  'XP_016883872.1',
#  'XP_016883868.1',
#  'XP_011527916.1',
#  'XP_011527917.1',
#  'XP_016883865.1',
#  'XP_016883871.1',
#  'XP_016884013.1',
#  'XP_016884014.1',
#  'NP_001001569.1',
#  'NP_002597.1',
#  'NP_001001578.1',
#  'XP_011527902.1',
#  'XP_016883856.1',
#  'NP_001001574.1',
#  'NP_001001567.1',
#  'NP_001001570.1',
#  'NP_001001583.1',
#  'NP_001001575.1',
#  'NP_001001582.1',
#  'NP_001001568.1',
#  'NP_001001581.1',
#  'NP_001001571.1',
#  'NP_001001577.1',
#  'XP_024307852.1',
#  'NP_001302462.1',
#  'XP_011527900.1',
#  'NP_001001580.1',
#  'NP_001001576.1',
#  'NP_001001579.1',
#  'NP_001001585.1',
#  'NP_001001572.1',
#  'NP_001001584.1',
#  'NP_001001573.1',
#  'XP_016883855.1',
#  'XP_024307817.1',
#  'XP_011527735.1',
#  'XP_016883752.1',
#  'NP_387510.1',
#  'XP_024307816.1',
#  'NP_061139.2',
#  'XP_024307815.1',
#  'XP_016883751.1',
#  'NP_001247406.1',
#  'XP_024307818.1',
#  'NP_001247405.1',
#  'XP_016883753.1',
#  'NP_001247403.1',
#  'NP_001247404.1',
#  'NP_001001503.1',
#  'XP_011527888.1',
#  'NP_066553.3',
#  'XP_016883848.1',
#  'NP_001295420.1',
#  'NP_001307623.1',
#  'NP_004562.2',
#  'NP_001273187.1',
#  'XP_016883980.1',
#  'NP_001171480.1',
#  'NP_001307227.1',
#  'XP_024307908.1',
#  'XP_024307905.1',
#  'NP_001171479.1',
#  'XP_024307907.1',
#  'NP_000062.1',
#  'XP_011528079.1',
#  'XP_011528085.1',
#  'XP_011528076.1',
#  'NP_001308001.1',
#  'XP_024307904.1',
#  'XP_024307906.1',
#  'XP_011528045.1',
#  'NP_006749.1',
#  'XP_024307898.1',
#  'XP_016883957.1',
#  'NP_001020375.1',
#  'XP_024307897.1',
#  'XP_024307899.1',
#  'NP_001020374.1',
#  'NP_000385.1',
#  'NP_001350695.1',
#  'NP_775490.2',
#  'XP_011527776.1',
#  'XP_016883758.1',
#  'XP_016883757.1',
#  'XP_011527747.2',
#  'XP_016883756.1',
#  'XP_016883759.1',
#  'XP_011527745.2',
#  'XP_016883760.1',
#  'XP_011527748.1',
#  'NP_008962.1',
#  'XP_016883761.1',
#  'XP_011527749.1',
#  'NP_059141.1',
#  'NP_055871.1',
#  'NP_003672.1',
#  'XP_005261252.2',
#  'XP_011528064.1',
#  'XP_011528060.1',
#  'XP_005261253.1',
#  'XP_011528113.1',
#  'NP_001317959.1',
#  'XP_011528063.1',
#  'XP_011528062.1',
#  'XP_005261256.1',
#  'XP_016883973.1',
#  'XP_016883972.1',
#  'NP_000091.1',
#  'XP_016883974.1',
#  'NP_003674.1',
#  'XP_016883975.1',
#  'XP_024307902.1',
#  'XP_016883897.1',
#  'XP_011527965.1',
#  'XP_016883903.1',
#  'XP_011527963.1',
#  'XP_011527966.1',
#  'XP_011527962.1',
#  'XP_011527964.1',
#  'NP_064517.1',
#  'XP_006724093.1',
#  'NP_001356807.1',
#  'NP_001032642.1',
#  'XP_011527967.1',
#  'XP_005261217.1',
#  'NP_001356809.1',
#  'XP_006724092.1',
#  'NP_001356810.1',
#  'XP_006724094.1',
#  'XP_016883901.1',
#  'XP_016883900.1',
#  'XP_011528028.1',
#  'NP_003265.3',
#  'XP_011528016.1',
#  'XP_011528020.1',
#  'XP_011528018.1',
#  'XP_011528022.1',
#  'XP_011528021.1',
#  'XP_011528027.1',
#  'XP_005261225.1',
#  'XP_011528019.1',
#  'XP_011528032.1',
#  'XP_011528017.1',
#  'XP_016883943.1',
#  'XP_011528023.1',
#  'XP_024307896.1',
#  'XP_011528024.1',
#  'XP_011528025.1',
#  'XP_011528031.1',
#  'XP_011528029.1',
#  'XP_011528030.1',
#  'NP_001338638.1',
#  'NP_005040.2',
#  'XP_011527969.1',
#  'NP_004640.4',
#  'NP_001307313.1',
#  'NP_001307312.1',
#  'NP_937798.4',
#  'XP_016883968.1',
#  'XP_024307901.1',
#  'XP_011527818.1',
#  'XP_011527816.1',
#  'NP_001269979.1',
#  'NP_056074.1',
#  'NP_001269981.1',
#  'NP_001352688.1',
#  'NP_001269980.1',
#  'XP_024307828.1',
#  'XP_011527817.1',
#  'NP_037501.2',
#  'NP_787063.1',
#  'NP_000374.1',
#  ...]

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[0:200]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_1 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_1['Chromosome'] = chromosome
protein_additional_data_1['Accession Version'] = accession_version
protein_additional_data_1['Organism'] = organism
protein_additional_data_1['Definition'] = definition
protein_additional_data_1['Division'] = division
protein_additional_data_1['Topology'] = topology
protein_additional_data_1['Molecule Type'] = moltype
protein_additional_data_1['Molecular Weight'] = molar_weight
protein_additional_data_1['Number of Regions'] = regions
protein_additional_data_1['Number of Binding Sites'] = sites
protein_additional_data_1['Sequence'] = sequence

# %%
protein_additional_data_1
# Out:
#     Chromosome Accession Version      Organism  \
# 0           21    XP_006723962.1  Homo sapiens
# 1           21    XP_011544381.1  Homo sapiens
# 2           21    XP_011544380.1  Homo sapiens
# 3           21    NP_001350699.1  Homo sapiens
# 4           21    NP_001350689.1  Homo sapiens
# ..         ...               ...           ...
# 195         21    XP_024307892.1  Homo sapiens
# 196         21    NP_001003701.1  Homo sapiens
# 197         21    NP_001003697.1  Homo sapiens
# 198         21    NP_001003696.1  Homo sapiens
# 199         21    NP_001307196.1  Homo sapiens
#
#                                             Definition Division Topology  \
# 0                ICOS ligand isoform X1 [Homo sapiens]      PRI   linear
# 1                ICOS ligand isoform X3 [Homo sapiens]      PRI   linear
# 2                ICOS ligand isoform X2 [Homo sapiens]      PRI   linear
# 3                 ICOS ligand precursor [Homo sapiens]      PRI   linear
# 4    glutamine amidotransferase-like class 1 domain...      PRI   linear
# ..                                                 ...      ...      ...
# 195  junctional adhesion molecule B isoform X1 [Hom...      PRI   linear
# 196  ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
# 197  ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
# 198  ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
# 199  ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
#
#     Molecule Type Molecular Weight  Number of Regions  \
# 0              AA            56181                  2
# 1              AA            33350                  2
# 2              AA            39507                  2
# 3              AA            31389                  2
# 4              AA            24598                  1
# ..            ...              ...                ...
# 195            AA            22874                  2
# 196            AA            13257                  1
# 197            AA             8960                  1
# 198            AA             8960                  1
# 199            AA            12456                  1
#
#      Number of Binding Sites  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          1
# ..                       ...
# 195                        0
# 196                        0
# 197                        9
# 198                        9
# 199                        9
#
#                                               Sequence
# 0    mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 1    mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 2    mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 3    mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 4    maavralvasrlaaasaftslspggrtpsqraalhlsvprpaarva...
# ..                                                 ...
# 195  midfniriknvtrsdagkyrcevsapseqgqnleedtvtlevlvap...
# 196  mhcdggismilqrlfrfssvirsavsvhlrrnigvtavafnkeldp...
# 197  milqrlfrfssvirsavsvhlrrnigvtavafnkeldpiqklfvdk...
# 198  milqrlfrfssvirsavsvhlrrnigvtavafnkeldpiqklfvdk...
# 199  milqrlfrfssvirsavsvhlrrnigvtavafnkeldpiqklfvdk...
#
# [200 rows x 11 columns]

# %%
import time
time.sleep(10)

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[200:400]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_2 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_2['Chromosome'] = chromosome
protein_additional_data_2['Accession Version'] = accession_version
protein_additional_data_2['Organism'] = organism
protein_additional_data_2['Definition'] = definition
protein_additional_data_2['Division'] = division
protein_additional_data_2['Topology'] = topology
protein_additional_data_2['Molecule Type'] = moltype
protein_additional_data_2['Molecular Weight'] = molar_weight
protein_additional_data_2['Number of Regions'] = regions
protein_additional_data_2['Number of Binding Sites'] = sites
protein_additional_data_2['Sequence'] = sequence

# %%
protein_additional_data_2
# Out:
#     Chromosome Accession Version      Organism  \
# 0           21       NP_001676.2  Homo sapiens
# 1           21    NP_001307195.1  Homo sapiens
# 2           21    NP_001003703.1  Homo sapiens
# 3           21    XP_005260995.1  Homo sapiens
# 4           21    NP_001184226.1  Homo sapiens
# ..         ...               ...           ...
# 195         21       NP_037461.2  Homo sapiens
# 196         21    XP_011528106.1  Homo sapiens
# 197         21    NP_001155967.2  Homo sapiens
# 198         21       NP_062542.5  Homo sapiens
# 199         21    NP_001155968.2  Homo sapiens
#
#                                             Definition Division Topology  \
# 0    ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
# 1    ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
# 2    ATP synthase-coupling factor 6, mitochondrial ...      PRI   linear
# 3    GA-binding protein alpha chain isoform X1 [Hom...      PRI   linear
# 4        GA-binding protein alpha chain [Homo sapiens]      PRI   linear
# ..                                                 ...      ...      ...
# 195  PAX3- and PAX7-binding protein 1 isoform 2 [Ho...      PRI   linear
# 196  PAX3- and PAX7-binding protein 1 isoform X2 [H...      PRI   linear
# 197  uncharacterized protein C21orf62 precursor [Ho...      PRI   linear
# 198  uncharacterized protein C21orf62 precursor [Ho...      PRI   linear
# 199  uncharacterized protein C21orf62 precursor [Ho...      PRI   linear
#
#     Molecule Type Molecular Weight  Number of Regions  \
# 0              AA             8960                  1
# 1              AA            12456                  1
# 2              AA             8960                  1
# 3              AA            51164                  3
# 4              AA            51164                  3
# ..            ...              ...                ...
# 195            AA            93040                  2
# 196            AA            73726                  1
# 197            AA            22843                  1
# 198            AA            22843                  1
# 199            AA            22843                  1
#
#      Number of Binding Sites  \
# 0                          9
# 1                          9
# 2                          9
# 3                          0
# 4                          1
# ..                       ...
# 195                       10
# 196                        0
# 197                        0
# 198                        0
# 199                        0
#
#                                               Sequence
# 0    milqrlfrfssvirsavsvhlrrnigvtavafnkeldpiqklfvdk...
# 1    milqrlfrfssvirsavsvhlrrnigvtavafnkeldpiqklfvdk...
# 2    milqrlfrfssvirsavsvhlrrnigvtavafnkeldpiqklfvdk...
# 3    mtkreaeelieieidgtekaecteesiveqtyapaecvsqaidine...
# 4    mtkreaeelieieidgtekaecteesiveqtyapaecvsqaidine...
# ..                                                 ...
# 195  mfrkarrvnvrkrndseeeererdeeqepppllpppgtgeeagpgg...
# 196  mfrkarrvnvrkrndseeeererdeeqepppllpppgtgeeagpgg...
# 197  mappsrhclllistlgvfalncftkgqknstliftrentirncscs...
# 198  mappsrhclllistlgvfalncftkgqknstliftrentirncscs...
# 199  mappsrhclllistlgvfalncftkgqknstliftrentirncscs...
#
# [200 rows x 11 columns]

# %%
time.sleep(10)

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[400:600]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_3 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_3['Chromosome'] = chromosome
protein_additional_data_3['Accession Version'] = accession_version
protein_additional_data_3['Organism'] = organism
protein_additional_data_3['Definition'] = definition
protein_additional_data_3['Division'] = division
protein_additional_data_3['Topology'] = topology
protein_additional_data_3['Molecule Type'] = moltype
protein_additional_data_3['Molecular Weight'] = molar_weight
protein_additional_data_3['Number of Regions'] = regions
protein_additional_data_3['Number of Binding Sites'] = sites
protein_additional_data_3['Sequence'] = sequence

# %%
protein_additional_data_3
# Out:
#     Chromosome Accession Version      Organism  \
# 0           21    XP_011527955.1  Homo sapiens
# 1           21       NP_005797.1  Homo sapiens
# 2           21    XP_005260965.1  Homo sapiens
# 3           21       NP_620450.2  Homo sapiens
# 4           21       NP_000865.2  Homo sapiens
# ..         ...               ...           ...
# 195         21    XP_006724040.1  Homo sapiens
# 196         21    XP_016883773.1  Homo sapiens
# 197         21    NP_001334650.1  Homo sapiens
# 198         21       NP_001387.2  Homo sapiens
# 199         21    XP_006724039.1  Homo sapiens
#
#                                             Definition Division Topology  \
# 0    uncharacterized protein C21orf62 isoform X1 [H...      PRI   linear
# 1    oligodendrocyte transcription factor 2 [Homo s...      PRI   linear
# 2    oligodendrocyte transcription factor 2 isoform...      PRI   linear
# 3    oligodendrocyte transcription factor 1 [Homo s...      PRI   linear
# 4    interferon alpha/beta receptor 2 isoform b [Ho...      PRI   linear
# ..                                                 ...      ...      ...
# 195  dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 196  dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 197  dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 198  dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 199  dual specificity tyrosine-phosphorylation-regu...      PRI   linear
#
#     Molecule Type Molecular Weight  Number of Regions  \
# 0              AA            11529                  0
# 1              AA            32254                  1
# 2              AA            32254                  1
# 3              AA            27774                  1
# 4              AA            37262                  3
# ..            ...              ...                ...
# 195            AA            85453                  1
# 196            AA            84426                  1
# 197            AA            84426                  2
# 198            AA            85453                  2
# 199            AA            85453                  1
#
#      Number of Binding Sites  \
# 0                          0
# 1                          3
# 2                          3
# 3                          3
# 4                          0
# ..                       ...
# 195                        4
# 196                        4
# 197                       20
# 198                       20
# 199                        4
#
#                                               Sequence
# 0    mrlvgqqlppgchgndqaagppkteknskcktthstlacrlnqlss...
# 1    mdsdaslvssrpsspepddlflparskgssgsaftggtvssstpsd...
# 2    mdsdaslvssrpsspepddlflparskgssgsaftggtvssstpsd...
# 3    myyavsqarvnavpgtmlrpqrpgdlqlgaslyelvgyrqppssss...
# 4    mllsqnafifrslnlvlmvyislvfgisydspdytdesctfkislr...
# ..                                                 ...
# 195  mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 196  mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 197  mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 198  mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 199  mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
#
# [200 rows x 11 columns]

# %%
time.sleep(10)

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[600:800]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_4 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_4['Chromosome'] = chromosome
protein_additional_data_4['Accession Version'] = accession_version
protein_additional_data_4['Organism'] = organism
protein_additional_data_4['Definition'] = definition
protein_additional_data_4['Division'] = division
protein_additional_data_4['Topology'] = topology
protein_additional_data_4['Molecule Type'] = moltype
protein_additional_data_4['Molecular Weight'] = molar_weight
protein_additional_data_4['Number of Regions'] = regions
protein_additional_data_4['Number of Binding Sites'] = sites
protein_additional_data_4['Sequence'] = sequence

# %%
protein_additional_data_4
# Out:
#     Chromosome Accession Version      Organism  \
# 0           21    XP_011527785.1  Homo sapiens
# 1           21       NP_569120.1  Homo sapiens
# 2           21       NP_567824.1  Homo sapiens
# 3           21       NP_569122.1  Homo sapiens
# 4           21    XP_006724041.1  Homo sapiens
# ..         ...               ...           ...
# 195         21       NP_004906.3  Homo sapiens
# 196         21       NP_058198.2  Homo sapiens
# 197         21    XP_011528109.1  Homo sapiens
# 198         21       NP_997057.1  Homo sapiens
# 199         21    XP_011528108.1  Homo sapiens
#
#                                             Definition Division Topology  \
# 0    dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 1    dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 2    dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 3    dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# 4    dual specificity tyrosine-phosphorylation-regu...      PRI   linear
# ..                                                 ...      ...      ...
# 195  ATP-binding cassette sub-family G member 1 iso...      PRI   linear
# 196  ATP-binding cassette sub-family G member 1 iso...      PRI   linear
# 197  ATP-binding cassette sub-family G member 1 iso...      PRI   linear
# 198  ATP-binding cassette sub-family G member 1 iso...      PRI   linear
# 199  ATP-binding cassette sub-family G member 1 iso...      PRI   linear
#
#     Molecule Type Molecular Weight  Number of Regions  \
# 0              AA            85453                  1
# 1              AA            84426                  2
# 2              AA            65968                  2
# 3              AA            60199                  2
# 4              AA            85453                  1
# ..            ...              ...                ...
# 195            AA            75461                  3
# 196            AA            74024                  3
# 197            AA            70746                  3
# 198            AA            75250                  3
# 199            AA            76687                  3
#
#      Number of Binding Sites  \
# 0                          4
# 1                         20
# 2                          4
# 3                         16
# 4                          4
# ..                       ...
# 195                       13
# 196                       13
# 197                        7
# 198                        7
# 199                        7
#
#                                               Sequence
# 0    mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 1    mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 2    mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 3    mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# 4    mhtggetsackpssvrlapsfsfhaaglqmagqmphshqysdrrqp...
# ..                                                 ...
# 195  maclmaafsvgtamnassysaemtepksvcvsvdevvssnmeatet...
# 196  maclmaafsvgtamnassysaemtepksvcvsvdevvssnmeatet...
# 197  mrislpraperdggvsasslldtvtnassysaemtepksvcvsvde...
# 198  mrislpraperdggvsasslldtvtnassysaemtepksvcvsvde...
# 199  mrislpraperdggvsasslldtvtnassysaemtepksvcvsvde...
#
# [200 rows x 11 columns]

# %%
time.sleep(10)

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[800:1000]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_5 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_5['Chromosome'] = chromosome
protein_additional_data_5['Accession Version'] = accession_version
protein_additional_data_5['Organism'] = organism
protein_additional_data_5['Definition'] = definition
protein_additional_data_5['Division'] = division
protein_additional_data_5['Topology'] = topology
protein_additional_data_5['Molecule Type'] = moltype
protein_additional_data_5['Molecular Weight'] = molar_weight
protein_additional_data_5['Number of Regions'] = regions
protein_additional_data_5['Number of Binding Sites'] = sites
protein_additional_data_5['Sequence'] = sequence

# %%
protein_additional_data_5
# Out:
#     Chromosome Accession Version      Organism  \
# 0           21       NP_997511.1  Homo sapiens
# 1           21    XP_024307909.1  Homo sapiens
# 2           21       NP_003217.3  Homo sapiens
# 3           21       NP_005414.1  Homo sapiens
# 4           21       NP_003216.1  Homo sapiens
# ..         ...               ...           ...
# 195         21    XP_024307828.1  Homo sapiens
# 196         21    XP_011527817.1  Homo sapiens
# 197         21       NP_037501.2  Homo sapiens
# 198         21       NP_787063.1  Homo sapiens
# 199         21       NP_000374.1  Homo sapiens
#
#                                             Definition Division Topology  \
# 0    ATP-binding cassette sub-family G member 1 iso...      PRI   linear
# 1    ATP-binding cassette sub-family G member 1 iso...      PRI   linear
# 2            trefoil factor 3 precursor [Homo sapiens]      PRI   linear
# 3            trefoil factor 2 precursor [Homo sapiens]      PRI   linear
# 4            trefoil factor 1 precursor [Homo sapiens]      PRI   linear
# ..                                                 ...      ...      ...
# 195              ICOS ligand isoform X1 [Homo sapiens]      PRI   linear
# 196              ICOS ligand isoform X3 [Homo sapiens]      PRI   linear
# 197  DNA (cytosine-5)-methyltransferase 3-like isof...      PRI   linear
# 198  DNA (cytosine-5)-methyltransferase 3-like isof...      PRI   linear
# 199                autoimmune regulator [Homo sapiens]      PRI   linear
#
#     Molecule Type Molecular Weight  Number of Regions  \
# 0              AA            71829                  3
# 1              AA            86625                  1
# 2              AA             6581                  1
# 3              AA            11990                  2
# 4              AA             6674                  1
# ..            ...              ...                ...
# 195            AA            51794                  2
# 196            AA            33350                  2
# 197            AA            43539                  1
# 198            AA            43452                  1
# 199            AA            57596                 12
#
#      Number of Binding Sites  \
# 0                          7
# 1                          0
# 2                          2
# 3                          4
# 4                          2
# ..                       ...
# 195                        0
# 196                        0
# 197                        2
# 198                        2
# 199                        4
#
#                                               Sequence
# 0    mtepksvcvsvdevvssnmeatetdllnghlkkvdnnlteaqrfss...
# 1    mvrrgwsvctaillarlwclvpthtflseypeaaeyphpgwvywlq...
# 2    mkrvlscvpeptvvmaaralcmlglvlallssssaeeyvglsanqc...
# 3    mgrrdaqllaallvlglcalagsekpspcqcsrlsphnrtncgfpg...
# 4    matmenkvicalvlvsmlalgtlaeaqtetctvaprerqncgfpgv...
# ..                                                 ...
# 195  mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 196  mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 197  maaipaldpeaepsmdvilvgsselsssvspgtgrdliayevkanq...
# 198  maaipaldpeaepsmdvilvgsselsssvspgtgrdliayevkanq...
# 199  matdaalrrllrlhrteiavavdsafpllhaladhdvvpedkfqet...
#
# [200 rows x 11 columns]

# %%
time.sleep(10)

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[1000:1200]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_6 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_6['Chromosome'] = chromosome
protein_additional_data_6['Accession Version'] = accession_version
protein_additional_data_6['Organism'] = organism
protein_additional_data_6['Definition'] = definition
protein_additional_data_6['Division'] = division
protein_additional_data_6['Topology'] = topology
protein_additional_data_6['Molecule Type'] = moltype
protein_additional_data_6['Molecular Weight'] = molar_weight
protein_additional_data_6['Number of Regions'] = regions
protein_additional_data_6['Number of Binding Sites'] = sites
protein_additional_data_6['Sequence'] = sequence

# %%
protein_additional_data_6
# Out:
#     Chromosome Accession Version      Organism  \
# 0           21       NP_002617.3  Homo sapiens
# 1           21    XP_005261192.1  Homo sapiens
# 2           21    NP_001002021.2  Homo sapiens
# 3           21    XP_016883857.1  Homo sapiens
# 4           21    XP_006724074.1  Homo sapiens
# ..         ...               ...           ...
# 195         21    XP_005261245.1  Homo sapiens
# 196         21    NP_001138908.1  Homo sapiens
# 197         21       NP_002331.3  Homo sapiens
# 198         21    NP_001001438.1  Homo sapiens
# 199         21    NP_001138909.1  Homo sapiens
#
#                                             Definition Division Topology  \
# 0    ATP-dependent 6-phosphofructokinase, liver typ...      PRI   linear
# 1    ATP-dependent 6-phosphofructokinase, liver typ...      PRI   linear
# 2    ATP-dependent 6-phosphofructokinase, liver typ...      PRI   linear
# 3    ATP-dependent 6-phosphofructokinase, liver typ...      PRI   linear
# 4    ATP-dependent 6-phosphofructokinase, liver typ...      PRI   linear
# ..                                                 ...      ...      ...
# 195   speriolin-like protein isoform X1 [Homo sapiens]      PRI   linear
# 196       lanosterol synthase isoform 2 [Homo sapiens]      PRI   linear
# 197       lanosterol synthase isoform 1 [Homo sapiens]      PRI   linear
# 198       lanosterol synthase isoform 1 [Homo sapiens]      PRI   linear
# 199       lanosterol synthase isoform 3 [Homo sapiens]      PRI   linear
#
#     Molecule Type Molecular Weight  Number of Regions  \
# 0              AA            84888                 10
# 1              AA            87546                  2
# 2              AA            90447                  1
# 3              AA            93105                  2
# 4              AA            93105                  2
# ..            ...              ...                ...
# 195            AA            37482                  2
# 196            AA            82068                  8
# 197            AA            83178                  9
# 198            AA            83178                  9
# 199            AA            74087                  2
#
#      Number of Binding Sites  \
# 0                          5
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 195                        0
# 196                        3
# 197                        3
# 198                        3
# 199                        2
#
#                                               Sequence
# 0    maavdleklrasgagkaigvltsggdaqgmnaavravtrmgiyvga...
# 1    maavdleklrasgagkaigvltsggdaqgmnaavravtrmgiyvga...
# 2    mrsmcnqgrgressrgglhvqgscrglsrspqqetgfakapagtdc...
# 3    mrsmcnqgrgressrgglhvqgscrglsrspqqetgfakapagtdc...
# 4    mrsmcnqgrgressrgglhvqgscrglsrspqqetgfakapagtdc...
# ..                                                 ...
# 195  maeggelmsrllsenadlkkqvrllkenqmlrrllsqscqeggghd...
# 196  mtegtclrrrggpyktepatdlgrwrlncergrqtwtylqderagr...
# 197  mtegtclrrrggpyktepatdlgrwrlncergrqtwtylqderagr...
# 198  mtegtclrrrggpyktepatdlgrwrlncergrqtwtylqderagr...
# 199  mtfyvglqaedghwtgdyggplfllpgllitchvariplpagyree...
#
# [200 rows x 11 columns]

# %%
time.sleep(10)

# %%
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
id_list = protein_accession_numbers[1200:1287]
search_results = Entrez.read(Entrez.epost("protein", id=",".join(id_list)))

# %%
webenv = search_results["WebEnv"]
query_key = search_results["QueryKey"]

# %%
results = Entrez.read(Entrez.efetch(db="protein", webenv=webenv, query_key=query_key, retmode='xml'))

# %%
protein_additional_data_7 = pd.DataFrame()
accession_version = []
definition = []
division = []
topology = []
moltype = []
organism = []
sequence = []
chromosome = []
molar_weight = []
regions = []
sites = []
for i in results:
    region = 0
    site = 0
    accession_version.append(i['GBSeq_accession-version'])
    organism.append(i['GBSeq_organism'])
    definition.append(i['GBSeq_definition'])
    division.append(i['GBSeq_division'])
    topology.append(i['GBSeq_topology'])
    moltype.append(i['GBSeq_moltype'])
    sequence.append(i['GBSeq_sequence'])
    if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
        chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
    else:
        continue
    if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
        if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
        elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
            molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
        else:
            print('add more elif statements')
    else:
        continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
            region += 1
        else:
            continue
    for j in range(0, len(i['GBSeq_feature-table'])):
        if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
            site += 1
        else:
            continue
    regions.append(region)
    sites.append(site)
protein_additional_data_7['Chromosome'] = chromosome
protein_additional_data_7['Accession Version'] = accession_version
protein_additional_data_7['Organism'] = organism
protein_additional_data_7['Definition'] = definition
protein_additional_data_7['Division'] = division
protein_additional_data_7['Topology'] = topology
protein_additional_data_7['Molecule Type'] = moltype
protein_additional_data_7['Molecular Weight'] = molar_weight
protein_additional_data_7['Number of Regions'] = regions
protein_additional_data_7['Number of Binding Sites'] = sites
protein_additional_data_7['Sequence'] = sequence

# %%
protein_additional_data_7
# Out:
#    Chromosome Accession Version      Organism  \
# 0          21    XP_005261261.1  Homo sapiens
# 1          21    XP_005261260.1  Homo sapiens
# 2          21       NP_003897.2  Homo sapiens
# 3          21    XP_005261262.1  Homo sapiens
# 4          21    XP_011527936.2  Homo sapiens
# ..        ...               ...           ...
# 81         21    NP_001273607.1  Homo sapiens
# 82         21       NP_001526.2  Homo sapiens
# 83         21    XP_006724061.1  Homo sapiens
# 84         21    NP_001229795.1  Homo sapiens
# 85         21    NP_001229794.1  Homo sapiens
#
#                                            Definition Division Topology  \
# 0   germinal-center associated nuclear protein iso...      PRI   linear
# 1   germinal-center associated nuclear protein iso...      PRI   linear
# 2   germinal-center associated nuclear protein [Ho...      PRI   linear
# 3   germinal-center associated nuclear protein iso...      PRI   linear
# 4     endoribonuclease YbeY isoform X4 [Homo sapiens]      PRI   linear
# ..                                                ...      ...      ...
# 81  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 82  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 83  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 84  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 85  protein arginine N-methyltransferase 2 isoform...      PRI   linear
#
#    Molecule Type Molecular Weight  Number of Regions  Number of Binding Sites  \
# 0             AA           218275                  5                        0
# 1             AA           218275                  5                        0
# 2             AA           218275                 12                        7
# 3             AA           218275                  5                        0
# 4             AA            33333                  0                        0
# ..           ...              ...                ...                      ...
# 81            AA            25363                  3                        4
# 82            AA            48911                  6                        4
# 83            AA            33412                  2                        2
# 84            AA            31062                  5                        4
# 85            AA            31031                  3                        4
#
#                                              Sequence
# 0   mnptnpfsgqqpsafsasssnvgtlpskppfrfgqpslfgqnstls...
# 1   mnptnpfsgqqpsafsasssnvgtlpskppfrfgqpslfgqnstls...
# 2   mnptnpfsgqqpsafsasssnvgtlpskppfrfgqpslfgqnstls...
# 3   mnptnpfsgqqpsafsasssnvgtlpskppfrfgqpslfgqnstls...
# 4   mwrpgraelrggrkrrpwrrpsphahrlapgprgprcplaprkdlr...
# ..                                                ...
# 81  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 82  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 83  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 84  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 85  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
#
# [86 rows x 11 columns]

# %%
time.sleep(10)

# %%
to_concat = [protein_additional_data_1, protein_additional_data_2, protein_additional_data_3, protein_additional_data_4, 
           protein_additional_data_5, protein_additional_data_6, protein_additional_data_7]

# %%
protein_additional_data = pd.concat(to_concat)

# %%
protein_additional_data
# Out:
#    Chromosome Accession Version      Organism  \
# 0          21    XP_006723962.1  Homo sapiens
# 1          21    XP_011544381.1  Homo sapiens
# 2          21    XP_011544380.1  Homo sapiens
# 3          21    NP_001350699.1  Homo sapiens
# 4          21    NP_001350689.1  Homo sapiens
# ..        ...               ...           ...
# 81         21    NP_001273607.1  Homo sapiens
# 82         21       NP_001526.2  Homo sapiens
# 83         21    XP_006724061.1  Homo sapiens
# 84         21    NP_001229795.1  Homo sapiens
# 85         21    NP_001229794.1  Homo sapiens
#
#                                            Definition Division Topology  \
# 0               ICOS ligand isoform X1 [Homo sapiens]      PRI   linear
# 1               ICOS ligand isoform X3 [Homo sapiens]      PRI   linear
# 2               ICOS ligand isoform X2 [Homo sapiens]      PRI   linear
# 3                ICOS ligand precursor [Homo sapiens]      PRI   linear
# 4   glutamine amidotransferase-like class 1 domain...      PRI   linear
# ..                                                ...      ...      ...
# 81  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 82  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 83  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 84  protein arginine N-methyltransferase 2 isoform...      PRI   linear
# 85  protein arginine N-methyltransferase 2 isoform...      PRI   linear
#
#    Molecule Type Molecular Weight  Number of Regions  Number of Binding Sites  \
# 0             AA            56181                  2                        0
# 1             AA            33350                  2                        0
# 2             AA            39507                  2                        0
# 3             AA            31389                  2                        0
# 4             AA            24598                  1                        1
# ..           ...              ...                ...                      ...
# 81            AA            25363                  3                        4
# 82            AA            48911                  6                        4
# 83            AA            33412                  2                        2
# 84            AA            31062                  5                        4
# 85            AA            31031                  3                        4
#
#                                              Sequence
# 0   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 1   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 2   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 3   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# 4   maavralvasrlaaasaftslspggrtpsqraalhlsvprpaarva...
# ..                                                ...
# 81  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 82  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 83  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 84  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# 85  matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
#
# [1286 rows x 11 columns]

# %%
dna_data_21 = dna_data[dna_data['RefSeq-Accn']=='NC_000021.9']
dna_data_21
# Out:
#    # Sequence-Name       Sequence-Role Assigned-Molecule  \
# 41              21  assembled-molecule                21
#
#    Assigned-Molecule-Location/Type GenBank-Accn Relationship  RefSeq-Accn  \
# 41                      Chromosome   CM000683.2            =  NC_000021.9
#
#        Assembly-Unit  Sequence-Length UCSC-style-name
# 41  Primary Assembly       46709983.0           chr21

# %%
protein_data_21 = protein_data[protein_data['Replicon Accession']=='NC_000021.9']
protein_data_21.index=protein_data_21['Protein product']
protein_data_21
# Out:
#                 #Replicon Name Replicon Accession     Start      Stop Strand  \
# Protein product
# XP_006723962.1              21        NC_000021.9   5022680   5034096      +
# XP_011544381.1              21        NC_000021.9   5022680   5034096      +
# XP_011544380.1              21        NC_000021.9   5022680   5045606      +
# NP_001350699.1              21        NC_000021.9   5022680   5034592      +
# NP_001350689.1              21        NC_000021.9   5117103   5128354      -
# ...                        ...                ...       ...       ...    ...
# NP_001273607.1              21        NC_000021.9  46636952  46664327      +
# NP_001526.2                 21        NC_000021.9  46636952  46664327      +
# XP_006724061.1              21        NC_000021.9  46636952  46664374      +
# NP_001229795.1              21        NC_000021.9  46636952  46658924      +
# NP_001229794.1              21        NC_000021.9  46636952  46652006      +
#
#                     GeneID         Locus Protein product  Length  \
# Protein product
# XP_006723962.1   102723996  LOC102723996  XP_006723962.1     516
# XP_011544381.1   102723996  LOC102723996  XP_011544381.1     304
# XP_011544380.1   102723996  LOC102723996  XP_011544380.1     361
# NP_001350699.1   102723996  LOC102723996  NP_001350699.1     302
# NP_001350689.1   102724023        GATD3B  NP_001350689.1     237
# ...                    ...           ...             ...     ...
# NP_001273607.1        3275         PRMT2  NP_001273607.1     228
# NP_001526.2           3275         PRMT2     NP_001526.2     433
# XP_006724061.1        3275         PRMT2  XP_006724061.1     301
# NP_001229795.1        3275         PRMT2  NP_001229795.1     277
# NP_001229794.1        3275         PRMT2  NP_001229794.1     284
#
#                                                       Protein name
# Protein product
# XP_006723962.1                              ICOS ligand isoform X1
# XP_011544381.1                              ICOS ligand isoform X3
# XP_011544380.1                              ICOS ligand isoform X2
# NP_001350699.1                               ICOS ligand precursor
# NP_001350689.1   glutamine amidotransferase-like class 1 domain...
# ...                                                            ...
# NP_001273607.1    protein arginine N-methyltransferase 2 isoform 7
# NP_001526.2       protein arginine N-methyltransferase 2 isoform 1
# XP_006724061.1   protein arginine N-methyltransferase 2 isoform X2
# NP_001229795.1    protein arginine N-methyltransferase 2 isoform 4
# NP_001229794.1    protein arginine N-methyltransferase 2 isoform 3
#
# [1286 rows x 10 columns]

# %%
protein_additional_data_21 = protein_additional_data
protein_additional_data_21.index = protein_additional_data_21['Accession Version']
protein_additional_data_21
# Out:
#                   Chromosome Accession Version      Organism  \
# Accession Version
# XP_006723962.1            21    XP_006723962.1  Homo sapiens
# XP_011544381.1            21    XP_011544381.1  Homo sapiens
# XP_011544380.1            21    XP_011544380.1  Homo sapiens
# NP_001350699.1            21    NP_001350699.1  Homo sapiens
# NP_001350689.1            21    NP_001350689.1  Homo sapiens
# ...                      ...               ...           ...
# NP_001273607.1            21    NP_001273607.1  Homo sapiens
# NP_001526.2               21       NP_001526.2  Homo sapiens
# XP_006724061.1            21    XP_006724061.1  Homo sapiens
# NP_001229795.1            21    NP_001229795.1  Homo sapiens
# NP_001229794.1            21    NP_001229794.1  Homo sapiens
#
#                                                           Definition Division  \
# Accession Version
# XP_006723962.1                 ICOS ligand isoform X1 [Homo sapiens]      PRI
# XP_011544381.1                 ICOS ligand isoform X3 [Homo sapiens]      PRI
# XP_011544380.1                 ICOS ligand isoform X2 [Homo sapiens]      PRI
# NP_001350699.1                  ICOS ligand precursor [Homo sapiens]      PRI
# NP_001350689.1     glutamine amidotransferase-like class 1 domain...      PRI
# ...                                                              ...      ...
# NP_001273607.1     protein arginine N-methyltransferase 2 isoform...      PRI
# NP_001526.2        protein arginine N-methyltransferase 2 isoform...      PRI
# XP_006724061.1     protein arginine N-methyltransferase 2 isoform...      PRI
# NP_001229795.1     protein arginine N-methyltransferase 2 isoform...      PRI
# NP_001229794.1     protein arginine N-methyltransferase 2 isoform...      PRI
#
#                   Topology Molecule Type Molecular Weight  Number of Regions  \
# Accession Version
# XP_006723962.1      linear            AA            56181                  2
# XP_011544381.1      linear            AA            33350                  2
# XP_011544380.1      linear            AA            39507                  2
# NP_001350699.1      linear            AA            31389                  2
# NP_001350689.1      linear            AA            24598                  1
# ...                    ...           ...              ...                ...
# NP_001273607.1      linear            AA            25363                  3
# NP_001526.2         linear            AA            48911                  6
# XP_006724061.1      linear            AA            33412                  2
# NP_001229795.1      linear            AA            31062                  5
# NP_001229794.1      linear            AA            31031                  3
#
#                    Number of Binding Sites  \
# Accession Version
# XP_006723962.1                           0
# XP_011544381.1                           0
# XP_011544380.1                           0
# NP_001350699.1                           0
# NP_001350689.1                           1
# ...                                    ...
# NP_001273607.1                           4
# NP_001526.2                              4
# XP_006724061.1                           2
# NP_001229795.1                           4
# NP_001229794.1                           4
#
#                                                             Sequence
# Accession Version
# XP_006723962.1     mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# XP_011544381.1     mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# XP_011544380.1     mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# NP_001350699.1     mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# NP_001350689.1     maavralvasrlaaasaftslspggrtpsqraalhlsvprpaarva...
# ...                                                              ...
# NP_001273607.1     matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# NP_001526.2        matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# XP_006724061.1     matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# NP_001229795.1     matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# NP_001229794.1     matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
#
# [1286 rows x 11 columns]

# %%
all_protein_data_21 = protein_data_21.join(protein_additional_data_21)
all_protein_data_21
# Out:
#                 #Replicon Name Replicon Accession     Start      Stop Strand  \
# Protein product
# XP_006723962.1              21        NC_000021.9   5022680   5034096      +
# XP_011544381.1              21        NC_000021.9   5022680   5034096      +
# XP_011544380.1              21        NC_000021.9   5022680   5045606      +
# NP_001350699.1              21        NC_000021.9   5022680   5034592      +
# NP_001350689.1              21        NC_000021.9   5117103   5128354      -
# ...                        ...                ...       ...       ...    ...
# NP_001273607.1              21        NC_000021.9  46636952  46664327      +
# NP_001526.2                 21        NC_000021.9  46636952  46664327      +
# XP_006724061.1              21        NC_000021.9  46636952  46664374      +
# NP_001229795.1              21        NC_000021.9  46636952  46658924      +
# NP_001229794.1              21        NC_000021.9  46636952  46652006      +
#
#                     GeneID         Locus Protein product  Length  \
# Protein product
# XP_006723962.1   102723996  LOC102723996  XP_006723962.1     516
# XP_011544381.1   102723996  LOC102723996  XP_011544381.1     304
# XP_011544380.1   102723996  LOC102723996  XP_011544380.1     361
# NP_001350699.1   102723996  LOC102723996  NP_001350699.1     302
# NP_001350689.1   102724023        GATD3B  NP_001350689.1     237
# ...                    ...           ...             ...     ...
# NP_001273607.1        3275         PRMT2  NP_001273607.1     228
# NP_001526.2           3275         PRMT2     NP_001526.2     433
# XP_006724061.1        3275         PRMT2  XP_006724061.1     301
# NP_001229795.1        3275         PRMT2  NP_001229795.1     277
# NP_001229794.1        3275         PRMT2  NP_001229794.1     284
#
#                                                       Protein name  ...  \
# Protein product                                                     ...
# XP_006723962.1                              ICOS ligand isoform X1  ...
# XP_011544381.1                              ICOS ligand isoform X3  ...
# XP_011544380.1                              ICOS ligand isoform X2  ...
# NP_001350699.1                               ICOS ligand precursor  ...
# NP_001350689.1   glutamine amidotransferase-like class 1 domain...  ...
# ...                                                            ...  ...
# NP_001273607.1    protein arginine N-methyltransferase 2 isoform 7  ...
# NP_001526.2       protein arginine N-methyltransferase 2 isoform 1  ...
# XP_006724061.1   protein arginine N-methyltransferase 2 isoform X2  ...
# NP_001229795.1    protein arginine N-methyltransferase 2 isoform 4  ...
# NP_001229794.1    protein arginine N-methyltransferase 2 isoform 3  ...
#
#                 Accession Version      Organism  \
# Protein product
# XP_006723962.1     XP_006723962.1  Homo sapiens
# XP_011544381.1     XP_011544381.1  Homo sapiens
# XP_011544380.1     XP_011544380.1  Homo sapiens
# NP_001350699.1     NP_001350699.1  Homo sapiens
# NP_001350689.1     NP_001350689.1  Homo sapiens
# ...                           ...           ...
# NP_001273607.1     NP_001273607.1  Homo sapiens
# NP_001526.2           NP_001526.2  Homo sapiens
# XP_006724061.1     XP_006724061.1  Homo sapiens
# NP_001229795.1     NP_001229795.1  Homo sapiens
# NP_001229794.1     NP_001229794.1  Homo sapiens
#
#                                                         Definition Division  \
# Protein product
# XP_006723962.1               ICOS ligand isoform X1 [Homo sapiens]      PRI
# XP_011544381.1               ICOS ligand isoform X3 [Homo sapiens]      PRI
# XP_011544380.1               ICOS ligand isoform X2 [Homo sapiens]      PRI
# NP_001350699.1                ICOS ligand precursor [Homo sapiens]      PRI
# NP_001350689.1   glutamine amidotransferase-like class 1 domain...      PRI
# ...                                                            ...      ...
# NP_001273607.1   protein arginine N-methyltransferase 2 isoform...      PRI
# NP_001526.2      protein arginine N-methyltransferase 2 isoform...      PRI
# XP_006724061.1   protein arginine N-methyltransferase 2 isoform...      PRI
# NP_001229795.1   protein arginine N-methyltransferase 2 isoform...      PRI
# NP_001229794.1   protein arginine N-methyltransferase 2 isoform...      PRI
#
#                 Topology Molecule Type Molecular Weight Number of Regions  \
# Protein product
# XP_006723962.1    linear            AA            56181                 2
# XP_011544381.1    linear            AA            33350                 2
# XP_011544380.1    linear            AA            39507                 2
# NP_001350699.1    linear            AA            31389                 2
# NP_001350689.1    linear            AA            24598                 1
# ...                  ...           ...              ...               ...
# NP_001273607.1    linear            AA            25363                 3
# NP_001526.2       linear            AA            48911                 6
# XP_006724061.1    linear            AA            33412                 2
# NP_001229795.1    linear            AA            31062                 5
# NP_001229794.1    linear            AA            31031                 3
#
#                  Number of Binding Sites  \
# Protein product
# XP_006723962.1                         0
# XP_011544381.1                         0
# XP_011544380.1                         0
# NP_001350699.1                         0
# NP_001350689.1                         1
# ...                                  ...
# NP_001273607.1                         4
# NP_001526.2                            4
# XP_006724061.1                         2
# NP_001229795.1                         4
# NP_001229794.1                         4
#
#                                                           Sequence
# Protein product
# XP_006723962.1   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# XP_011544381.1   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# XP_011544380.1   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# NP_001350699.1   mrlgspgllfllfsslradtqekevramvgsdvelscacpegsrfd...
# NP_001350689.1   maavralvasrlaaasaftslspggrtpsqraalhlsvprpaarva...
# ...                                                            ...
# NP_001273607.1   matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# NP_001526.2      matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# XP_006724061.1   matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# NP_001229795.1   matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
# NP_001229794.1   matsgdcprsesqgeepaecseagllqegvqpeefvaiadyaatde...
#
# [1286 rows x 21 columns]

# %%
import pickle
all_protein_data_21.to_csv('all_protein_data_21.csv')

# %% [markdown]
# References
# Stephen F. Altschul, Thomas L. Madden, Alejandro A. Schäffer, Jinghui Zhang, Zheng Zhang, Webb Miller, and David J. Lipman (1997), "Gapped BLAST and PSI-BLAST: a new generation of protein database search programs", Nucleic Acids Res. 25:3389-3402.
# https://towardsdatascience.com/processing-xml-in-python-elementtree-c8992941efd2 # processing xml data
# https://stackoverflow.com/questions/10220412/convert-tab-delimited-txt-file-into-a-csv-file-using-python # import of a text file
# https://www.ncbi.nlm.nih.gov/assembly/model/
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.39_GRCh38.p13/GCF_000001405.39_GRCh38.p13_assembly_report.txt # dna data
# https://www.ncbi.nlm.nih.gov/genomes/Genome2BE/genome2srv.cgi?action=GetFeatures4Grid&amp;download=on&amp;type=Proteins&amp;genome_id=51&genome_assembly_id=582967&mode=2&is_locus=1&is_locus_tag=0&optcols=1,0,0,0,0 # protein data
# https://blast.ncbi.nlm.nih.gov/Blast.cgi?CMD=Web&PAGE_TYPE=BlastDocs&DOC_TYPE=References
# https://www.ncbi.nlm.nih.gov/pubmed/20003500?dopt=Citation # paper for the creation of blast+
# https://www.ncbi.nlm.nih.gov/books/NBK52637/ # stand alone blast+ set up for pc
# ftp://ftp.ncbi.nlm.nih.gov/blast/db/ # data base location
# http://seqanswers.com/forums/showthread.php?t=44370 # troubleshooting database set up
# https://widdowquinn.github.io/2018-03-06-ibioic/02-sequence_databases/03-programming_for_blast.html # python/blast+ integration
# http://biopython.org/DIST/docs/tutorial/Tutorial.pdf # use of entrez package for online searches using api
# https://www.ncbi.nlm.nih.gov/books/NBK25499/
