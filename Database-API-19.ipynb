# %% [markdown]
# # Table of Contents<a id='Table of Contents'></a>
#
# <a href='#Obtain General Data'>**1. Obtain General Data**</a>
#
# <a href='#Obtain DNA Data'>**2. Obtain DNA Data**</a>
#
# <a href='#Obtain Protein Data'>**3. Obtain Protein Data</a>
#
# <a href='#dna+protein'>3.1 DNA and Protein Data Join Compatability
#
# <a href='#Obtain Sequence Data'>**4. Obtain Protein Sequence Data</a>
#
# <a href='#Join Data'>**5. Join Data**</a>
#
# <a href='#References'>**6. References**</a>
#
# <a href='#Future Work'>**7. Future Work**</a>

# %% [markdown]
# # Obtain General Data<a id='Obtain General Data'></a>

# %%
# parse txt dna input from Assembly Report into csv format
import csv
txt_file_dna = r"GCF_000001405.39_GRCh38.p13_assembly_report.txt"
csv_file_dna = r"GCF_000001405.39_GRCh38.p13_assembly_report.csv"
in_txt_dna = csv.reader(open(txt_file_dna, "r", encoding='utf-8'), delimiter = '\t')
out_csv_dna = csv.writer(open(csv_file_dna, 'w'))
out_csv_dna.writerows(in_txt_dna)

# %%
# read in csv dna unique identifers for this entire project
import pandas as pd
to_skip_info = []
for i in range(34,1406):
    to_skip_info.append(i)
information_about_dna_data = pd.read_csv('GCF_000001405.39_GRCh38.p13_assembly_report_fixed.csv', skiprows=(to_skip_info), header=0)
pd.DataFrame(information_about_dna_data['Assembly name:  GRCh38.p13'].dropna(axis=0))
# Out:
#                            Assembly name:  GRCh38.p13
# 1   Description:    Genome Reference Consortium Hu...
# 3                Organism name:  Homo sapiens (human)
# 5                                Taxid:          9606
# 7                          BioProject:     PRJNA31257
# 9         Submitter:      Genome Reference Consortium
# 11                         Date:           2019-02-28
# 13              Assembly type:  haploid-with-alt-loci
# 15                              Release type:   patch
# 17                         Assembly level: Chromosome
# 19                        Genome representation: full
# 21                  RefSeq category: Reference Genome
# 23       GenBank assembly accession: GCA_000001405.28
# 25        RefSeq assembly accession: GCF_000001405.39
# 27  RefSeq assembly and GenBank assemblies identic...
# 31                                    Assembly-Units:

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents</a>

# %% [markdown]
# # Obtain DNA Data<a id='Obtain DNA Data'></a>

# %%
# read in csv dna data to study for this project
dna_data = pd.read_csv('GCF_000001405.39_GRCh38.p13_assembly_report_fixed.csv', header=124)
dna_data = dna_data.dropna(axis=0)

# %%
# ensure proper loading of csv dna data
dna_data.sample(10)
# Out:
#               # Sequence-Name         Sequence-Role Assigned-Molecule  \
# 267        HSCHRUN_RANDOM_118     unplaced-scaffold                na
# 669           HSCHR17_12_CTG4           novel-patch                17
# 573              HG2111_PATCH             fix-patch                11
# 51    HSCHR1_CTG2_UNLOCALIZED  unlocalized-scaffold                 1
# 983            HSCHR13_1_CTG1          alt-scaffold                13
# 1209      HSCHR6_MHC_QBL_CTG1          alt-scaffold                 6
# 595              HG1398_PATCH             fix-patch                12
# 299        HSCHRUN_RANDOM_136     unplaced-scaffold                na
# 167        HSCHRUN_RANDOM_107     unplaced-scaffold                na
# 283        HSCHRUN_RANDOM_125     unplaced-scaffold                na
#
#      Assigned-Molecule-Location/Type GenBank-Accn Relationship  \
# 267                               na   KI270424.1            =
# 669                       Chromosome   KZ559114.1            =
# 573                       Chromosome   ML143360.1            =
# 51                        Chromosome   KI270707.1            =
# 983                       Chromosome   KI270838.1            =
# 1209                      Chromosome   GL000255.2            =
# 595                       Chromosome   ML143362.1            =
# 299                               na   KI270512.1            =
# 167                               na   KI270316.1            =
# 283                               na   KI270466.1            =
#
#          RefSeq-Accn     Assembly-Unit  Sequence-Length  \
# 267      NT_187414.1  Primary Assembly           2140.0
# 669   NW_019805501.1           PATCHES         116753.0
# 573   NW_021160006.1           PATCHES         170928.0
# 51       NT_187362.1  Primary Assembly          32032.0
# 983      NT_187592.1    ALT_REF_LOCI_1         306913.0
# 1209     NT_167248.2    ALT_REF_LOCI_6        4606388.0
# 595   NW_021160008.1           PATCHES         192531.0
# 299      NT_187432.1  Primary Assembly          22689.0
# 167      NT_187403.1  Primary Assembly           1444.0
# 283      NT_187421.1  Primary Assembly           1233.0
#
#              UCSC-style-name
# 267         chrUn_KI270424v1
# 669                       na
# 573                       na
# 51    chr1_KI270707v1_random
# 983     chr13_KI270838v1_alt
# 1209     chr6_GL000255v2_alt
# 595                       na
# 299         chrUn_KI270512v1
# 167         chrUn_KI270316v1
# 283         chrUn_KI270466v1

# %%
# check dna data datatypes
dna_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 1 to 1279
# Data columns (total 10 columns):
# # Sequence-Name                    640 non-null object
# Sequence-Role                      640 non-null object
# Assigned-Molecule                  640 non-null object
# Assigned-Molecule-Location/Type    640 non-null object
# GenBank-Accn                       640 non-null object
# Relationship                       640 non-null object
# RefSeq-Accn                        640 non-null object
# Assembly-Unit                      640 non-null object
# Sequence-Length                    640 non-null float64
# UCSC-style-name                    640 non-null object
# dtypes: float64(1), object(9)
# memory usage: 55.0+ KB

# %%
# check length of dna dataset
len(dna_data)
# Out:
# 640

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents</a>

# %% [markdown]
# # Obtain Protein Data<a id='Obtain Protein Data'></a>

# %% [markdown]
# From the same https://www.ncbi.nlm.nih.gov/assembly/GCF_000001405.39/ page, under genome information, https://www.ncbi.nlm.nih.gov/genome/?term=txid9606[orgn], and in the Genome Assembly and Annotation report, https://www.ncbi.nlm.nih.gov/genome/genomes/51?, in the protein section at https://www.ncbi.nlm.nih.gov/genome/proteins/51?genome_assembly_id=582967, a comprehensive report of human proteins can be found.

# %%
# parse txt protein input from Assembly Report into csv format
txt_file_protein = r"ProteinTable51_582967.txt"
csv_file_protein = r"ProteinTable51_582967.csv"
in_txt_protein = csv.reader(open(txt_file_protein, "r"), delimiter = '\t')
out_csv_protein = csv.writer(open(csv_file_protein, 'w'))
out_csv_protein.writerows(in_txt_protein)

# %%
# read csv protein data
protein_data = pd.read_csv('ProteinTable51_582967.csv')
protein_data.sample(10)
# Out:
#        #Replicon Name Replicon Accession      Start       Stop Strand  GeneID  \
# 77326              12       NC_000012.12   55986961   55992212      +    5869
# 53293               7       NC_000007.14  152094228  152105387      +   63917
# 99576              17       NC_000017.11   79944093   79950761      -  125058
# 47032               6       NC_000006.12  127119193  127192684      +   84870
# 100358             18       NC_000018.10    8707140    8831840      +   23255
# 109160             20       NC_000020.11    3908171    3923294      +   80025
# 21580               2       NC_000002.12  113628607  113642129      +   11159
# 32613               3       NC_000003.12  183650357  183679286      +   54800
# 97276              17       NC_000017.11   44708821   44749361      +   80174
# 113280             22       NC_000022.11   21383859   21388778      +  440804
#
#           Locus Protein product  Length  \
# 77326     RAB5B  NP_001238966.1     174
# 53293   GALNT11  NP_001358401.1     242
# 99576   TBC1D16  NP_001258775.1     278
# 47032     RSPO3  XP_016866867.1     224
# 100358    MTCL1  XP_016881160.1    1766
# 109160    PANK2     NP_079236.3     279
# 21580    RABL2A  NP_001341347.1     175
# 32613    KLHL24  NP_001336350.1     600
# 97276     DBF4B  XP_016880636.1     720
# 113280  RIMBP3B  NP_001122107.1    1639
#
#                                              Protein name
# 77326                ras-related protein Rab-5B isoform 2
# 53293   polypeptide N-acetylgalactosaminyltransferase ...
# 99576              TBC1 domain family member 16 isoform d
# 47032                              R-spondin-3 isoform X1
# 100358     microtubule cross-linking factor 1 isoform X17
# 109160     pantothenate kinase 2, mitochondrial isoform 2
# 21580                       rab-like protein 2A isoform 7
# 32613                     kelch-like protein 24 isoform b
# 97276                   protein DBF4 homolog B isoform X3
# 113280                            RIMS-binding protein 3B

# %%
# check protein data datatypes
protein_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119489 entries, 0 to 119488
# Data columns (total 10 columns):
# #Replicon Name        119489 non-null object
# Replicon Accession    119489 non-null object
# Start                 119489 non-null int64
# Stop                  119489 non-null int64
# Strand                119489 non-null object
# GeneID                119489 non-null int64
# Locus                 119489 non-null object
# Protein product       119489 non-null object
# Length                119489 non-null int64
# Protein name          119489 non-null object
# dtypes: int64(4), object(6)
# memory usage: 9.1+ MB

# %%
# check length of protein dataset
len(protein_data)
# Out:
# 119489

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents</a>

# %% [markdown]
# ## DNA and Protein Data Join Compatability<a id='dna+protein'></a>

# %% [markdown]
# The protein and dna information is related through the RefSeq-Accn column on the dna_data table and the Replicon Accession column on the protein_data table. The two cells below show that many types of protein information is stored in chromosomes.

# %%
# dna data
dna_data[dna_data['RefSeq-Accn'] == 'NC_000001.11']
# Out:
#   # Sequence-Name       Sequence-Role Assigned-Molecule  \
# 1               1  assembled-molecule                 1
#
#   Assigned-Molecule-Location/Type GenBank-Accn Relationship   RefSeq-Accn  \
# 1                      Chromosome   CM000663.2            =  NC_000001.11
#
#       Assembly-Unit  Sequence-Length UCSC-style-name
# 1  Primary Assembly      248956422.0            chr1

# %%
# protein data
protein_data[protein_data['Replicon Accession']== 'NC_000001.11']
# Out:
#       #Replicon Name Replicon Accession      Start       Stop Strand  \
# 6542               1       NC_000001.11      69091      70008      +
# 6543               1       NC_000001.11     358067     399100      -
# 6544               1       NC_000001.11     358153     399100      -
# 6545               1       NC_000001.11     450740     451678      -
# 6546               1       NC_000001.11     586839     611297      -
# ...              ...                ...        ...        ...    ...
# 17623              1       NC_000001.11  248913863  248918363      +
# 17624              1       NC_000001.11  248913863  248918363      +
# 17625              1       NC_000001.11  248913863  248918363      +
# 17626              1       NC_000001.11  248914552  248918363      +
# 17627              1       NC_000001.11  248917338  248918363      +
#
#           GeneID         Locus Protein product  Length  \
# 6542       79501         OR4F5  NP_001005484.1     305
# 6543   112268260  LOC112268260  XP_024307731.1     152
# 6544   112268260  LOC112268260  XP_024307730.1     166
# 6545      729759        OR4F29  NP_001005221.2     312
# 6546   105378947  LOC105378947  XP_011540840.1     750
# ...          ...           ...             ...     ...
# 17623     267002         PGBD2  XP_011542463.1     592
# 17624     267002         PGBD2  XP_011542461.1     592
# 17625     267002         PGBD2     NP_733843.1     592
# 17626     267002         PGBD2  XP_005270390.1     589
# 17627     267002         PGBD2  NP_001017434.1     341
#
#                                             Protein name
# 6542                              olfactory receptor 4F5
# 6543     uncharacterized protein LOC112268260 isoform X2
# 6544     uncharacterized protein LOC112268260 isoform X1
# 6545                    olfactory receptor 4F3/4F16/4F29
# 6546             proline-rich extensin-like protein EPR1
# ...                                                  ...
# 17623  piggyBac transposable element-derived protein ...
# 17624  piggyBac transposable element-derived protein ...
# 17625  piggyBac transposable element-derived protein ...
# 17626  piggyBac transposable element-derived protein ...
# 17627  piggyBac transposable element-derived protein ...
#
# [11086 rows x 10 columns]

# %% [markdown]
# The protein data shown is stored in the dna data above. The dna data serves as non-unique identification for the protein data.

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents</a>

# %% [markdown]
# # Obtain Protien Sequence Data<a id='Obtain Sequence Data'></a>
#
# <a href='#decision'>Jump to Decision about Chromosome to Study</a>
#
# <a href='api prep'>Jump to API Preperation</a>
#
# <a href='#api pull'>Jump to API Pull</a>

# %%
# load api key
import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)
keys = get_keys("/Users/eannefawcett/.secret/ncbi_api.json")
api_key = keys['api_key']

# %%
# connect with server
from Bio import Entrez
Entrez.api_key = api_key
Entrez.email = 'elizabethfawcett47@gmail.com'
Entrez.tool = 'locus_by_amino_acid'
handle = Entrez.einfo()
result = handle.read()
handle.close()

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents</a>

# %% [markdown]
# ## Decision about Chromosome to Study<a id='decision'></a>
#
# <a href='#Protein evaluation'>Jump to Protein Evaluation</a>
#
# <a href='#Loci evaluation'>Jump to Loci Evaluation</a>
#
# <a href='#Chromosome evaluation'>Jump to Chromosome Evaluation</a>
#
# <a href='#Obtain Sequence Data'>Back to section Obtain Protein Sequence Data</a>
#
# <a href='#Table of Contents'>Back to Table of Contents</a>

# %% [markdown]
# ### Protein evaluation<a id='Protein evaluation'></a>

# %%
# generate dataframe that compares chromosomes to number of proteins present on chromosome
decision_about_chromosome = pd.DataFrame()
accession_numbers = dna_data['RefSeq-Accn'].unique()
number_of_proteins = []
for accession_number in accession_numbers:
    number_of_proteins.append(len(protein_data[protein_data['Replicon Accession']==accession_number]))
decision_about_chromosome['Accession Number'] = accession_numbers
decision_about_chromosome['Number of Proteins'] = number_of_proteins

# %%
# view chromosomes with more than 5000 proteins
decision_about_chromosome[decision_about_chromosome['Number of Proteins'] >= 5000]
# Out:
#    Accession Number  Number of Proteins
# 0      NC_000001.11               11086
# 1      NC_000002.12                8442
# 2      NC_000003.12                7198
# 5      NC_000006.12                5618
# 6      NC_000007.14                5212
# 9      NC_000010.11                5420
# 10     NC_000011.10                6710
# 11     NC_000012.12                5957
# 16     NC_000017.11                6096
# 18     NC_000019.10                6702

# %% [markdown]
# <a href='#decision'>Back to subsection Decision about Chromosome to Study</a>
#
# <a href='#Obtain Sequence Data'>Back to section Obtain Protein Sequence Data</a>
#
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# ### Loci evaluation<a id='Loci evaluation'></a>

# %%
# generate dataframe that compares loci to the number present
decision_about_locuses = pd.DataFrame()
locus_ids = protein_data['Locus'].unique()
number_of_locuses = []
for locus_id in locus_ids:
    number_of_locuses.append(len(protein_data[protein_data['Locus']==locus_id]))
decision_about_locuses['Locus'] = locus_ids
decision_about_locuses['Number of Locuses'] = number_of_locuses

# %%
# view loci with more than 50 occurances
locuses_of_interest = list(decision_about_locuses[decision_about_locuses['Number of Locuses'] >= 50]['Locus'])
locuses_of_interest
# Out:
# ['ZNF311',
#  'MOG',
#  'DDR1',
#  'LST1',
#  'BAG6',
#  'AGER',
#  'KIR3DL2',
#  'KIR2DL4',
#  'KIR2DS2',
#  'RBFOX2',
#  'KIR2DS4',
#  'FCAR',
#  'NCR1',
#  'OSCAR',
#  'RPS9',
#  'NLRP2',
#  'HNRNPH1',
#  'TPK1',
#  'CACNA1C',
#  'TNNT3',
#  'PEX5',
#  'EIF4G3',
#  'EPB41',
#  'SGIP1',
#  'PDE4DIP',
#  'ESRRG',
#  'DTNB',
#  'MAP4K4',
#  'GTDC1',
#  'ABI2',
#  'MAP2',
#  'TRIP12',
#  'CLASP2',
#  'ARPP21',
#  'LRRFIP2',
#  'PBRM1',
#  'SLMAP',
#  'PXK',
#  'CADPS',
#  'ABI3BP',
#  'NEK11',
#  'ZBTB38',
#  'MBNL1',
#  'MAPK10',
#  'ANK2',
#  'SORBS2',
#  'RIMS1',
#  'SNAP91',
#  'SUN1',
#  'COA1',
#  'NRCAM',
#  'PCM1',
#  'ST18',
#  'ASPH',
#  'RIMS2',
#  'CYRIB',
#  'PTK2',
#  'PTPRD',
#  'CELF2',
#  'CCDC7',
#  'CREM',
#  'PTPN20',
#  'ANK3',
#  'CAMK2G',
#  'KCNMA1',
#  'SORBS1',
#  'NT5C2',
#  'ABLIM1',
#  'NUCB2',
#  'PAX6',
#  'PHF21A',
#  'ATG13',
#  'MADD',
#  'CELF1',
#  'PPP6R3',
#  'DLG2',
#  'CAPRIN2',
#  'R3HDM2',
#  'PPFIA2',
#  'VEZT',
#  'ANKS1B',
#  'RGS6',
#  'WDR20',
#  'RBFOX1',
#  'ADGRG1',
#  'EPB41L3',
#  'CELF4',
#  'MBD1',
#  'TCF4',
#  'CARD8',
#  'TANGO2',
#  'ASCC2',
#  'PPP6R2',
#  'UTY']

# %%
# number of loci with greater than 50 occurances
len(locuses_of_interest)
# Out:
# 94

# %%
# generate list of accession numbers for protein data that include these loci with greater than 50 occurances
proteins_for_locuses_of_interest = []
for i in locuses_of_interest:
    for j, k in enumerate(protein_data['Locus']):
        if i == k:
            proteins_for_locuses_of_interest.append(protein_data.loc[j, 'Replicon Accession'])
proteins_for_locuses_of_interest
# Out:
# ['NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167245.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_113891.3',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167244.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167246.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167247.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167248.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NT_167249.2',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NC_000006.12',
#  'NT_113949.2',
#  'NT_113949.2',
#  'NT_187636.1',
#  'NT_187636.1',
#  'NT_187637.1',
#  'NT_187637.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187639.1',
#  'NT_187639.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187641.1',
#  'NT_187641.1',
#  'NT_187642.1',
#  'NT_187642.1',
#  'NT_187643.1',
#  'NT_187643.1',
#  'NT_187644.1',
#  'NT_187644.1',
#  'NT_187645.1',
#  'NT_187645.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187669.1',
#  'NT_187669.1',
#  'NT_187670.1',
#  'NT_187670.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187673.1',
#  'NT_187673.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187684.1',
#  'NT_187684.1',
#  'NT_187685.1',
#  'NT_187685.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NT_187687.1',
#  'NT_187687.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571059.2',
#  'NW_003571059.2',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_016107300.1',
#  'NW_016107300.1',
#  'NW_016107301.1',
#  'NW_016107301.1',
#  'NW_016107302.1',
#  'NW_016107302.1',
#  'NW_016107303.1',
#  'NW_016107303.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107305.1',
#  'NW_016107305.1',
#  'NW_016107306.1',
#  'NW_016107306.1',
#  'NW_016107307.1',
#  'NW_016107307.1',
#  'NW_016107308.1',
#  'NW_016107308.1',
#  'NW_016107309.1',
#  'NW_016107309.1',
#  'NW_016107310.1',
#  'NW_016107310.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107313.1',
#  'NW_016107313.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NT_113949.2',
#  'NT_113949.2',
#  'NT_187636.1',
#  'NT_187636.1',
#  'NT_187637.1',
#  'NT_187637.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187639.1',
#  'NT_187639.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187641.1',
#  'NT_187641.1',
#  'NT_187642.1',
#  'NT_187642.1',
#  'NT_187643.1',
#  'NT_187643.1',
#  'NT_187644.1',
#  'NT_187644.1',
#  'NT_187645.1',
#  'NT_187645.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187669.1',
#  'NT_187669.1',
#  'NT_187670.1',
#  'NT_187670.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187672.1',
#  'NT_187672.1',
#  'NT_187673.1',
#  'NT_187673.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187684.1',
#  'NT_187684.1',
#  'NT_187685.1',
#  'NT_187685.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NT_187687.1',
#  'NT_187687.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_016107300.1',
#  'NW_016107300.1',
#  'NW_016107300.1',
#  'NW_016107301.1',
#  'NW_016107301.1',
#  'NW_016107301.1',
#  'NW_016107302.1',
#  'NW_016107302.1',
#  'NW_016107302.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107305.1',
#  'NW_016107305.1',
#  'NW_016107305.1',
#  'NW_016107306.1',
#  'NW_016107306.1',
#  'NW_016107306.1',
#  'NW_016107307.1',
#  'NW_016107307.1',
#  'NW_016107307.1',
#  'NW_016107309.1',
#  'NW_016107309.1',
#  'NW_016107309.1',
#  'NW_016107310.1',
#  'NW_016107310.1',
#  'NW_016107310.1',
#  'NW_016107313.1',
#  'NW_016107313.1',
#  'NW_016107313.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NT_113949.2',
#  'NT_113949.2',
#  'NT_113949.2',
#  'NT_113949.2',
#  'NT_113949.2',
#  'NT_187636.1',
#  'NT_187636.1',
#  'NT_187636.1',
#  'NT_187636.1',
#  'NT_187636.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187642.1',
#  'NT_187642.1',
#  'NT_187642.1',
#  'NT_187642.1',
#  'NT_187642.1',
#  'NT_187644.1',
#  'NT_187644.1',
#  'NT_187644.1',
#  'NT_187644.1',
#  'NT_187644.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187670.1',
#  'NT_187670.1',
#  'NT_187670.1',
#  'NT_187670.1',
#  'NT_187670.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NW_003571056.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NT_187630.1',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NC_000022.11',
#  'NT_187637.1',
#  'NT_187637.1',
#  'NT_187638.1',
#  'NT_187638.1',
#  'NT_187639.1',
#  'NT_187640.1',
#  'NT_187640.1',
#  'NT_187642.1',
#  'NT_187643.1',
#  'NT_187645.1',
#  'NT_187668.1',
#  'NT_187668.1',
#  'NT_187669.1',
#  'NT_187671.1',
#  'NT_187673.1',
#  'NT_187673.1',
#  'NT_187674.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187683.1',
#  'NT_187684.1',
#  'NT_187684.1',
#  'NT_187685.1',
#  'NT_187686.1',
#  'NT_187686.1',
#  'NT_187687.1',
#  'NT_187687.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571060.1',
#  'NW_016107300.1',
#  'NW_016107300.1',
#  'NW_016107300.1',
#  'NW_016107301.1',
#  'NW_016107301.1',
#  'NW_016107301.1',
#  'NW_016107302.1',
#  'NW_016107302.1',
#  'NW_016107302.1',
#  'NW_016107305.1',
#  'NW_016107305.1',
#  'NW_016107305.1',
#  'NW_016107306.1',
#  'NW_016107306.1',
#  'NW_016107306.1',
#  'NW_016107307.1',
#  'NW_016107307.1',
#  'NW_016107307.1',
#  'NW_016107309.1',
#  'NW_016107309.1',
#  'NW_016107309.1',
#  'NW_016107313.1',
#  'NW_016107313.1',
#  'NW_016107313.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NW_016107314.1',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187671.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187674.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187675.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187676.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187677.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187683.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571059.2',
#  'NW_003571059.2',
#  'NW_003571059.2',
#  'NW_003571059.2',
#  'NW_003571059.2',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571060.1',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_003571061.2',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107304.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NW_016107312.1',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NC_000019.10',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NT_187693.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571054.1',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571055.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571056.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571057.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  'NW_003571058.2',
#  ...]

# %%
# number of accession numbers from protein data
len(proteins_for_locuses_of_interest)
# Out:
# 5983

# %%
# see unique accession numbers from protein data
proteins_of_interest = pd.DataFrame()
proteins_of_interest['Proteins'] = proteins_for_locuses_of_interest
proteins_of_interest['Proteins'].unique()
# Out:
# array(['NT_113891.3', 'NT_167244.2', 'NT_167245.2', 'NT_167246.2',
#        'NT_167248.2', 'NT_167249.2', 'NC_000006.12', 'NT_167247.2',
#        'NT_113949.2', 'NT_187636.1', 'NT_187637.1', 'NT_187638.1',
#        'NT_187639.1', 'NT_187640.1', 'NT_187641.1', 'NT_187642.1',
#        'NT_187643.1', 'NT_187644.1', 'NT_187645.1', 'NT_187668.1',
#        'NT_187669.1', 'NT_187670.1', 'NT_187671.1', 'NT_187673.1',
#        'NT_187674.1', 'NT_187675.1', 'NT_187676.1', 'NT_187677.1',
#        'NT_187683.1', 'NT_187684.1', 'NT_187685.1', 'NT_187686.1',
#        'NT_187687.1', 'NT_187693.1', 'NW_003571055.2', 'NW_003571056.2',
#        'NW_003571057.2', 'NW_003571058.2', 'NW_003571059.2',
#        'NW_003571060.1', 'NW_016107300.1', 'NW_016107301.1',
#        'NW_016107302.1', 'NW_016107303.1', 'NW_016107304.1',
#        'NW_016107305.1', 'NW_016107306.1', 'NW_016107307.1',
#        'NW_016107308.1', 'NW_016107309.1', 'NW_016107310.1',
#        'NW_016107312.1', 'NW_016107313.1', 'NW_016107314.1',
#        'NC_000019.10', 'NT_187672.1', 'NW_003571061.2', 'NT_187630.1',
#        'NC_000022.11', 'NW_003571054.1', 'NW_016107298.1', 'NC_000005.10',
#        'NW_018654715.1', 'NC_000007.14', 'NW_018654718.1', 'NC_000012.12',
#        'NW_021160004.1', 'NC_000011.10', 'NW_021160008.1', 'NC_000001.11',
#        'NC_000002.12', 'NC_000003.12', 'NC_000004.12', 'NC_000008.11',
#        'NC_000009.12', 'NC_000010.11', 'NC_000014.9', 'NC_000016.10',
#        'NC_000018.10', 'NC_000024.10'], dtype=object)

# %% [markdown]
# <a href='#decision'>Back to subsection Decision about Chromosome to Study</a>
#
# <a href='#Obtain Sequence Data'>Back to section Obtain Protein Sequence Data</a>
#
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# ### Chromosome evaluation<a id='Chromosome evaluation'></a>

# %%
# see chromosome for unique accession numbers from protein data
proteins_of_interest_list = proteins_of_interest['Proteins'].unique()
chromosomes = []
for protein in proteins_of_interest_list:
    for j, k in enumerate(dna_data['RefSeq-Accn']):
        if protein == k:
            chromosomes.append(dna_data.loc[dna_data[dna_data['RefSeq-Accn']==k].index[0], 'Assigned-Molecule'])
chromosomes
# Out:
# ['6',
#  '6',
#  '6',
#  '6',
#  '6',
#  '6',
#  '6',
#  '6',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '22',
#  '22',
#  '19',
#  '5',
#  '5',
#  '7',
#  '7',
#  '12',
#  '12',
#  '11',
#  '11',
#  '12',
#  '1',
#  '2',
#  '3',
#  '4',
#  '8',
#  '9',
#  '10',
#  '14',
#  '16',
#  '18',
#  'Y']

# %%
# see highest count for chromosome
chromosomes_of_interest = pd.DataFrame()
chromosomes_of_interest['Chromosomes'] = chromosomes
chromosomes_of_interest['Chromosomes'].value_counts().nlargest(1)
# Out:
# 19    48
# Name: Chromosomes, dtype: int64

# %% [markdown]
# <a href='#decision'>Back to subsection Decision about Chromosome to Study</a>
#
# <a href='#Obtain Sequence Data'>Back to section Obtain Protein Sequence Data</a>
#
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# ## API Preperation<a id='api prep'></a>

# %%
# pull dna data for chromosome 19
selected_dna_data = dna_data[dna_data['Assigned-Molecule'] == chromosomes_of_interest['Chromosomes'].value_counts().nlargest(1).index[0]]
selected_dna_data
# Out:
#                      # Sequence-Name       Sequence-Role Assigned-Molecule  \
# 37                                19  assembled-molecule                19
# 681                     HG2021_PATCH           fix-patch                19
# 683                       HG26_PATCH           fix-patch                19
# 685                      HG109_PATCH           fix-patch                19
# 687    HSCHR19KIR_0019-4656-A_CTG3_1         novel-patch                19
# ...                              ...                 ...               ...
# 1267  HSCHR19KIR_FH08_BAX_HAP_CTG3_1        alt-scaffold                19
# 1269    HSCHR19KIR_FH13_A_HAP_CTG3_1        alt-scaffold                19
# 1271  HSCHR19KIR_FH13_BA2_HAP_CTG3_1        alt-scaffold                19
# 1273    HSCHR19KIR_FH15_A_HAP_CTG3_1        alt-scaffold                19
# 1275     HSCHR19KIR_RP5_B_HAP_CTG3_1        alt-scaffold                19
#
#      Assigned-Molecule-Location/Type GenBank-Accn Relationship  \
# 37                        Chromosome   CM000681.2            =
# 681                       Chromosome   KN196484.1            =
# 683                       Chromosome   KQ458386.1            =
# 685                       Chromosome   ML143376.1            =
# 687                       Chromosome   KV575246.1            =
# ...                              ...          ...          ...
# 1267                      Chromosome   KI270930.1            =
# 1269                      Chromosome   KI270931.1            =
# 1271                      Chromosome   KI270932.1            =
# 1273                      Chromosome   KI270933.1            =
# 1275                      Chromosome   GL000209.2            =
#
#          RefSeq-Accn     Assembly-Unit  Sequence-Length       UCSC-style-name
# 37      NC_000019.10  Primary Assembly       58617616.0                 chr19
# 681   NW_009646206.1           PATCHES         370917.0                    na
# 683   NW_014040929.1           PATCHES         405389.0                    na
# 685   NW_021160022.1           PATCHES         493165.0                    na
# 687   NW_016107300.1           PATCHES         163926.0                    na
# ...              ...               ...              ...                   ...
# 1267     NT_187684.1   ALT_REF_LOCI_31         200773.0  chr19_KI270930v1_alt
# 1269     NT_187685.1   ALT_REF_LOCI_32         170148.0  chr19_KI270931v1_alt
# 1271     NT_187686.1   ALT_REF_LOCI_33         215732.0  chr19_KI270932v1_alt
# 1273     NT_187687.1   ALT_REF_LOCI_34         170537.0  chr19_KI270933v1_alt
# 1275     NT_113949.2   ALT_REF_LOCI_35         177381.0  chr19_GL000209v2_alt
#
# [62 rows x 10 columns]

# %%
# pull protein data for chromosome 19
selected_accession_numbers = selected_dna_data['RefSeq-Accn']
selected_protein_dataframes = []
for accession_number in selected_accession_numbers:
    selected_protein_dataframes.append(protein_data[protein_data['Replicon Accession'] == accession_number])
selected_protein_dataframes[0]
# Out:
#        #Replicon Name Replicon Accession     Start      Stop Strand  GeneID  \
# 102114             19       NC_000019.10    110679    111596      +   81099
# 102115             19       NC_000019.10    281388    291336      -    8612
# 102116             19       NC_000019.10    281388    291066      -    8612
# 102117             19       NC_000019.10    281388    288055      -    8612
# 102118             19       NC_000019.10    281388    291336      -    8612
# ...               ...                ...       ...       ...    ...     ...
# 108811             19       NC_000019.10  58562072  58572632      -    7593
# 108812             19       NC_000019.10  58562072  58573296      -    7593
# 108813             19       NC_000019.10  58562072  58571389      -    7593
# 108814             19       NC_000019.10  58562072  58563424      -    7593
# 108815             19       NC_000019.10  58563160  58571389      -    7593
#
#          Locus Protein product  Length                           Protein name
# 102114  OR4F17  NP_001005240.1     305                olfactory receptor 4F17
# 102115   PLPP2  XP_011526698.1     294  phospholipid phosphatase 2 isoform X1
# 102116   PLPP2     NP_808211.1     309   phospholipid phosphatase 2 isoform 3
# 102117   PLPP2     NP_803545.1     232   phospholipid phosphatase 2 isoform 2
# 102118   PLPP2     NP_003703.1     288   phospholipid phosphatase 2 isoform 1
# ...        ...             ...     ...                                    ...
# 108811    MZF1  XP_024307457.1     775       myeloid zinc finger 1 isoform X1
# 108812    MZF1  XP_011525566.1     764       myeloid zinc finger 1 isoform X2
# 108813    MZF1     NP_003413.2     734        myeloid zinc finger 1 isoform 1
# 108814    MZF1  XP_016882695.1     450       myeloid zinc finger 1 isoform X3
# 108815    MZF1  NP_001253962.1     290        myeloid zinc finger 1 isoform 2
#
# [6702 rows x 10 columns]

# %%
# stitch together selected protein data after data evaluation
selected_protein_data = pd.concat(selected_protein_dataframes)
selected_protein_data.head()
# Out:
#        #Replicon Name Replicon Accession   Start    Stop Strand  GeneID  \
# 102114             19       NC_000019.10  110679  111596      +   81099
# 102115             19       NC_000019.10  281388  291336      -    8612
# 102116             19       NC_000019.10  281388  291066      -    8612
# 102117             19       NC_000019.10  281388  288055      -    8612
# 102118             19       NC_000019.10  281388  291336      -    8612
#
#          Locus Protein product  Length                           Protein name
# 102114  OR4F17  NP_001005240.1     305                olfactory receptor 4F17
# 102115   PLPP2  XP_011526698.1     294  phospholipid phosphatase 2 isoform X1
# 102116   PLPP2     NP_808211.1     309   phospholipid phosphatase 2 isoform 3
# 102117   PLPP2     NP_803545.1     232   phospholipid phosphatase 2 isoform 2
# 102118   PLPP2     NP_003703.1     288   phospholipid phosphatase 2 isoform 1

# %%
# check to see if this will be enough data to study
proteins_to_study = []
for protein in selected_protein_dataframes:
    for j in protein['Protein product']:
        proteins_to_study.append(j)
len(proteins_to_study)
# Out:
# 7981

# %%
# preparing batches to contact database
batch_01 = proteins_to_study[0:200]
batch_02 = proteins_to_study[200:400]
batch_03 = proteins_to_study[400:600]
batch_04 = proteins_to_study[600:800]
batch_05 = proteins_to_study[800:1000]
batch_06 = proteins_to_study[1000:1200]
batch_07 = proteins_to_study[1200:1400]
batch_08 = proteins_to_study[1400:1600]
batch_09 = proteins_to_study[1600:1800]
batch_10 = proteins_to_study[1800:2000]
batch_11 = proteins_to_study[2000:2200]
batch_12 = proteins_to_study[2200:2400]
batch_13 = proteins_to_study[2400:2600]
batch_14 = proteins_to_study[2600:2800]
batch_15 = proteins_to_study[2800:3000]
batch_16 = proteins_to_study[3000:3200]
batch_17 = proteins_to_study[3200:3400]
batch_18 = proteins_to_study[3400:3600]
batch_19 = proteins_to_study[3600:3800]
batch_20 = proteins_to_study[3800:4000]
batch_21 = proteins_to_study[4000:4200]
batch_22 = proteins_to_study[4200:4400]
batch_23 = proteins_to_study[4400:4600]
batch_24 = proteins_to_study[4600:4800]
batch_25 = proteins_to_study[4800:5000]
batch_26 = proteins_to_study[5000:5200]
batch_27 = proteins_to_study[5200:5400]
batch_28 = proteins_to_study[5400:5600]
batch_29 = proteins_to_study[5600:5800]
batch_30 = proteins_to_study[5800:6000]
batch_31 = proteins_to_study[6000:6200]
batch_32 = proteins_to_study[6200:6400]
batch_33 = proteins_to_study[6400:6600]
batch_34 = proteins_to_study[6600:6800]
batch_35 = proteins_to_study[6800:7000]
batch_36 = proteins_to_study[7000:7200]
batch_37 = proteins_to_study[7200:7400]
batch_38 = proteins_to_study[7400:7600]
batch_39 = proteins_to_study[7600:7800]
batch_40 = proteins_to_study[7800:7982]

# %%
# list of batches prepared
batches = [batch_01, batch_02, batch_03, batch_04, batch_05, batch_06, batch_07, batch_08, batch_09,
           batch_10, batch_11, batch_12, batch_13, batch_14, batch_15, batch_16, batch_17, batch_18,
           batch_19, batch_20, batch_21, batch_22, batch_23, batch_24, batch_25, batch_26, batch_27,
           batch_28, batch_29, batch_30, batch_31, batch_32, batch_33, batch_34, batch_35, batch_36,
           batch_37, batch_38, batch_39, batch_40]

# %% [markdown]
# <a href='#Obtain Sequence Data'>Back to section Obtain Protein Sequence Data</a>
#
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# ## API Pull<a id='api pull'></a>

# %%
# function to contact database
def get_ncbi_data(api, email, tool, database, ids):
    """To get data from the ncbi blast data base given: 
    an API key, 
    an email, must be on file with ncbi, 
    a tool, must be on file with ncbi, 
    the database name to search, and 
    the ids to search by in list format."""
    from Bio import Entrez
    import time
    Entrez.api_key = api
    Entrez.email = email
    Entrez.tool = tool
    print('Searching')
    time.sleep(10)
    search_results = Entrez.read(Entrez.epost(database, id=",".join(ids)))
    time.sleep(1)
    webenv = search_results["WebEnv"]
    query_key = search_results["QueryKey"]
    print('Fetching Results')
    results = Entrez.read(Entrez.efetch(db=database, webenv=webenv, query_key=query_key, retmode='xml'))
    protein_additional_data = pd.DataFrame()
    accession_version = []
    definition = []
    division = []
    topology = []
    moltype = []
    organism = []
    sequence = []
    chromosome = []
    molar_weight = []
    regions = []
    sites = []
    print('Parsing Results')
    for i in results:
        region = 0
        site = 0
        accession_version.append(i['GBSeq_accession-version'])
        organism.append(i['GBSeq_organism'])
        definition.append(i['GBSeq_definition'])
        division.append(i['GBSeq_division'])
        topology.append(i['GBSeq_topology'])
        moltype.append(i['GBSeq_moltype'])
        sequence.append(i['GBSeq_sequence'])
        if i['GBSeq_feature-table'][0]['GBFeature_key'] == 'source':
            chromosome.append(i['GBSeq_feature-table'][0]['GBFeature_quals'][2]['GBQualifier_value'])
        else:
            continue
        if i['GBSeq_feature-table'][1]['GBFeature_key'] == 'Protein':
            if i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][0]['GBQualifier_value'])
            elif i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][1]['GBQualifier_value'])
            elif i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][2]['GBQualifier_value'])
            elif i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][3]['GBQualifier_value'])
            elif i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][4]['GBQualifier_value'])
            elif i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][5]['GBQualifier_value'])
            elif i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_name'] == 'calculated_mol_wt':
                molar_weight.append(i['GBSeq_feature-table'][1]['GBFeature_quals'][6]['GBQualifier_value'])
            else:
                print('add more elif statements')
        else:
            continue
        for j in range(0, len(i['GBSeq_feature-table'])):
            if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Region':
                region += 1
            else:
                continue
        for j in range(0, len(i['GBSeq_feature-table'])):
            if i['GBSeq_feature-table'][j]['GBFeature_key'] == 'Site':
                site += 1
            else:
                continue
        regions.append(region)
        sites.append(site)
    protein_additional_data['Chromosome'] = chromosome
    protein_additional_data['Accession Version'] = accession_version
    protein_additional_data['Organism'] = organism
    protein_additional_data['Definition'] = definition
    protein_additional_data['Division'] = division
    protein_additional_data['Topology'] = topology
    protein_additional_data['Molecule Type'] = moltype
    protein_additional_data['Molecular Weight'] = molar_weight
    protein_additional_data['Number of Regions'] = regions
    protein_additional_data['Number of Binding Sites'] = sites
    protein_additional_data['Sequence'] = sequence
    time.sleep(10)
    print('Finished')
    return protein_additional_data

# %%
# contact database using api
email = 'elizabethfawcett47@gmail.com'
tool = 'locus_by_amino_acid'
protein_additional_dataframes = []
for batch in batches:
    protein_additional_dataframes.append(get_ncbi_data(api_key, email, tool, 'protein', batch))
# Out:
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished
# Searching
# Fetching Results
# Parsing Results
# Finished

# %%
# check random additional protein dataframe to see if sequence was captured
protein_additional_dataframes[39].head()
# Out:
#   Chromosome Accession Version      Organism  \
# 0         19       NP_579805.1  Homo sapiens
# 1         19       NP_579806.1  Homo sapiens
# 2         19       NP_579812.1  Homo sapiens
# 3         19       NP_579807.1  Homo sapiens
# 4         19       NP_579811.1  Homo sapiens
#
#                                           Definition Division Topology  \
# 0  immunoglobulin alpha Fc receptor isoform c pre...      PRI   linear
# 1  immunoglobulin alpha Fc receptor isoform d [Ho...      PRI   linear
# 2  immunoglobulin alpha Fc receptor isoform h [Ho...      PRI   linear
# 3  immunoglobulin alpha Fc receptor isoform e [Ho...      PRI   linear
# 4  immunoglobulin alpha Fc receptor isoform g [Ho...      PRI   linear
#
#   Molecule Type Molecular Weight  Number of Regions  Number of Binding Sites  \
# 0            AA            19367                  1                        0
# 1            AA            30794                  2                        2
# 2            AA            28212                  2                        0
# 3            AA            20223                  1                        0
# 4            AA            19462                  1                        2
#
#                                             Sequence
# 0  mdpkqttllclvlclgqriqaqegdfpmpfisaksspvipldgsvk...
# 1  mdpkqttllclgdfpmpfisaksspvipldgsvkiqcqaireaylt...
# 2  mdpkqttllclgdfpmpfisaksspvipldgsvkiqcqaireaylt...
# 3  mdpkqttllclgdfpmpfisaksspvipldgsvkiqcqaireaylt...
# 4  mdpkqttllclglygkpflsadrglvlmpgenisltcssahipfdr...

# %%
# stitch together additional protein data after sequence capture
protein_additional_data = pd.concat(protein_additional_dataframes)
protein_additional_data.head()
# Out:
#   Chromosome Accession Version      Organism  \
# 0         19    NP_001005240.1  Homo sapiens
# 1         19    XP_011526698.1  Homo sapiens
# 2         19       NP_808211.1  Homo sapiens
# 3         19       NP_803545.1  Homo sapiens
# 4         19       NP_003703.1  Homo sapiens
#
#                                           Definition Division Topology  \
# 0             olfactory receptor 4F17 [Homo sapiens]      PRI   linear
# 1  phospholipid phosphatase 2 isoform X1 [Homo sa...      PRI   linear
# 2  phospholipid phosphatase 2 isoform 3 [Homo sap...      PRI   linear
# 3  phospholipid phosphatase 2 isoform 2 [Homo sap...      PRI   linear
# 4  phospholipid phosphatase 2 isoform 1 [Homo sap...      PRI   linear
#
#   Molecule Type Molecular Weight  Number of Regions  Number of Binding Sites  \
# 0            AA            34081                  2                        7
# 1            AA            33015                  1                        1
# 2            AA            34262                  1                        1
# 3            AA            25972                  1                        1
# 4            AA            32443                  1                        8
#
#                                             Sequence
# 0  mvtefiflglsdsqglqtflfmlffvfyggivfgnllivitvvsds...
# 1  mqrrwvfvlldvlcllvgfssppaslpfailtlvnapykrgfycgd...
# 2  mgvargpgsrgqhppprqqevcaegprarlhpappglgaslpfail...
# 3  magvtitatvilvsageaylvytdrlysrsdfnnyvaavykvlgtf...
# 4  mqrrwvfvlldvlcllvaslpfailtlvnapykrgfycgddsiryp...

# %% [markdown]
# <a href='#Obtain Sequence Data'>Back to section Obtain Protein Sequence Data</a>
#
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# # Join Data<a id='Join Data'></a>

# %%
# selected dna data check
selected_dna_data.head()
# Out:
#                    # Sequence-Name       Sequence-Role Assigned-Molecule  \
# 37                              19  assembled-molecule                19
# 681                   HG2021_PATCH           fix-patch                19
# 683                     HG26_PATCH           fix-patch                19
# 685                    HG109_PATCH           fix-patch                19
# 687  HSCHR19KIR_0019-4656-A_CTG3_1         novel-patch                19
#
#     Assigned-Molecule-Location/Type GenBank-Accn Relationship     RefSeq-Accn  \
# 37                       Chromosome   CM000681.2            =    NC_000019.10
# 681                      Chromosome   KN196484.1            =  NW_009646206.1
# 683                      Chromosome   KQ458386.1            =  NW_014040929.1
# 685                      Chromosome   ML143376.1            =  NW_021160022.1
# 687                      Chromosome   KV575246.1            =  NW_016107300.1
#
#         Assembly-Unit  Sequence-Length UCSC-style-name
# 37   Primary Assembly       58617616.0           chr19
# 681           PATCHES         370917.0              na
# 683           PATCHES         405389.0              na
# 685           PATCHES         493165.0              na
# 687           PATCHES         163926.0              na

# %%
# selected protein data check
selected_protein_data.head()
# Out:
#        #Replicon Name Replicon Accession   Start    Stop Strand  GeneID  \
# 102114             19       NC_000019.10  110679  111596      +   81099
# 102115             19       NC_000019.10  281388  291336      -    8612
# 102116             19       NC_000019.10  281388  291066      -    8612
# 102117             19       NC_000019.10  281388  288055      -    8612
# 102118             19       NC_000019.10  281388  291336      -    8612
#
#          Locus Protein product  Length                           Protein name
# 102114  OR4F17  NP_001005240.1     305                olfactory receptor 4F17
# 102115   PLPP2  XP_011526698.1     294  phospholipid phosphatase 2 isoform X1
# 102116   PLPP2     NP_808211.1     309   phospholipid phosphatase 2 isoform 3
# 102117   PLPP2     NP_803545.1     232   phospholipid phosphatase 2 isoform 2
# 102118   PLPP2     NP_003703.1     288   phospholipid phosphatase 2 isoform 1

# %%
# selected dna data join to selected protein data
selected_dna_data.index = selected_dna_data['RefSeq-Accn']
dna_plus_protein = selected_protein_data.join(selected_dna_data, on='Replicon Accession', how='inner')
dna_plus_protein.head()
# Out:
#        #Replicon Name Replicon Accession   Start    Stop Strand  GeneID  \
# 102114             19       NC_000019.10  110679  111596      +   81099
# 102115             19       NC_000019.10  281388  291336      -    8612
# 102116             19       NC_000019.10  281388  291066      -    8612
# 102117             19       NC_000019.10  281388  288055      -    8612
# 102118             19       NC_000019.10  281388  291336      -    8612
#
#          Locus Protein product  Length                           Protein name  \
# 102114  OR4F17  NP_001005240.1     305                olfactory receptor 4F17
# 102115   PLPP2  XP_011526698.1     294  phospholipid phosphatase 2 isoform X1
# 102116   PLPP2     NP_808211.1     309   phospholipid phosphatase 2 isoform 3
# 102117   PLPP2     NP_803545.1     232   phospholipid phosphatase 2 isoform 2
# 102118   PLPP2     NP_003703.1     288   phospholipid phosphatase 2 isoform 1
#
#        # Sequence-Name       Sequence-Role Assigned-Molecule  \
# 102114              19  assembled-molecule                19
# 102115              19  assembled-molecule                19
# 102116              19  assembled-molecule                19
# 102117              19  assembled-molecule                19
# 102118              19  assembled-molecule                19
#
#        Assigned-Molecule-Location/Type GenBank-Accn Relationship  \
# 102114                      Chromosome   CM000681.2            =
# 102115                      Chromosome   CM000681.2            =
# 102116                      Chromosome   CM000681.2            =
# 102117                      Chromosome   CM000681.2            =
# 102118                      Chromosome   CM000681.2            =
#
#          RefSeq-Accn     Assembly-Unit  Sequence-Length UCSC-style-name
# 102114  NC_000019.10  Primary Assembly       58617616.0           chr19
# 102115  NC_000019.10  Primary Assembly       58617616.0           chr19
# 102116  NC_000019.10  Primary Assembly       58617616.0           chr19
# 102117  NC_000019.10  Primary Assembly       58617616.0           chr19
# 102118  NC_000019.10  Primary Assembly       58617616.0           chr19

# %%
# additional protein data join
protein_additional_data.index = protein_additional_data['Accession Version']
all_data = dna_plus_protein.join(protein_additional_data, on='Protein product', how='inner')
all_data.sample(10)
# Out:
#        #Replicon Name Replicon Accession     Start      Stop Strand  GeneID  \
# 4366               Un     NW_003571055.2    176167    182557      +    6203
# 3802               Un        NT_187684.1     86773    100740      -    3802
# 108209             19       NC_000019.10  54850476  54866731      +    3812
# 108006             19       NC_000019.10  53794049  53811241      -   91662
# 3715               Un        NT_187676.1    150240    165813      +    2204
# 4515               Un     NW_003571057.2    176167    182557      +    6203
# 5653               Un     NW_016107310.1     42307     56254      +    3803
# 103873             19       NC_000019.10  13751809  13763068      +   81576
# 5664               Un     NW_016107310.1    209676    218355      +    3812
# 4689               Un     NW_003571060.1    148822    163294      -   79143
#
#           Locus Protein product  Length  \
# 4366       RPS9  NP_001308630.1     194
# 3802    KIR2DL1     NP_055033.2     348
# 108209  KIR3DL2  NP_001229796.1     438
# 108006   NLRP12  XP_016882954.1     923
# 3715       FCAR     NP_579805.1     191
# 4515       RPS9     NP_001004.2     194
# 5653    KIR2DL2     NP_055034.2     348
# 103873  CCDC130  XP_005260143.1     396
# 5664    KIR3DL2     NP_006728.2     455
# 4689     MBOAT7  NP_001139528.1     399
#
#                                              Protein name  ...  \
# 4366                   40S ribosomal protein S9 isoform a  ...
# 3802    killer cell immunoglobulin-like receptor 2DL1 ...  ...
# 108209  killer cell immunoglobulin-like receptor 3DL2 ...  ...
# 108006  NACHT, LRR and PYD domains-containing protein ...  ...
# 3715    immunoglobulin alpha Fc receptor isoform c pre...  ...
# 4515                   40S ribosomal protein S9 isoform a  ...
# 5653    killer cell immunoglobulin-like receptor 2DL2 ...  ...
# 103873  coiled-coil domain-containing protein 130 isof...  ...
# 5664    killer cell immunoglobulin-like receptor 3DL2 ...  ...
# 4689         lysophospholipid acyltransferase 7 isoform 2  ...
#
#        Accession Version      Organism  \
# 4366      NP_001308630.1  Homo sapiens
# 3802         NP_055033.2  Homo sapiens
# 108209    NP_001229796.1  Homo sapiens
# 108006    XP_016882954.1  Homo sapiens
# 3715         NP_579805.1  Homo sapiens
# 4515         NP_001004.2  Homo sapiens
# 5653         NP_055034.2  Homo sapiens
# 103873    XP_005260143.1  Homo sapiens
# 5664         NP_006728.2  Homo sapiens
# 4689      NP_001139528.1  Homo sapiens
#
#                                                Definition Division Topology  \
# 4366    40S ribosomal protein S9 isoform a [Homo sapiens]      PRI   linear
# 3802    killer cell immunoglobulin-like receptor 2DL1 ...      PRI   linear
# 108209  killer cell immunoglobulin-like receptor 3DL2 ...      PRI   linear
# 108006  NACHT, LRR and PYD domains-containing protein ...      PRI   linear
# 3715    immunoglobulin alpha Fc receptor isoform c pre...      PRI   linear
# 4515    40S ribosomal protein S9 isoform a [Homo sapiens]      PRI   linear
# 5653    killer cell immunoglobulin-like receptor 2DL2 ...      PRI   linear
# 103873  coiled-coil domain-containing protein 130 isof...      PRI   linear
# 5664    killer cell immunoglobulin-like receptor 3DL2 ...      PRI   linear
# 4689    lysophospholipid acyltransferase 7 isoform 2 [...      PRI   linear
#
#        Molecule Type Molecular Weight Number of Regions  \
# 4366              AA            22460                 1
# 3802              AA            36328                 3
# 108209            AA            46277                 4
# 108006            AA           104290                 0
# 3715              AA            19367                 1
# 4515              AA            22460                 1
# 5653              AA            36221                 2
# 103873            AA            44671                 1
# 5664              AA            47991                 3
# 4689              AA            44602                 1
#
#         Number of Binding Sites  \
# 4366                          5
# 3802                          5
# 108209                        4
# 108006                        0
# 3715                          0
# 4515                          5
# 5653                          6
# 103873                        0
# 5664                          5
# 4689                          0
#
#                                                  Sequence
# 4366    mpvarswvcrktyvtprrpfeksrldqelkligeyglrnkrevwrv...
# 3802    msllvvsmacvgffllqgawphegvhrkpsllahpgrlvkseetvi...
# 108209  msltvvsmacvgffllqgawplmggqdkpflsarpstvvprgghva...
# 108006  medrnarlgecvnlshrytrlllvkehsnpmqvqqqlldtgrghar...
# 3715    mdpkqttllclvlclgqriqaqegdfpmpfisaksspvipldgsvk...
# 4515    mpvarswvcrktyvtprrpfeksrldqelkligeyglrnkrevwrv...
# 5653    mslmvvsmacvgffllqgawphegvhrkpsllahpgrlvkseetvi...
# 103873  mgerkgvnkyyppdfnpekhgslnryhnshplrerarklsqgilii...
# 5664    msltvvsmacvgffllqgawplmggqdkpflsarpstvvprgghva...
# 4689    mgssrcgpgahpvhlwpphfafsghhprdlgphsgpallvslasev...
#
# [10 rows x 31 columns]

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# # References<a id='References'></a>
# 1. Stephen F. Altschul, Thomas L. Madden, Alejandro A. Schäffer, Jinghui Zhang, Zheng Zhang, Webb Miller, and David J. Lipman (1997), "Gapped BLAST and PSI-BLAST: a new generation of protein database search programs", Nucleic Acids Res. 25:3389-3402.
# 2. https://towardsdatascience.com/processing-xml-in-python-elementtree-c8992941efd2 # processing xml data
# 3. https://stackoverflow.com/questions/10220412/convert-tab-delimited-txt-file-into-a-csv-file-using-python # import of a text file
# 4. https://www.ncbi.nlm.nih.gov/assembly/model/
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.39_GRCh38.p13/GCF_000001405.39_GRCh38.p13_assembly_report.txt # dna data
# 5. https://www.ncbi.nlm.nih.gov/genomes/Genome2BE/genome2srv.cgi?action=GetFeatures4Grid&amp;download=on&amp;type=Proteins&amp;genome_id=51&genome_assembly_id=582967&mode=2&is_locus=1&is_locus_tag=0&optcols=1,0,0,0,0 # protein data
# 6. https://blast.ncbi.nlm.nih.gov/Blast.cgi?CMD=Web&PAGE_TYPE=BlastDocs&DOC_TYPE=References
# 7. https://www.ncbi.nlm.nih.gov/pubmed/20003500?dopt=Citation # paper for the creation of blast+
# 8. https://www.ncbi.nlm.nih.gov/books/NBK52637/ # stand alone blast+ set up for pc
# 9. ftp://ftp.ncbi.nlm.nih.gov/blast/db/ # data base location
# 10. http://seqanswers.com/forums/showthread.php?t=44370 # troubleshooting database set up
# 11. https://widdowquinn.github.io/2018-03-06-ibioic/02-sequence_databases/03-programming_for_blast.html # python/blast+ integration
# 12. http://biopython.org/DIST/docs/tutorial/Tutorial.pdf # use of entrez package for online searches using api
# 13. https://www.ncbi.nlm.nih.gov/books/NBK25499/

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents

# %% [markdown]
# # Future Work<a id='Future Work'></a>

# %%
# save data for use in other notebooks
all_data.to_csv('all_protein_data_19.csv')

# %% [markdown]
# <a href='#Table of Contents'>Back to Table of Contents
